# %% [markdown]
# # [0. Settings](#0)
# <br></br>
# ## [0.1 Librerie](#0.1)

# %% [markdown]
# <font size=3>
#
# Le librerie importate hanno le seguenti funzionalità:
# * `selenium`: la libreria principale attraverso la quale si effettuerà lo scraping. Da esse sono importati diversi moduli:
#     * `webdriver`: attraverso `selenium` è possibile tramite codice aprire una nuova finestra del browser. Nel caso in questione è stato utilizzato Firefox, la comunizazione fra i due avviene attraverso un file esterno `geckodriver.exe`.
#     * `ActionChains`: permette al browser di simulare azioni di un utente come ad esempio un click.
#     * `NoSuchElementException`: nella fase di scraping si cercherà di individuare elementi tramite il loro `xpath`, nel caso l'elemento non sia individuato l'errore risultate è quello riportato. Per non bloccare il codice davanti a questi errori ma lasciarlo continuare è necessario importare questa liberia.
#     * `ElementNotInteractableException`: come il precedente ma è riferito ad un elemento con cui non si può interagire (ad esempio un click).
# * `Counter`: una funzione che permette di contare gli elementi all'interno di una lista o un dizionario e ne restituisce la frequenza. Utile per controllare se ci sono dei duplicati.
# * `deepflatten`: permette di trasformare liste di liste in un'unica lista.
# * `os`: permette di specificare un percorso in locale da cui accedere a dei file.
# * `pandas`: libreria per gestire dataframe.
# * `pickle`: permette di salvare elementi creati in una sessione e caricarli in una successiva senza alternarne la loro struttura.
# * `time`: serve per gestire la tempistica con cui le operazioni di scraping verranno effettuate.
# * `tqdm`: se applicato ad un ciclo stima il tempo necessario per tutte le iterazioni.

# %%
from collections import Counter
from iteration_utilities import deepflatten

from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException

from tqdm import tqdm

import pandas as pd
import pickle
import os
import time

os.chdir('D:/Scraping')

# %% [markdown]
# <br></br>
# ## [0.2 Impostazioni Firefox](#0.2)

# %% [markdown]
# <font size=3>
#
# Nelle impostazioni del browser vengono disabilitate le immagini, questo permette un caricamento della pagina più veloce e allo stesso tempo non modifica il codice degli elementi da invididuare.

# %%
firefox_profile = webdriver.FirefoxProfile()
firefox_profile.set_preference('permissions.default.image', 2)
firefox_profile.set_preference('dom.ipc.plugins.enabled.libflashplayer.so', 'false')

# %% [markdown]
# <br></br>
# ## [0.3 Pickle Load](#0.3)

# %% [markdown]
# <font size=3>
#
# L'operazione di scraping è stata effettuata in più sessioni per via dei tempi esigenti nell'ottenere tante recensioni di uno stesso film, da qui l'esigenza di creare dei file `pickle` che permettono di salvare un oggetto e di ricaricarlo senza che la sua struttura sia modificata, in questo caso vengono caricate delle liste.

# %%
with open('output_review', "rb") as input_file:
    review_list = pickle.load(input_file)
with open('output_score', "rb") as input_file2:
    score_list = pickle.load(input_file2)
with open('output_date', "rb") as input_file3:
    date_list = pickle.load(input_file3)
with open('output_title', "rb") as input_file4:
    title_list = pickle.load(input_file4)

# %% [markdown]
# <br></br> <br></br>
# # [1. Scraping](#1)
# <br></br>
# ## [1.1 Funzione recensioni](#1.1)

# %% [markdown]
# <font size=3>
#
# La funzione `reviews` permette di estrarre le informazioni da un film. Prende in input i seguenti parameri:
# * `url`: un indirizzo da quale sono mostrati i film di interesse. Nel caso in questione i film da cui trarre informazioni sono film Drama, preferibilmente con una quantità elevata di commenti. L'url può quindi essere scomposto nelle seguenti parti: <br></br>
#     * `base`: <i>"https://www.imdb.com/search/title/?title_type=feature"</i>, è la parte comune a tutti gli url, viene ricavato dalla funzione di ricerca avanzata del sito.
#     * `data`: <i>"&release_date=YYYY-MM-DD,YYYY-MM-DD"</i>, l'approccio prevede l'estrazione dei commenti di film usciti in anni diversi, nella fase di ricerca è possibile indicare un filtro con cui sono selezionati i film di un determinato anno. Nel primo parametro viene specificata la data minima di uscita del film, $1$ gennaio dell'anno specifico, mentre nel secondo la data massima, $31$ dicembre dell'anno specifico.
#     * `genere`: <i>"&genres='genre'"</i>, il genere specifico da cui estrarre i film, nel caso in questione è stato scelto "drama" in quanto offre il numero più elevato di film e di conseguenza di commenti.
#     * `numero risultati`: <i>"&count='num'"</i>, rappresenta il numero di risultati da visualizzare per pagina, per lo scraping è stato posto al massimo ottenibile dal sito, ovvero $250$. Questo rende le operazioni di scraping più semplici, in quanto dopo il $250$&ndash;esimo film il numero di recensioni inzia ad essere esiguo e quindi non conviene estrarre ulteriori commenti, in questo modo si evita di caricare la pagina successiva, un passaggio delicato che potrebbe portare a degli errori.
#
# * `review_list`: in un blocco a parte viene inizializzata una lista in cui verrano inserite le recensioni. Il risultato sarà una lista di liste dove ogni lista interna conterrà un numero variabile di commenti ma sempre riferiti allo stesso film.
# * `score_list`: come sopra in riferimento al punteggio della recensione su una scala da $1$ a $10$.
# * `date_list`: come sopra in riferimento alla data della recensione.
# * `title_list`: una lista in cui viene salvato il nome del film. A differenza delle tre liste precedenti, questa è una lista semplice in quanto, come dice il nome, è in riferimento al film e non alla singola recensione.
#
# <br></br>
# Il codice inzia definendo la variabile `movie` che apre il browser sul'url predefinito; in questa pagina viene visualizzata una lista dei $250$ film drama più popolari di un anno specifico. Il ciclo `for`  si sviluppa per un numero grande tanto quanto sono i film per pagina. All'interno di esso sono effettuate le seguenti operazioni:
# * Viene identificato l'`xpath` relativo al titolo del film, nel caso specifico il titolo viene suddiviso dal sito in due elementi distinti, per questo vengono inzializzate due variabili, `title` e `title 2`, che fanno riferimento a due xpath diversi. Il motivo per cui il sito effettua questa distinzione è per evitare casi di omonimia: la prima parte è il titolo vero e proprio del film, la seconda parte è solamente l'anno di uscita messo tra parentesi. <br></br>
# L'oggetto ricavato è nel formato della libreria utilizzata, in questo caso `selenium`, per accedere al contenuto testuale si deve applicare la funzione `text` alle variabili. I due titoli vengono uniti mediante un separatore come spazio e il risultato è aggiunto alla lista dei titoli. <br></br>
# La pagina riporta i film come un elenco, quindi per selezionare di volta in volta il film successivo è necessario modificare l'xpath ad ogni iterazione, da qui l'esigenza di introdurre l'elemento `str(i + 1)` in prossimità della parte che fa riferimento all'ordine nella lista dei film.
# * Sono inizializzate delle liste temporanee per recensioni, punteggi e date. In queste liste verranno salvate informazioni per ogni recensione e delle nuove liste vengono inizializzate quando si passa al film successivo. In questo modo si creano liste di liste in cui ogni lista contiene informazioni relative ad un unico film.
# * Viene catturato un nuovo xpath, in questo caso il collegamento ipertestuale che porta alla pagina principale del film. Ancora una volta è necessario chiamare una funzione, `get_attribute`, per ricavare il valore testuale identificato. Si effettua una modifica all'url in modo tale da accedere alla pagina delle recensioni. Qui viene aperta una nuova finestra per accedere alle recensioni.
#
# Una complicazione nel processo di ricavare le recensioni riguarda la possibilità di visualizzare a video le recensioni stesse. Di default il sito permette di visualizzare solamente $25$ recensioni e questa quantità non è modificabile inserendo degli elementi aggiuntivi nell'url. L'unica via percorribile è la seguente:
# * In fondo alla pagine è presente la casella `Load More` che se cliccata permette di visualizzare ulteriori 25 recensioni.
# * Viene quindi identificato l'xpath corrispondente a quella casella e tramite la funzione `click` è possibile in maniera automatico cliccare sull'elemento trovato.
# * Le recensioni di un film possono raggiungere, nel caso di film molto popolari, anche oltre $5000$ unità, la navigazione sulla pagina diventa estremamente lenta per la quantità eccessiva di testo, da qui l'esigenza di limitare il numero di possibili click a $39$ per un massimo di $1000$ commenti per film.
# * È necessario effettuare un cooldown fra un click e l'altro in modo da lasciare abbastanza tempo al browser di caricare i nuovi commenti. Senza il comando `time.sleep` che permette di fermare il codice per un certo lasso di tempo, nel caso in questione $2$ sono sufficienti, il codice una volta caricati i nuovi commenti cercherebbe immediatamente la casella "Load More", ma in alcuni casi una ricerca così repentina porta ad un errore di elemento non trovato.
# * Per i film meno conosciuti invece si pone il problema opposto, ovvero che non ci sono molti commenti e quindi non è presente la casella "Load More" direttamente all'inizio o prima delle iterazioni prefeissate. A questo proposito è stato creato un blocco di `try` &ndash; `except`, nel caso in cui l'elemento da cliccare non fosse disponibile, il codice passa direttamente allo step successivo.
#
# Caricate tutte le recensioni possibili, esse si trovano in un formato simile ad una lista, come capitava per i titoli dei film. Tutti gli xpath che si identificheranno dovranno quindi essere modificati con `str(i + 1)` per ricavare di volta in volta la recensione di interesse. Questo ultimo step si articola in:
# * Un ciclo for che identifica $25$ elementi tante volte quanti sono stati i click effettuati in precedenza.
# * Di default le recensioni lunghe risultano trocante, con una freccia in basso a destra che se cliccata permette di visualizzare il testo completo. Per ogni recensione si verifica l'eventuale esistenza di questo elemento, sempre facendo riferimento all'xpath relativo, se è trovato allora si applica un click per visualizzare a schermo il commento completo.
# * Esiste un'altra categoria di recensioni che sono quelle contrassegnate da spoiler, per queste non è possibile vedere alcuna porzione di testo e si deve cliccare sempre una freccia in basso a destra per mostrare il tutto. Si è dovuto implementare un blocco di `try` &ndash; `except` aggiuntivo in quanto gli xpath di riferimento tra le recensioni troncate e spoiler sono differenti.
# * Se non risultano problemi con l'xpath della recensione, il contenuto viene salvato nella lista temporanea delle recensioni così come per la data e lo score.
# * Una volta raccolte tutte le informazioni delle recensioni di uno specifico film, le liste temporanee vengono salvate all'interno delle liste passate come parametri della funzione.
#
# Quando tutte le informazioni di un film sono state salvate, la finestra del browser con le recensioni viene chiusa e si inizia una nuova iterazione per un nuovo film. Al termine di tutti i $250$ film, viene chiuso anche la finestra iniziale con la lista di tutti i film e i contenuti delle liste sono messi in output dalla funzione. <br>
# Si è ritenuto necessario aprire e chiudere le finestre del browser ad ogni iterazione in quanto proseguire con i comandi di pagina precedente, è noto che la velocità del browser diminuisce all'aumentare delle iterazioni.

# %%
def reviews(url, review_list, score_list, date_list, title_list):
    movie = webdriver.Firefox(executable_path=r'D:/Scraping2/geckodriver.exe')
    movie.get(url)
    
    for i in range(250):
        """
        Nella lista verranno salvate le recensioni di un singolo film, questa lista verrà aggiunta alla lista creata prima.
        Dall'xpath si estrae l'elemento 'href' che contiene l'indirizzo url della pagina del film.
        """
        title = movie.find_element_by_xpath('/html/body/div[3]/div/div[2]/div[3]/div[1]/div/div[3]/div/div[' + str(i + 1) + ']/div[3]/h3/a')
        title2 = movie.find_element_by_xpath('/html/body/div[3]/div/div[2]/div[3]/div[1]/div/div[3]/div/div[' + str(i + 1) + ']/div[3]/h3/span[2]')
        title_list.append(title.text + ' ' + title2.text)
        
        temp_review_list = [] 
        temp_score_list = []
        temp_date_list = []
        xpath = '//*[@id="main"]/div/div[3]/div/div[' + str(i + 1) + ']/div[3]/h3/a'
        element = movie.find_element_by_xpath(xpath=xpath)
        href = element.get_attribute('href')

        temp_url = href.split('?')
        reviews_url = temp_url[0] + "reviews" # Si crea l'url per le recensioni nascondendo quelle con spoiler
        movie2 = webdriver.Firefox(executable_path=r'D:/Scraping2/geckodriver.exe')
        movie2.get(reviews_url)
        
        
        """
        Si caricano le recensioni e si clicca su "Load more" un numero predefinito di volte (10 nell'esempio).
        Ogni click fa apparire 25 nuove recensioni, se non ce ne sono abbastanza, l'exception fa andare alla parte successiva.
        Il click avviene ogni 3 secondi, senza un delay il browser poteva non identificare l'elemento anche se presente.
        """
        next_review = 0
        click_count = 0
        while click_count < 39:
            try:
                load_more = movie2.find_element_by_xpath(xpath='//*[@id="load-more-trigger"]')
                load_more.click()
                click_count = click_count + 1
                time.sleep(2)
            except (NoSuchElementException, ElementNotInteractableException):
                click_count = 39
                
        """
        Si identifica l'xpath relativo ad ogni recensione, se non è trovato si passa avanti.
        Per ogni recensione si verifica se è troncata e bisogna cliccare la freccia per far comparire tutto il testo.
        Ad ogni iterazione la recensione viene salvata nella lista interna.
        A fine iterazioni la lista creata viene aggiunta alla lista principale e la finestra viene chiusa.
        Da qui poi si prende l'url del film successivo e si procede per 50 film.
        """
        for i in range(25 * click_count):
            review_xpath = '/html/body/div[3]/div/div[2]/div[3]/div[1]/section/div[2]/div[2]/div[' + str(i + 1) + ']/div[1]/div[1]/div[3]/div'
            try: # verifica se la recensione è troncata
                long_text = movie2.find_element_by_xpath('/html/body/div[3]/div/div[2]/div[3]/div[1]/section/div[2]/div[2]/div[' + str(i + 1) + ']/div[2]/div[2]/div[1]/div/div')
                long_text.click()
            except (NoSuchElementException, ElementNotInteractableException):
                try: # prova a vedere se la recensione è uno spoiler
                    long_text = movie2.find_element_by_xpath('/html/body/div[3]/div/div[2]/div[3]/div[1]/section/div[2]/div[2]/div[' + str(i + 1) + ']/div/div[1]/div[2]/div/div')
                    long_text.click()
                    review_xpath = '/html/body/div[3]/div/div[2]/div[3]/div[1]/section/div[2]/div[2]/div[' + str(i + 1) + ']/div/div[1]/div[4]/div[1]'
                except (NoSuchElementException, ElementNotInteractableException):
                    pass

            try: # verifica se esiste effettivamente la recensione
                review = movie2.find_element_by_xpath(review_xpath)
                temp_review_list.append(review.text)

                score = movie2.find_element_by_xpath('/html/body/div[3]/div/div[2]/div[3]/div[1]/section/div[2]/div[2]/div[' + str(i + 1) + ']/div[1]/div[1]/div[1]/span/span[1]')
                temp_score_list.append(score.text)

                date = movie2.find_element_by_xpath('/html/body/div[3]/div/div[2]/div[3]/div[1]/section/div[2]/div[2]/div[' + str(i + 1) + ']/div[1]/div[1]/div[2]/span[2]')
                temp_date_list.append(date.text)

            except (NoSuchElementException):
                pass

        review_list.append(temp_review_list)
        score_list.append(temp_score_list)
        date_list.append(temp_date_list)
        movie2.quit()
        
    movie.quit()
    
    return (review_list, score_list, date_list, title_list)

# %% [markdown]
# <font size=3>
#
# Nella seguente riga di codice sono create le liste che saranno passate come input alla funzione di scraping. Le liste sono inizializzate una volta sola e non per ogni anno, essendo soggette solamente ad un append, anche passando alla funzione `reviews` una lista non vuota, i nuovi elementi saranno aggiunti in coda senza sovrascrivere quelli già esistenti.

# %%
review_list = [] 
score_list = []
date_list = []
title_list = []

# %%
url = 'https://www.imdb.com/search/title/?title_type=feature&release_date=2001-01-01,2001-12-31&genres=drama&count=250'
(review, score, date, title) = reviews(url=url, 
                                       review_list=review_list, 
                                       score_list=score_list, 
                                       date_list=date_list, 
                                       title_list=title_list)

# %% [markdown]
# <font size=3>
#
# Come detto in precedenza il processo per ricavare le recensioni di quasi $30$ anni ha richiesto diverso tempo e diverse sessioni di lavoro. Una volta chiuso il notebook le variabili presenti sono eliminate, quindi sono stati creati dei salvataggi ad ogni sessione attraverso la funzione `pickle.dump` che crea un oggetto con estensione anonima in cui gli elementi sono salvati senza modifiche e possono essere ricaricati all'inizio di ogni sessione senza ulteriori modifiche.

# %% [markdown]
# <br></br>
# ## [1.2 Pickle Save](#1.2)

# %%
os.chdir('D:/Scraping')
with open('output_review', 'wb') as fp:
    pickle.dump(review_list, fp)
    
with open('output_score', 'wb') as fp2:
    pickle.dump(score_list, fp2)
    
with open('output_date', 'wb') as fp3:
    pickle.dump(date_list, fp3)
    
with open('output_title', 'wb') as fp4:
    pickle.dump(title_list, fp4)

# %% [markdown]
# <br></br>
# <br></br>
# # [2. Controllo Recensioni](#2)
# <br></br>
# ## [2.1 Confronto lunghezza e titoli](#2.1)

# %% [markdown]
# <font size=3>
#
# Si è notato che c'erano alcuni problemi con particolari titoli di film, nello specifico quelli relativi al $2016$ e $2017$ per la presenza di parentesi all'interno del titolo (parentesi non relative all'anno di uscita). Questo codice ha cercato di sistemare queste problematiche e successivamente viene effettuato un conteggio per verificare se tutti i film sono stati presi una volta sola. <br></br>
#
# Il print è stato effettuato dopo la correzione nei blocchi successivi, in origine un titolo era presente due volte.

# %%
film = []
for el in title_list:
    temp = el.split('(')
    if len(temp) == 2:
        if '2017' or '2016' in temp[1]:
            film.append(temp[0] + '(' + temp[1])
    if len(temp) == 3:
        if '2017' or '2016' in temp[2]:
            film.append(temp[0] + ' ' + temp[1] + '(' + temp[2])

freq = Counter(film).most_common(10)
freq
# Out:
# [("Le Mans '66 - La grande sfida (2019)", 1),
#  ('Joker (2019)', 1),
#  ('The Irishman (2019)', 1),
#  ('Cats (2019)', 1),
#  ('Doctor Sleep (2019)', 1),
#  ('Midway (2019)', 1),
#  ("C'era una volta a... Hollywood (2019)", 1),
#  ('Cena con delitto - Knives Out (2019)', 1),
#  ('Last Christmas (2019)', 1),
#  ('Il re  I) (2019)', 1)]

# %% [markdown]
# <font size=3>
#
# Un titolo risulta duplicato e non ci sono recensioni a cui fa riferimento, viene quindi eliminato l'elemento dalla lista.

# %%
print(title_list.index(b[0][0]))
print(title_list[501])
print(review_list[500], '\n', review_list[501])
print(title_list[502])

del title_list[501]

# %% [markdown]
# <font size=3>
#
# Stranamente era presente un titolo duplicato a cui però non erano legate recensioni, quindi probabilmente il codice di scraping si era fermato ad individuare solamente il primo titolo di un film e poi per qualche motivo si è interrotto.
# Da qui la necessità di sistemare l'ordine dei film presenti nella lista completa:
# * Il primo for entra all'interno di ogni gruppo di recensioni
# * Il secondo for aggiunge nella nuova lista il nome del film di riferimento tante volte quanti sono i commenti ottenuti.

# %%
new_title_list = []
for cont in range(len(review_list)):
    for cont2 in range(len(review_list[cont])):
        new_title_list.append(title_list[cont])

# %% [markdown]
# <br></br>
# ## [2.2 Confronto score e data](#2.2)

# %% [markdown]
# <font size=3>
#
# Analogamente a quanto fatto in precedenza si controlla la lunghezza delle liste contenenti il punteggio e la data della recensione. Dato che si lavora con liste di liste, si controlla la lunghezza di tutte le lunghezze delle liste interne, se la lunghezza delle due liste non combacia significa che in una delle due è stato salvato un elemento in più o in meno. Il codice stampa a video l'indice della lista per cui si verificano problemi.

# %%
for i in range(len(score_list)):
    if len(review_list[i]) == len(date_list[i]):
        pass
    else:
        print(i)
# Out:
# 540

# %% [markdown]
# <font size=3>
#
# Per un errore del sito, una data non è visualizzata correttamente, come se non ci fosse una tabulazione fra il nome dell'utente che ha postato la recensione e la data, in questo modo i due oggetti appaiono attaccati come rappresentato nella seguente immagine nel riquadro nero.
# ![title](Date_error1.png) <br></br>
#
# Questa struttura diversificata non permette l'individuazione corretta dell'xpath associato alla data, mentre per il punteggio non ci sono problemi, da qui la discrepanza nelle lunghezze delle liste. <br></br>
#
# La data con errore è stata individuata manualmente non avendo a disposizioni altre informazioni se non il titolo del film per identificare l'errore. Sempre manualmente quindi si procede con l'aggiungere la data mancante alla lista:
# * Attraverso la funzione `index` viene identificato l'indice della data specificata, in questo caso è l'indice relativo alla prima data ottenuta dopo quella dove si è verificato l'errore.
# * Si salva in una variabile temporanea il contenuto della lista delle date fino all'indice identificato al passo prima e lo stesso contenuto viene eliminato dalla lista originale. <br></br>
# (nota: questo meccanismo è rischioso in quanto la funzione `index` restituisce il primo indice di cui trova l'elemento, nel caso ci fossero state più recensioni nella stessa data, sarebbe potuto accadere che l'indice in output non corrispondesse a quello dopo la data mancante. La possibilità di questo errore è presente in quanto le recensioni sul sito sono elencate in base all'"utilità" e non per data. L'utilità è il rapporto fra il numero di persone che ha ritenuto quella recensione utile e quelli che non l'hanno trovata utile, in caso di rapporto uguale prevale il numero di recensioni utili e successivamente si procede per data. Nel caso in questione solo una recensione è stata scritta in quella data quindi l'indice riportato è certamente quello corretto).
# * Viene aggiunta la data mancante alla data originale e successivamente il contenuto della lista temporanea che è stato momentaneamente eliminato.

# %%
idx = date_list[540].index("25 February 2019")
temp = date_list[540][idx:]
del date_list[540][idx:]

date_list[540].append("31 March 2019")
for el in temp:
    date_list[540].append(el)

# %% [markdown]
# <font size=3>
#
# La funzione `deepflatten` restituisce un oggetto in cui tutti gli elementi al suo interno sono posti ad una determinata stratificazione, specificando `depth=1` sono posti tutti allo stesso livello. L'oggetto risultante viene poi trasfomrato in una lista. <br></br>
# Questo passaggio deriva dalla necessità di dover ottenere un'unica lista con le recensioni, punteggio e data e non una lista di liste.

# %%
reivew_flatten = list(deepflatten(review_list, depth=1))
score_flatten = list(deepflatten(score_list, depth=1))
date_flatten = list(deepflatten(date_list, depth=1))

# %% [markdown]
# <font size=3>
#
# Partendo dalla lista di film modificata eliminando il doppione e dalle liste di liste rese una lista unica, si crea un dataftame contenente queste informazioni.

# %%
df = pd.DataFrame({'Title':new_title_list, 'Review':reivew_flatten, 'Date':date_flatten, 'Score':score_flatten})
df.head()
# Out:
#                 Date                                             Review Score  \
# 0   16 November 2019  This is what cinema is supposed to be! Amazing...    10
# 1   20 November 2019  Rating 10/10 Inspired movie of the year. It is...    10
# 2   15 November 2019  I was at the Philadelphia Film center premiere...    10
# 3     31 August 2019  Just saw F v F at the Telluride Film Festival ...    10
# 4  10 September 2019  Biopics can be a hard sell at times. Whether y...     9
#
#                                   Title
# 0  Le Mans '66 - La grande sfida (2019)
# 1  Le Mans '66 - La grande sfida (2019)
# 2  Le Mans '66 - La grande sfida (2019)
# 3  Le Mans '66 - La grande sfida (2019)
# 4  Le Mans '66 - La grande sfida (2019)

# %% [markdown]
# <br></br>
# <br></br>
# # [3 Merge](#3)
# <br></br>
# ## [3.1 Part 2](#3.1)

# %% [markdown]
# <font size=3>
#
# Come già detto in precedenza lo scraping ha richiesto molto tempo e per velocizzare il processo si è provato a utilizzare la funzione `review` su più notebook in quanto in uno stesso non è possibile far girare più blocchi di codice contemporaneamente. <br></br>
# Per gli altri notebook il contenuto era lo stesso qua presente e alla fine di ogni sessione veniva salvato l'output delle liste. Una volta terminato il processo i file completi sono caricati tramite la libreria `pickle` come visto in precedenza. In seguito ci sono tutti gli step di controllo sui titoli e le recensioni che sono stati applicati in precedenza all'output di questo notebook.

# %%
with open('output_review2', "rb") as input_file:
    review_list2 = pickle.load(input_file)
with open('output_score2', "rb") as input_file2:
    score_list2 = pickle.load(input_file2)
with open('output_date2', "rb") as input_file3:
    date_list2 = pickle.load(input_file3)
with open('output_title2', "rb") as input_file4:
    title_list2 = pickle.load(input_file4)

# %%
print(len(review_list2), len(score_list2), len(date_list2), len(title_list2))

for i in range(len(review_list2)):
    if len(review_list2[i]) == len(date_list2[i]):
        pass
    else:
        print(i)
# Out:
# 1500 1500 1500 1500

# %% [markdown]
# <font size=3>
#
# Originariamente c'era una recensione vuota in ecccesso.

# %%
del review_list2[1204][2]

# %% [markdown]
# <font size=3>
#
# I tre step vist in in precedenza sono combinati:
# * Creazione di una lista unica partendo da liste di liste
# * Controllo dei titoli dei film
# * Creazione di un dataframe

# %%
reivew_flatten2 = list(deepflatten(review_list2, depth=1))
score_flatten2 = list(deepflatten(score_list2, depth=1))
date_flatten2 = list(deepflatten(date_list2, depth=1))

new_title_list2 = []
for cont in range(len(review_list2)):
    for cont2 in range(len(review_list2[cont])):
        new_title_list2.append(title_list2[cont])
        
df2 = pd.DataFrame({'Title':new_title_list2, 'Review':reivew_flatten2, 'Date':date_flatten2, 'Score':score_flatten2})
df2.head()
# Out:
#                Date                                             Review Score  \
# 0  23 December 2012  I only had one thought on my mind for this Chr...     8
# 1  26 December 2012  Merry Christmas to all you Tarantino fans out ...    10
# 2  26 December 2012  Absolutely loved every minute of this movie. U...    10
# 3  26 December 2012  Quentin Tarantino's 8th film "Django Unchained...    10
# 4    1 January 2013  In Quentin Tarantino's Django Unchained, there...     9
#
#                      Title
# 0  Django Unchained (2012)
# 1  Django Unchained (2012)
# 2  Django Unchained (2012)
# 3  Django Unchained (2012)
# 4  Django Unchained (2012)

# %% [markdown]
# <br></br>
# ## [3.2 Part 3](#3.2)

# %%
with open('output_review3', "rb") as input_file:
    review_list3 = pickle.load(input_file)
with open('output_score3', "rb") as input_file2:
    score_list3 = pickle.load(input_file2)
with open('output_date3', "rb") as input_file3:
    date_list3 = pickle.load(input_file3)
with open('output_title3', "rb") as input_file4:
    title_list3 = pickle.load(input_file4)

# %%
print(len(review_list3), len(score_list3), len(date_list3), len(title_list3))

for i in range(len(review_list3)):
    if len(review_list3[i]) == len(score_list3[i]):
        pass
    else:
        print(i)
# Out:
# 1500 1500 1500 1500

# %% [markdown]
# <font size=3>
#
# Anche in questo caso si aveva una recensione vuota extra.

# %%
del review_list3[971][1]

# %%
reivew_flatten3 = list(deepflatten(review_list3, depth=1))
score_flatten3 = list(deepflatten(score_list3, depth=1))
date_flatten3 = list(deepflatten(date_list3, depth=1))

new_title_list3 = []
fl = 0
for cont in range(len(review_list3)):
    for cont2 in range(len(review_list3[cont])):
        new_title_list3.append(title_list3[cont])
        
df3 = pd.DataFrame({'Title':new_title_list3, 'Review':reivew_flatten3, 'Date':date_flatten3, 'Score':score_flatten3})
df3.head()
# Out:
#                Date                                             Review Score  \
# 0      8 March 2009  For over 25 years now, I have cited Blade Runn...    10
# 1  25 February 2009  Screened FRebruary 23 for Australian Media.\n\...    10
# 2      3 March 2009  Before anyone sees this film, Zach Snyder shou...     8
# 3     14 March 2009  Watchmen is the long-awaited graphic novel ada...    10
# 4     10 March 2009  Firstly, I have not read the graphic novel. Th...    10
#
#              Title
# 0  Watchmen (2009)
# 1  Watchmen (2009)
# 2  Watchmen (2009)
# 3  Watchmen (2009)
# 4  Watchmen (2009)

# %% [markdown]
# <br></br>
# ## [3.3 Part 4](#3.3)

# %%
with open('output_review4', "rb") as input_file:
    review_list4 = pickle.load(input_file)
with open('output_score4', "rb") as input_file2:
    score_list4 = pickle.load(input_file2)
with open('output_date4', "rb") as input_file3:
    date_list4 = pickle.load(input_file3)
with open('output_title4', "rb") as input_file4:
    title_list4 = pickle.load(input_file4)

# %%
print(len(review_list4), len(score_list4), len(date_list4), len(title_list4))

for i in range(len(review_list4)):
    if len(review_list4[i]) == len(date_list4[i]):
        pass
    else:
        print(i)
# Out:
# 1500 1500 1500 1500
# 1011

# %% [markdown]
# <font size=3>
#
# Anche in questo caso la differente lunghezza delle liste è dovuto al fatto che una data non è stata catturata correttamente. Per risolvere il problema si procede in maniera analoga a quanto visto in precedenza. Le prime righe di codice servono per avere un'idea di dove si trovi il commento con errore.
# ![title](Date_error2.png) <br></br>

# %%
temp_l = []
for i in range(len(date_list4[1011])):
    temp_l.append(score_list4[1011][i] + ' - ' + date_list4[1011][i])

date_list4[1011].index("25 January 2005")


temp = date_list4[1011][129:]
del date_list4[1011][129:]
date_list4[1011].append("29 June 2004")
for el in temp:
    date_list4[1011].append(el)

# %%
reivew_flatten4 = list(deepflatten(review_list4, depth=1))
score_flatten4 = list(deepflatten(score_list4, depth=1))
date_flatten4 = list(deepflatten(date_list4, depth=1))

new_title_list4 = []
fl = 0
for cont in range(len(review_list4)):
    for cont2 in range(len(review_list4[cont])):
        new_title_list4.append(title_list4[cont])
        
df4 = pd.DataFrame({'Title':new_title_list4, 'Review':reivew_flatten4, 'Date':date_flatten4, 'Score':score_flatten4})
df4.head()
# Out:
#              Date                                             Review Score  \
# 0    9 March 2019  The Departed is one of the rare cases when the...     9
# 1  2 October 2006  Now I know that 'The Departed' is based off of...    10
# 2    26 June 2019  When veteran director Martin Scorsese walked u...     9
# 3  3 October 2006  Please don't make negative comments like some ...    10
# 4  7 October 2006  Just came back from watching the movie so it's...     5
#
#                                      Title
# 0  The Departed - Il bene e il male (2006)
# 1  The Departed - Il bene e il male (2006)
# 2  The Departed - Il bene e il male (2006)
# 3  The Departed - Il bene e il male (2006)
# 4  The Departed - Il bene e il male (2006)

# %% [markdown]
# <br></br>
# ## [3.4 Concat](#3.4)

# %% [markdown]
# <font size=3>
#
# Creati i singoli dataset si procede con l'unione. In pandas è presente la funzione `concat` che permette di unire più dataset diversi, il comendo `axis=0` indica che devono essere aggiunte delle righe.

# %%
imdb_df = pd.concat([df, df2, df3, df4], axis=0)
# Out:
#                 Date                                             Review Score  \
# 0   16 November 2019  This is what cinema is supposed to be! Amazing...    10
# 1   20 November 2019  Rating 10/10 Inspired movie of the year. It is...    10
# 2   15 November 2019  I was at the Philadelphia Film center premiere...    10
# 3     31 August 2019  Just saw F v F at the Telluride Film Festival ...    10
# 4  10 September 2019  Biopics can be a hard sell at times. Whether y...     9
#
#                                   Title
# 0  Le Mans '66 - La grande sfida (2019)
# 1  Le Mans '66 - La grande sfida (2019)
# 2  Le Mans '66 - La grande sfida (2019)
# 3  Le Mans '66 - La grande sfida (2019)
# 4  Le Mans '66 - La grande sfida (2019)

# %% [markdown]
# <br></br>
# ## [3.5 File Save/Read](#3.5)

# %%
#imdb_df.to_csv('imdb_df.csv', sep='\t')
imdb_df = pd.read_csv("imdb_df.csv", delimiter='\t')

# %% [markdown]
# <br></br>
# <br></br>
# # [4. Scraping Titoli](#4)

# %% [markdown]
# <font size=3>
#
# In un secondo momento si è notato che il sito applica una geolocalizzazione automatica che non è modificabile per gli ospiti, ma si dovrebbe fare un login e cambiare la lingua nelle impostazioni. Questa seconda soluzioni non è percorribile in quanto il login tramite un browser gestito da un robot è vietato. <br></br>
# Nelle pagine con la lista dei film i titoli erano riportati con la geolocalizzazione e questo è stato il processo con cui sono stati salvati. L'alternativa è aprire la pagina principale del film e all'inizio è presente sia il titolo geolocalizzato sia il titolo originale. <br></br>
#
# Per ricavare i titoli originali viene creata una nuova funzione `movie_info2` che riprende per alcuni tratti quello già visto nella funzione `reviews`. I parametri in ingresso sono:
# * `url`: in questo caso, come verrà specificato in seguito, non si tratta di un url singolo ma di una lista di indirizzi, dove l'unica differnza è l'anno di riferimento. L'estrazione del titolo originale è una procedura che è molto più veloce rispetto all'identificazione e il salvataggio di centinaia di recensioni per un singolo film, quindi risulta fattibile l'utilizzo di una lista.
# * `title_list`: è la lista in cui sono salvati i titoli geolocalizzati, già ottenuti con la funzione precedente. Questi valori fungeranno da chiave il successivo merge.
# * `original_title_list`: come dice il nome è la lista in cui saranno salvati i titoli originali dei film.
#
# Il codice inizia con l'inizializzazione di un contatore `j` che servirà in seguito. Le operazioni svolte dalla funzione sono:
# * Prende volta per volta un url della lista in ingresso, viene impostato il browser per evitare di caricare le immagini nelle pagine e si apre una pagina sull'url inserito.
# * Si crea una lista in cui saranno inseriti i collegamenti ipertestuali che rimandano alla pagina principale di ogni film. Il ciclo for itera per tutti i $250$ film della pagina estraendo il nome (geolocalizzato) in modo identico a quello che era stato fatto in precedenza. Allo stesso modo vengono estratti gli url dei film ed inseriti nella lista.
# * Per questa procedura risulta più comodo aprire una nuova finestra che sarà chiusa solo alla fine delle operazioni e non volta per volta in quanto le informazioni da scaricare sono inferiori a quelle della prima funzione. Per ogni indirizzo ipertestuale si ottiene l'url per accedere alla pagina principale del film.
# * Aperta la pagina principale ci possono essere due casi: il titolo è effettivamente geolocalizzato, oppure il titolo non è stato tradotto ma (in questo caso in Italia) si utilizza sempre il titolo originale.
#     * Se il titolo è stato tradotto,allora è presente sotto al titolo geolocalizzato il titolo originale con l'aggiunta di '(original title)'
#     * Se il titolo non è stato tradotto, allora è presente un unico titolo.
# * Mediante la funzione `find_elements_by_partial_link_text` è possibile indicare al browser di identificare un oggetto nella pagina in cui compare un determinato testo, in questo caso quello che identifica la presenza di un titolo originale che differisce da quello geolocalizzato, ovvero '(original title)'. Se questo elemento non è presente si tratta quindi di un film il cui titolo non è stato tradotto. In caso contrario si procede con l'identifcazione dell'xpath di esso.
# * Nella lista dei titoli tradotto si aggiunge l'elemento trovato. Nel caso in cui il titolo non sia tradotto allora si deve far riferimento alla lista dei titoli ottenuti all'inizio del codice. A differenza della funzione `reviews` qua si effettua un ciclo for su diversi url, da qui l'esigenza di utilizzare un ulteriore contatore `j` per contare le iterazioni degli url e posizionare i titoli non tradotti correttamente nella lista.
#
# Una volta ottenuti i titoli di un determinato anno i due browser vengono chiusi e si procede con l'url successivo. La funzione ritorna come output la lista dei titoli originali e quelli tradotti.

# %%
def movie_info2(url, title_list, original_title_list):
    j = 0
    for url in url_list:
        firefox_profile = webdriver.FirefoxProfile()
        firefox_profile.set_preference('permissions.default.image', 2)
        firefox_profile.set_preference('dom.ipc.plugins.enabled.libflashplayer.so', 'false')
        movie = webdriver.Firefox(firefox_profile=firefox_profile, executable_path=r'D:/Scraping2/geckodriver.exe')
        movie.get(url)

        href_list = []
        for i in range(250):
            title = movie.find_element_by_xpath('/html/body/div[3]/div/div[2]/div[3]/div[1]/div/div[3]/div/div[' + str(i + 1) + ']/div[3]/h3/a')
            title2 = movie.find_element_by_xpath('/html/body/div[3]/div/div[2]/div[3]/div[1]/div/div[3]/div/div[' + str(i + 1) + ']/div[3]/h3/span[2]')

            title_list.append(title.text + ' ' + title2.text)

            xpath = '//*[@id="main"]/div/div[3]/div/div[' + str(i + 1) + ']/div[3]/h3/a'
            element = movie.find_element_by_xpath(xpath=xpath)
            href = element.get_attribute('href')
            href_list.append(href)

        movie2 = webdriver.Firefox(firefox_profile=firefox_profile, executable_path=r'D:/Scraping2/geckodriver.exe')
        for i in range(250):
            temp_url = href_list[i].split('?')
            movie2.get(temp_url[0])

            try:
                movie2.find_elements_by_partial_link_text("(original title)")
                original_title = movie2.find_element_by_xpath("/html/body/div[3]/div/div[2]/div[5]/div[1]/div/div/div[1]/div[2]/div/div[2]/div[2]/div[1]")
                if ("(original title)") not in original_title.text:
                    original_title_list.append(title_list[(i + 250*j)])
                else:
                    original_title_list.append(original_title.text)
            except (NoSuchElementException, ElementNotInteractableException):
                original_title_list.append("")
        j = j + 1
        movie2.quit()
        movie.quit()
    
    return(title_list, original_title_list)

# %% [markdown]
# <font size=3>
#
# Per creare gli url si fa riferimento a:
# * Un url di base
# * L'anno che viene creato tramite un ciclo for decrescente, partendo dall'anno più recente a quello più lontano. L'anno poi viene attaccato come stringa al mese e anno di inizio e fine ricerca che sono sempre fissi a $1$ gennaio e $31$ dicembre.
# * L'ultima parte dell'url è relativa al genere e al numero di film da visualizzare per anno.

# %%
url = 'https://www.imdb.com/search/title/?title_type=feature&release_date='
url_list = []
for i in range(2019, 2011, -1):
    url_list.append(url + str(i) + "-01-01," + str(i) + "-12-31&genres=drama&count=250")
print(url_list)
# Out:
# ['https://www.imdb.com/search/title/?title_type=feature&release_date=2019-01-01,2019-12-31&genres=drama&count=250', 'https://www.imdb.com/search/title/?title_type=feature&release_date=2018-01-01,2018-12-31&genres=drama&count=250', 'https://www.imdb.com/search/title/?title_type=feature&release_date=2017-01-01,2017-12-31&genres=drama&count=250', 'https://www.imdb.com/search/title/?title_type=feature&release_date=2016-01-01,2016-12-31&genres=drama&count=250', 'https://www.imdb.com/search/title/?title_type=feature&release_date=2015-01-01,2015-12-31&genres=drama&count=250', 'https://www.imdb.com/search/title/?title_type=feature&release_date=2014-01-01,2014-12-31&genres=drama&count=250', 'https://www.imdb.com/search/title/?title_type=feature&release_date=2013-01-01,2013-12-31&genres=drama&count=250', 'https://www.imdb.com/search/title/?title_type=feature&release_date=2012-01-01,2012-12-31&genres=drama&count=250']

# %%
title_list = []
original_title_list = []

# %% [markdown]
# <font size=3>
#
# Poiché si effettua un'iterazione su diversi url non è necessario richiamare più volte la funzione. <br></br>
# Durante la ricerca degli url si sono riscontrati dei problemi relativi a dei file locali, molto probabilmente legato al fatto che si è imposto al browser di non caricare le immagini e questo codice si ripeteva ogni volta che si passava ad un nuovo url. Nonostante gli errori mostrati a video il codice non si è interrotto, sono da interndesi più come dei warning, e i titoli sono stati salvati nelle liste senza problemi.

# %%
(title, original_title) = movie_info2(url=url_list,
                                      title_list=title_list,
                                      original_title_list=original_title_list)
# Out:
# [WinError 3] Impossibile trovare il percorso specificato: 'C:\\Users\\Hp\\AppData\\Local\\Temp\\tmpul9157do'
# [WinError 3] Impossibile trovare il percorso specificato: 'C:\\Users\\Hp\\AppData\\Local\\Temp\\tmpmf_gnd5f'
# [WinError 3] Impossibile trovare il percorso specificato: 'C:\\Users\\Hp\\AppData\\Local\\Temp\\tmp7tb9d8j6'
# [WinError 3] Impossibile trovare il percorso specificato: 'C:\\Users\\Hp\\AppData\\Local\\Temp\\tmpiaya8g39'
# [WinError 3] Impossibile trovare il percorso specificato: 'C:\\Users\\Hp\\AppData\\Local\\Temp\\tmp_ijssw4r'
# [WinError 3] Impossibile trovare il percorso specificato: 'C:\\Users\\Hp\\AppData\\Local\\Temp\\tmpng1n6i3_'
# [WinError 3] Impossibile trovare il percorso specificato: 'C:\\Users\\Hp\\AppData\\Local\\Temp\\tmp9lxrews9'
# [WinError 3] Impossibile trovare il percorso specificato: 'C:\\Users\\Hp\\AppData\\Local\\Temp\\tmpvvp191iu'

# %%
for el in title:
    print(el)
# Out:
# The Irishman (2019)
# Cena con delitto - Knives Out (2019)
# C'era una volta a... Hollywood (2019)
# Le Mans '66 - La grande sfida (2019)
# Joker (2019)
# La ragazze di Wall Street (2019)
# Un amico straordinario (2019)
# Parasite (2019)
# Midway (2019)
# Doctor Sleep (2019)
# Last Christmas (2019)
# Honey Boy (2019)
# 1917 (2019)
# 21 Bridges (2019)
# Un cavaliere per Natale (2019)
# It - Capitolo due (2019)
# Il re (I) (2019)
# Blue Story (2019)
# Il Re Leone (2019)
# The Lighthouse (I) (2019)
# Queen & Slim (2019)
# Avengers: Endgame (2019)
# Cats (2019)
# Gemini Man (2019)
# Lilli e il vagabondo (2019)
# Jojo Rabbit (2019)
# Piccole donne (2019)
# The Peanut Butter Falcon (2019)
# Storia di un matrimonio (2019)
# Richard Jewell (2019)
# The Report (I) (2019)
# Midsommar - Il villaggio dei dannati (I) (2019)
# Downton Abbey (2019)
# L'inganno perfetto (2019)
# The Courier (2019)
# Brittany non si ferma più (2019)
# Bombshell (2019)
# Dark Waters (2019)
# Dove la terra trema (2019)
# Il cardellino (2019)
# Panama Papers (I) (2019)
# Motherless Brooklyn - I segreti di una città (2019)
# Uncut Gems (2019)
# Rocketman (I) (2019)
# After (2019)
# Che fine ha fatto Bernadette? (2019)
# Harriet (I) (2019)
# Dolemite Is My Name (2019)
# Seberg (2019)
# El Camino: Il film di Breaking Bad (2019)
# Official Secrets (2019)
# Waves (I) (2019)
# I See You (II) (2019)
# Glass (2019)
# Danger Close: The Battle of Long Tan (2019)
# Un safari per Natale (2019)
# Attraverso i miei occhi (2019)
# Un uomo tranquillo (2019)
# Ad Astra (2019)
# Crawl - Intrappolati (2019)
# Ritratto della giovane in fiamme (2019)
# The Aeronauts (2019)
# Le regine del crimine (2019)
# 47 Meters Down: Uncaged (2019)
# The Farewell - Una bugia buona (I) (2019)
# Nell'erba alta (2019)
# The Mandela Effect (2019)
# La vita nascosta - Hidden Life (2019)
# Running with the Devil (2019)
# Dolor y gloria (2019)
# L'angelo del male - Brightburn (2019)
# Una famiglia al tappeto (2019)
# Ip Man 4 (2019)
# Atlantique (2019)
# Blinded by the Light - Travolto dalla musica (2019)
# I due Papi (2019)
# Ted Bundy - Fascino criminale (2019)
# Il diritto di opporsi (2019)
# Triple Frontier (2019)
# American Son (2019)
# Overcomer (2019)
# A un metro da te (2019)
# Serenity - L'isola dell'inganno (2019)
# Killerman (2019)
# E poi c'è Katherine (2019)
# Wounds (2019)
# Weathering with You (2019)
# Sorry We Missed You (2019)
# Little Joe (2019)
# Polar (I) (2019)
# Highwaymen - L'ultima imboscata (2019)
# The Wolf Hour (2019)
# Dov'è il mio corpo (2019)
# Don't Let Go (2019)
# The Informer - Tre secondi per sopravvivere (2019)
# L'arte della difesa personale (2019)
# Luce (2019)
# Il professore e il pazzo (2019)
# Cep Herkülü: Naim Süleymanoglu (2019)
# The Room (2019)
# Crown Vic (2019)
# Adithya Varma (2019)
# Judy (II) (2019)
# True History of the Kelly Gang (2019)
# Dronningen (2019)
# I Am Mother (2019)
# Zeroville (2019)
# The Dirt (2019)
# The Lodge (2019)
# Dopo il matrimonio (2019)
# The Cave (III) (2019)
# Tolkien (2019)
# Serpente a sonagli (2019)
# L'ufficiale e la spia (2019)
# Lucy in the Sky (2019)
# The Silence (II) (2019)
# Black and Blue (I) (2019)
# Judy & Punch (2019)
# La conseguenza (II) (2019)
# Hellaro (2019)
# Inherit the Viper (2019)
# Section 375 (2019)
# I miserabili (2019)
# Red Sea Diving (2019)
# Kaithi (2019)
# Clemency (2019)
# La vita invisibile di Euridice Gusmao (2019)
# Asuran (2019)
# The Shed (2019)
# The Kid (II) (2019)
# Chhichhore (2019)
# The Souvenir (2019)
# Enai Noki Paayum Thota (2019)
# Qua La Zampa - Un Amico È Per Sempre (2019)
# Dylda (2019)
# Light of My Life (2019)
# Un gioco da ragazzi - Monos (2019)
# The Bygone (2019)
# Radioflash (2019)
# The Personal History of David Copperfield (2019)
# Miss Bala (2019)
# Semper Fi (2019)
# Prassthanam (2019)
# Captive State (2019)
# Sye Raa Narasimha Reddy (2019)
# The Tax Collector (2019)
# Fisherman's Friends (2019)
# A Score to Settle (2019)
# The Intruder (I) (2019)
# The Friend (I) (2019)
# Mon frère (2019)
# And Then We Danced (2019)
# Waiting for the Barbarians (2019)
# Polaroid (I) (2019)
# The Last Black Man in San Francisco (2019)
# Curiosa (2019)
# Il traditore (2019)
# Atto di fede (I) (2019)
# Angel of Mine (2019)
# Proxima (2019)
# The Parts You Lose (2019)
# Secret Obsession (2019)
# Plus One (I) (2019)
# Red Devil (2019)
# Super 30 (2019)
# Submission (I) (2019)
# Un viaggio a quattro zampe (2019)
# Connect (2019)
# Lying and Stealing (2019)
# Shao nian de ni (2019)
# Sharon Tate - Tra incubo e realtà (2019)
# Ms. Purple (2019)
# Mr. Jones (2019)
# The Wandering Earth (2019)
# Pranaam (2019)
# Io (2019)
# Batla House (2019)
# The Mustang (2019)
# Das perfekte Geheimnis (2019)
# Art of Deception (2019)
# Yedinci Kogustaki Mucize (2019)
# The Painted Bird (2019)
# ANYA (2019)
# Kabir Singh (2019)
# Article 15 (2019)
# Nancy Drew e il passaggio segreto (2019)
# L'uomo senza gravità (2019)
# Il mostro di St. Pauli (2019)
# Pan deng zhe (2019)
# Scarpette rosse e i 7 nani (2019)
# Gully Boy (2019)
# Il ragazzo che catturò il vento (2019)
# Jesus Rolls - Quintana è tornato! (2019)
# Endings, Beginnings (2019)
# Synonymes (2019)
# Hala (2019)
# Adopt a Highway (2019)
# Bad Education (2019)
# The Long Home (2019)
# Ghost in the Graveyard (2019)
# Badla (2019)
# The Kill Team (2019)
# Changeland (2019)
# Dua Garis Biru (2019)
# Helen (V) (2019)
# Crypto (2019)
# The Warrior Queen of Jhansi (2019)
# Unplanned (I) (2019)
# Mickey and the Bear (2019)
# The Collini Case (2019)
# Super Deluxe (2019)
# The Sky Is Pink (2019)
# Migliori nemici (2019)
# Kim Ji-young: Born 1982 (2019)
# 2nd Chance for Christmas (2019)
# Il sole è anche una stella (2019)
# Palm Beach (2019)
# Guava Island (2019)
# Where We Go from Here (I) (2019)
# Berlin, I Love You (2019)
# Ordinary Love (2019)
# Theresa & Allison (2019)
# Bigil (2019)
# The Death of Dick Long (2019)
# La odisea de los giles (2019)
# Dreamland (I) (2019)
# Hors normes (2019)
# Le verità (2019)
# Panipat (2019)
# Uri: The Surgical Strike (2019)
# Elisa y Marcela (2019)
# Queen Marie of Romania (2019)
# Judgementall Hai Kya (2019)
# Sibyl (2019)
# Jangsa-ri 9.15 (2019)
# Stano (2019)
# Summer Night (2019)
# Never Grow Old (2019)
# Matthias et Maxime (2019)
# Ana (I) (2019)
# Low Tide (2019)
# Angelfish (2019)
# Moothon (2019)
# Poms (2019)
# Born a King (2019)
# Systemsprenger (2019)
# Balance, Not Symmetry (2019)
# Paddleton (2019)
# Sword of Trust (2019)
# L'intervention (2019)
# Bohemian Rhapsody (2018)
# Instant Family (2018)
# Freaks (2018)
# Il corriere - The Mule (2018)
# The Chaperone (2018)
# Hereditary: Le radici del male (2018)
# Green Book (2018)
# The Nightingale (I) (2018)
# La favorita (2018)
# La mia vita con John F. Donovan (2018)
# A Quiet Place: Un posto tranquillo (2018)
# Un piccolo favore (2018)
# A Star Is Born (2018)
# Crazy & Rich (2018)
# Creed II (2018)
# Vice - L'uomo nell'ombra (I) (2018)
# 7 sconosciuti a El Royale (2018)
# BlacKkKlansman (2018)
# Attacco a Mumbai - Una vera storia di coraggio (2018)
# Red Sparrow (2018)
# La ballata di Buster Scruggs (2018)
# Annientamento (2018)
# Destroyer (2018)
# A Million Little Pieces (2018)
# Maria regina di Scozia (2018)
# First Man - Il primo uomo (2018)
# Arctic (2018)
# Climax (I) (2018)
# Widows: Eredità criminale (2018)
# Millennium - Quello che non uccide (2018)
# Bird Box (2018)
# Nella tana dei lupi (2018)
# High Life (2018)
# Cafarnao - Caos e miracoli (2018)
# Skin (V) (2018)
# Cinquanta sfumature di rosso (2018)
# Friday's Child (2018)
# Peppermint - L'angelo della vendetta (2018)
# Roma (2018)
# La vita in un attimo (2018)
# Greta (2018)
# Aniara (2018)
# Outlaw King - Il re fuorilegge (2018)
# Beautiful Boy (I) (2018)
# I fratelli Sisters (2018)
# Bigger (2018)
# La casa di Jack (2018)
# Ricomincio da me (2018)
# Soldado (2018)
# Nomis (2018)
# Dragged Across Concrete (2018)
# Arrivederci professore (2018)
# Under the Silver Lake (2018)
# Benvenuti a Marwen (2018)
# Ophelia (I) (2018)
# Braven - Il coraggioso (2018)
# Burning - L'amore brucia (2018)
# Copia originale (2018)
# Replicas (2018)
# Un principe per Natale - Matrimonio reale (2018)
# Searching (III) (2018)
# Tutte le volte che ho scritto ti amo (2018)
# The Perfection (2018)
# Ritorno al Bosco dei 100 Acri (2018)
# Mid90s (2018)
# 12 Soldiers (2018)
# A proposito di Rose (2018)
# Il giustiziere della notte - Death Wish (2018)
# Border - Creature di confine (2018)
# We Have Always Lived in the Castle (2018)
# Una giusta causa (2018)
# Senza lasciare traccia (2018)
# Cocaine - La vera storia di White Boy Rick (2018)
# Se la strada potesse parlare (2018)
# L'isola dei cani (2018)
# Boy Erased - Vite cancellate (2018)
# Old Man & the Gun (2018)
# Tuo, Simon (2018)
# Il coraggio della verità - The Hate U Give (2018)
# Eighth Grade - Terza media (2018)
# L'uomo che uccise Don Chisciotte (2018)
# Prospect (2018)
# Hotel Artemis (2018)
# Doppia colpa (2018)
# Level 16 (2018)
# Mowgli - Il figlio della giungla (2018)
# Inganni online (2018)
# Il sole a mezzanotte - Midnight Sun (2018)
# Un affare di famiglia (2018)
# Kursk (2018)
# Resta con me (I) (2018)
# Voglio una vita a forma di me (2018)
# American Woman (2018)
# The Vanishing - Il Mistero del Faro (2018)
# Cold War (2018)
# Terminal (I) (2018)
# Apostolo (2018)
# Operation Finale (2018)
# Il club del libro e della torta di bucce di patata di Guernsey (2018)
# Charlie Says (2018)
# Blindspotting (2018)
# Colette (I) (2018)
# Il calendario di Natale (2018)
# Brian Banks (2018)
# Ying (2018)
# Stanlio e Ollio (2018)
# Vox Lux (2018)
# L'uomo che uccise Hitler e poi il Bigfoot (2018)
# Buttons (I) (2018)
# Durante la tormenta (2018)
# The Clovehitch Killer (2018)
# Red Joan (2018)
# Tully (2018)
# Wij (2018)
# Driven (I) (2018)
# Hold the Dark (2018)
# Non tutte le sciagure vengono dal cielo (2018)
# Juliet, Naked - Tutta un'altra musica (2018)
# Alpha - Un'amicizia forte come la vita (2018)
# Extinction (2018)
# American Kamasutra (2018)
# Anon (I) (2018)
# Don't Worry (2018)
# Tutti lo sanno (2018)
# The Cloverfield Paradox (2018)
# The Last Man (2018)
# Kin (I) (2018)
# Yip Man ngoi zyun: Cheung Tin Chi (2018)
# Van Gogh - Sulla soglia dell'eternità (2018)
# The Front Runner - Il vizio del potere (2018)
# Assassination Nation (2018)
# Ore 15:17 - Attacco al treno (2018)
# The Public (2018)
# Opera senza autore (2018)
# Black Mirror: Bandersnatch (2018)
# Book Club - Tutto può succedere (I) (2018)
# Billionaire Boys Club (2018)
# A Private War (2018)
# La fine (2018)
# Il colpevole - The Guilty (2018)
# Vita & Virginia (2018)
# Fahrenheit 451 (2018)
# Her Smell (2018)
# Tell It to the Bees (2018)
# Sobibor - La grande fuga (2018)
# 22 luglio (2018)
# Unsane (2018)
# La sirenetta - The Little Mermaid (2018)
# Galveston (2018)
# Dogman (2018)
# The Titan (2018)
# Darkest Minds (2018)
# Gotti - Il primo padrino (2018)
# Maria Maddalena (2018)
# Rapina a Stoccolma (I) (2018)
# Ben Is Back (2018)
# The Outsider (I) (2018)
# Lords of Chaos (2018)
# Summer of 84 (2018)
# An Acceptable Loss - Decisione estrema (2018)
# The Catcher Was a Spy (2018)
# King of Thieves (2018)
# Destinazione matrimonio (2018)
# Truffatori in erba (2018)
# Wildlife (2018)
# Ladies in Black (2018)
# Un viaggio indimenticabile (2018)
# La vedova Winchester (2018)
# La diseducazione di Cameron Post (2018)
# Fast Color (2018)
# Rust Creek (2018)
# City of Lies - L'ora della verità (2018)
# Wildling (2018)
# American Animals (2018)
# Ogni giorno (2018)
# Girl (II) (2018)
# Spell (I) (2018)
# Una canzone per mio padre (2018)
# A Vigilante (2018)
# Ballon (2018)
# La casa delle bambole - Ghostland (2018)
# The Tale (2018)
# Nureyev - The White Crow (2018)
# Per sempre la mia ragazza (2018)
# Only You (2018)
# Grazie a dio (2018)
# Örök tél (2018)
# Every Other Holiday (2018)
# Lez Bomb (2018)
# Farming (2018)
# Da xiang xi di er zuo (2018)
# Final Score (2018)
# Gloria Bell (2018)
# Trautmann (2018)
# Lontano da qui (2018)
# The Quake - Il terremoto del secolo (2018)
# Cold Brook (2018)
# L'albero dei frutti selvatici (2018)
# Dark Hall (2018)
# Alex Strangelove (2018)
# Christmas Harmony (2018)
# Casa Shakespeare (2018)
# Teen Spirit - A un passo dal sogno (2018)
# Diqiu zuihou de yewan (2018)
# Duck Butter (2018)
# Paziente Zero (I) (2018)
# The Mountain (II) (2018)
# Between Worlds (2018)
# Eerie (2018)
# Giant Little Ones (2018)
# Ashes in the Snow (2018)
# K.G.F: Chapter 1 (2018)
# Calibre (2018)
# Alla fine ci sei tu (2018)
# Zero (III) (2018)
# Private Life (2018)
# Sierra Burgess è una sfigata (2018)
# What Death Leaves Behind (2018)
# L'ospite (2018)
# Lizzie (2018)
# Trial by Fire (I) (2018)
# Possum (2018)
# Geetha Govindam (2018)
# La donna dello scrittore (I) (2018)
# 96 (II) (2018)
# L'angelo (2018)
# Le jeu (2018)
# The Party's Just Beginning (2018)
# Una stagione da ricordare (2018)
# Backtrace (2018)
# Black Water (2018)
# Occupation (2018)
# Entebbe (2018)
# Oro verde - C'era una volta in Colombia (2018)
# Support the Girls (2018)
# Kickboxer: Retaliation (2018)
# Holiday (I) (2018)
# Black '47 (2018)
# The Golem (2018)
# Little Women (2018)
# Il fotografo di Mauthausen (2018)
# Acts of Violence (2018)
# Pilgrim (2018)
# Loro (2018)
# Lazzaro felice (2018)
# Living Space (2018)
# Burden (I) (2018)
# Summer '03 (2018)
# Traffik (2018)
# Damsel (I) (2018)
# Blade Runner 2049 (2017)
# Chiamami col tuo nome (2017)
# The Greatest Showman (2017)
# La fratellanza (2017)
# Logan - The Wolverine (2017)
# Dunkirk (2017)
# A Beautiful Day - You Were Never Really Here (2017)
# Wonder (I) (2017)
# Tre manifesti a Ebbing, Missouri (2017)
# Baby Driver - Il genio della fuga (2017)
# Assassinio sull'Orient Express (2017)
# Madre! (2017)
# Lady Bird (2017)
# La forma dell'acqua - The Shape of Water (2017)
# Downsizing - Vivere alla grande (2017)
# Edison - L'uomo che illuminò il mondo (2017)
# Fire Squad - Incubo di fuoco (2017)
# L'uomo di neve (2017)
# Molly's Game (2017)
# L'ora più buia (2017)
# Okja (2017)
# Good Time (2017)
# Il gioco di Gerald (2017)
# Tonya (2017)
# Papillon (I) (2017)
# The Disaster Artist (2017)
# I segreti di Wind River (2017)
# King Arthur: Il potere della spada (2017)
# Il filo nascosto (2017)
# Il sacrificio del cervo sacro (2017)
# Cinquanta sfumature di nero (2017)
# La truffa dei Logan (2017)
# The Post (2017)
# Sempre amici (2017)
# Hostiles: Ostili (2017)
# Ghost in the Shell (2017)
# 2 gran figli di... (2017)
# La terra di Dio (2017)
# The War - Il pianeta delle scimmie (2017)
# Morto Stalin, se ne fa un altro (2017)
# Dickens: L'uomo che inventò il Natale (2017)
# End of Justice - Nessuno è innocente (2017)
# Seven Sisters (2017)
# 47 Metri (2017)
# Tutti i soldi del mondo (2017)
# 1922 (2017)
# The Big Sick: Il matrimonio si può evitare, l'amore no (2017)
# The Meyerowitz Stories (New and Selected) (2017)
# Gifted - Il dono del talento (2017)
# Blue My Mind - Il segreto dei miei anni (2017)
# Un sogno chiamato Florida (2017)
# Il viaggio delle ragazze (2017)
# Qua la zampa! (2017)
# Suburbicon (2017)
# Codice Unlocked (I) (2017)
# L'inganno (2017)
# War Machine (2017)
# The Circle (I) (2017)
# Newness (2017)
# Il castello di vetro (2017)
# Oltre la notte (2017)
# Disobedience (2017)
# How to Be a Latin Lover (2017)
# Flatliners: Linea mortale (2017)
# Flower (I) (2017)
# Cell Block 99: Nessuno può fermarmi (2017)
# Death Note: Il quaderno della morte (I) (2017)
# Storia di un fantasma (2017)
# T2 Trainspotting (2017)
# First Reformed - La creazione a rischio (2017)
# Three Christs (2017)
# Detroit (2017)
# Jungle (I) (2017)
# Mudbound (2017)
# Una preghiera prima dell'alba (2017)
# 40 sono i nuovi 20 (2017)
# My Friend Dahmer (2017)
# Amiche di sangue (2017)
# La genesi di Wonder Woman (2017)
# Amar (2017)
# Ingrid va a ovest (2017)
# Hangman - Il gioco dell'impiccato (II) (2017)
# The Square (2017)
# Lo spazio che ci unisce (I) (2017)
# Shaadi Mein Zaroor Aana (2017)
# Cargo (I) (2017)
# Hot Summer Nights (2017)
# Fino all'osso (I) (2017)
# Submergence (2017)
# Caccia al 12° uomo (2017)
# L'ultima discesa (2017)
# Mistero a Crooked House (2017)
# Prima di domani (2017)
# La ruota delle meraviglie (2017)
# Der Hauptmann (2017)
# The Wife - Vivere nell'ombra (I) (2017)
# Ghost Stories (I) (2017)
# I Kill Giants (2017)
# Loving Vincent (2017)
# Castello di sabbia (2017)
# All Eyez on Me (2017)
# La ragazza dei tulipani (2017)
# Borg McEnroe (2017)
# I Don't Feel at Home in This World Anymore. (2017)
# Vittoria e Abdul (2017)
# Song to Song (I) (2017)
# The Shack (I) (2017)
# Thelma (2017)
# Ogni tuo respiro (I) (2017)
# Corpo e anima (2017)
# Stronger - Io sono più forte (I) (2017)
# Aftermath - La vendetta (IV) (2017)
# Wish upon (2017)
# La casa dei libri (2017)
# Il libro di Henry (2017)
# Per primo hanno ucciso mio padre (2017)
# La battaglia dei sessi (2017)
# Shimmer Lake (2017)
# Il domani tra di noi (2017)
# Mary Shelley - Un amore immortale (2017)
# The Ring 3 (2017)
# Marrowbone (2017)
# La voce della pietra (2017)
# Hunter's Prayer - In fuga (2017)
# My Days of Mercy (2017)
# 6 Days (I) (2017)
# Vi presento Christopher Robin (2017)
# The Only Living Boy in New York (2017)
# Noi siamo tutto (2017)
# Bullet Head (2017)
# Pin Cushion (2017)
# Beast (III) (2017)
# The Bye Bye Man (2017)
# La scoperta (I) (2017)
# Diverso come me (2017)
# Indian Horse (2017)
# Kidnap (2017)
# The Pirates of Somalia (2017)
# L'amore criminale (II) (2017)
# You Get Me (2017)
# Berlin Syndrome - In Ostaggio (2017)
# La signora dello zoo di Varsavia (2017)
# Ayla: The Daughter of War (2017)
# Loveless (2017)
# Last Flag Flying (2017)
# All Inclusive (2017)
# The Vanishing of Sidney Hall (2017)
# Columbus (2017)
# La donna più odiata d'America (2017)
# Beach Rats (2017)
# Marcia per la libertà (2017)
# Tavolo 19 (2017)
# The Silent Man (2017)
# The Wall (II) (2017)
# Escobar - Il fascino del male (2017)
# Hagazussa (2017)
# Lucky (I) (2017)
# Chesil Beach - Il segreto di una notte (2017)
# Sweet Virginia (2017)
# Unicorn Store (2017)
# Arjun Reddy (2017)
# Bushwick (2017)
# Kings (2017)
# The Rider - Il sogno di un cowboy (2017)
# I Am Not a Witch (2017)
# Sergente Rex (2017)
# Super Dark Times (2017)
# Tutto ciò che voglio (2017)
# Quello che non so di lei (I) (2017)
# Trafficked (2017)
# Inconceivable (2017)
# La stanza delle meraviglie (2017)
# Rachel (2017)
# Appuntamento al parco (2017)
# Journey's End (I) (2017)
# Euphoria (I) (2017)
# F*&% the Prom (2017)
# Doppio amore (2017)
# Lo scandalo Kennedy (2017)
# Il tenente ottomano (2017)
# Pieles (2017)
# Churchill (2017)
# Palm Swings (2017)
# Brad's Status (2017)
# American Satan (2017)
# Una pericolosa ossessione (2017)
# Tuntematon sotilas (2017)
# Forget About Nick (2017)
# Attraction (2017)
# Zama (2017)
# Walking Out (I) (2017)
# Le stelle non si spengono a Liverpool (2017)
# Bad Day for the Cut (2017)
# Dismissed (2017)
# I racconti di Parvana - The Breadwinner (2017)
# The Yellow Birds (2017)
# The Party (I) (2017)
# Woman Walks Ahead (2017)
# L'immortale (2017)
# Renegades: Commando d'assalto (2017)
# Vendetta finale (2017)
# Le nostre anime di notte (2017)
# Attacco alla Verità (2017)
# Operazione S.M.A.R.T. - Senza tregua (2017)
# The Maus (2017)
# Desearás al hombre de tu hermana (2017)
# Thumper (2017)
# Submission (2017)
# Singularity (I) (2017)
# Thank You for Your Service (I) (2017)
# The Lovers - Ritrovare l'amore (I) (2017)
# My Little Pony: Il film (2017)
# Princess Cyd (2017)
# The Year of Spectacular Men (2017)
# La scelta (2017)
# Happy End (2017)
# A taxi driver (2017)
# The Hero (I) (2017)
# Picture of Beauty (2017)
# Kodachrome (2017)
# The Children Act - Il verdetto (2017)
# Chalard games goeng (2017)
# L'assassina - The Villainess (2017)
# The Lodgers - Non infrangere le regole (2017)
# Billy Boy (I) (2017)
# Rebel in the Rye (2017)
# Small Crimes (2017)
# Vendetta: Una storia d'amore (2017)
# Soleil battant (2017)
# I Love You, Daddy (2017)
# Il palazzo del Viceré (2017)
# Freak Show (2017)
# Brigsby Bear (2017)
# The Place (2017)
# Pyewacket (2017)
# M.F.A. (2017)
# Breath (I) (2017)
# Tyler Perry's Boo 2! A Madea Halloween (2017)
# Zwodniczy urok (IV) (2017)
# The Jade Pendant (2017)
# Charley Thompson (2017)
# The Dinner (I) (2017)
# Dog Years (I) (2017)
# Terre selvagge (II) (2017)
# Blame (I) (2017)
# Patto d'amore (I) (2017)
# Hostile (I) (2017)
# Gemini (II) (2017)
# November (2017)
# Hindi Medium (2017)
# La battaglia di Hacksaw Ridge (2016)
# Silence (I) (2016)
# La La Land (I) (2016)
# Io prima di te (2016)
# Moonlight (I) (2016)
# Arrival (II) (2016)
# Animali notturni (2016)
# Your Name. (2016)
# Miss Peregrine - La casa dei ragazzi speciali (2016)
# La ragazza del treno (I) (2016)
# Mademoiselle (2016)
# Il diritto di contare (2016)
# The Legend of Tarzan (2016)
# The Accountant (2016)
# The Escort (IV) (2016)
# Hell or High Water (II) (2016)
# Captain Fantastic (2016)
# Passengers (I) (2016)
# 13 Hours: The Secret Soldiers of Benghazi (2016)
# Manchester by the Sea (2016)
# La quinta onda (2016)
# Below Her Mouth (2016)
# American Honey (2016)
# Lion - La strada verso casa (2016)
# Trafficanti (2016)
# Inferno (I) (2016)
# 10 Cloverfield Lane (2016)
# Ben-Hur (2016)
# L'ultima tempesta (2016)
# Ave, Cesare! (2016)
# Il libro della giungla (2016)
# Civiltà perduta (2016)
# 17 anni (e come uscirne vivi) (2016)
# Collateral Beauty (2016)
# Dangal (2016)
# Sully (2016)
# Snowden (2016)
# Selvaggi in fuga (2016)
# Criminal (2016)
# Miss Sloane - Giochi di potere (2016)
# Paradise Beach: Dentro l'incubo (2016)
# Babbo bastardo 2 (2016)
# Il cacciatore e la regina di ghiaccio (2016)
# The Bad Batch (2016)
# Brimstone (2016)
# Swiss Army Man - Un amico multiuso (2016)
# The Founder (2016)
# Paterson (2016)
# Dark crimes (2016)
# Deepwater: Inferno sull'oceano (2016)
# Nerve (I) (2016)
# Allied: Un'ombra nascosta (2016)
# Single ma non troppo (2016)
# Colossal (2016)
# Le donne della mia vita (2016)
# Il drago invisibile (2016)
# Blood Father (2016)
# Boston: Caccia all'uomo (2016)
# La forma della voce (2016)
# Lights Out - Terrore nel buio (II) (2016)
# Midnight Special (2016)
# Sing Street (2016)
# La scelta - The Choice (I) (2016)
# L'amore oltre la guerra (2016)
# Jackie (V) (2016)
# Free State of Jones (2016)
# Café Society (2016)
# Sette minuti dopo la mezzanotte (2016)
# The Promise (II) (2016)
# Florence (2016)
# Io, Daniel Blake (2016)
# La cura dal benessere (2016)
# Raw - Una cruda verità (2016)
# Billy Lynn: Un giorno da eroe (2016)
# Barriere (2016)
# La ragazza che sapeva troppo (2016)
# La legge della notte (2016)
# Somnia (2016)
# Fallen (II) (2016)
# Personal Shopper (2016)
# USS Indianapolis (2016)
# Gold - La grande truffa (I) (2016)
# White Girl (2016)
# La battaglia di Jadotville (2016)
# Batman: The Killing Joke (2016)
# Money Monster - L'altra faccia del denaro (2016)
# Perfetti sconosciuti (2016)
# Bridget Jones's Baby (2016)
# Hands of Stone (2016)
# Io sono vendetta (2016)
# Imperium (2016)
# Nell'ombra di un delitto (III) (2016)
# La luce sugli oceani (2016)
# Montagna II (2016)
# Miracoli dal cielo (2016)
# Elle (I) (2016)
# La rivoluzione di Charlie (2016)
# This Beautiful Fantastic (2016)
# Crouching Tiger, Hidden Dragon: Sword of Destiny (2016)
# The Infiltrator (2016)
# Lady Macbeth (2016)
# 93 Days (2016)
# Ouija: L'origine del male (2016)
# LBJ (2016)
# Almost Christmas - Vacanze in famiglia (2016)
# Conspiracy - La Cospirazione (2016)
# Come and Find Me (2016)
# Chiudi gli occhi (2016)
# Vi Presento Toni Erdmann (2016)
# Bleed - Più forte del destino (2016)
# The Comedian (2016)
# Frantz (2016)
# Mother's Day (I) (2016)
# Altruisti si diventa (2016)
# Genius (2016)
# The Young Offenders (2016)
# Tempo limite (2016)
# Mr. Church (2016)
# Bastille Day - Il colpo del secolo (2016)
# Shin Godzilla (2016)
# Aspettando il re (2016)
# Brain on Fire (2016)
# Cell (I) (2016)
# New York Academy - Freedance (2016)
# Julieta (2016)
# L'eccezione alla regola (2016)
# Kickboxer - La vendetta del guerriero (2016)
# The Good Neighbor (2016)
# Miss Stevens (2016)
# Be Somebody (2016)
# Bad Girl (II) (2016)
# Dear Zindagi (2016)
# A Dark Song (2016)
# Wish for Christmas (2016)
# Loving - L'amore deve nascere libero (2016)
# Lavender (I) (2016)
# Osiride - Il 9° pianeta (2016)
# I.T. - Una mente pericolosa (2016)
# Conspiracy of Faith - Il messaggio nella bottiglia (2016)
# Out of Love (2016)
# American Pastoral (2016)
# Sotto l'ombra (2016)
# Race - Il colore della vittoria (I) (2016)
# Whiskey Tango Foxtrot (2016)
# Una doppia verità (2016)
# Mashina lyubvi (2016)
# Teenage Cocktail (2016)
# Quando un padre (2016)
# A spasso con Bob (2016)
# L'ora più bella (2016)
# La región salvaje (2016)
# Sadie (2016)
# Mine (II) (2016)
# Il duello (I) (2016)
# Maudie: Una vita a colori (2016)
# King Cobra (2016)
# Il traditore tipo (2016)
# Buster's Mal Heart (2016)
# Amore e inganni (2016)
# Good Kids (I) (2016)
# Il cliente (2016)
# Joker (2016)
# È solo la fine del mondo (2016)
# The Last King (2016)
# Sugar Mountain (2016)
# Viking (2016)
# Hounds of Love (2016)
# Il segreto (2016)
# Manhattan Nocturne (2016)
# Una (2016)
# La bottega del barbiere 3 (2016)
# La verità negata (II) (2016)
# The Intervention (I) (2016)
# Pink (III) (2016)
# Il viaggio - The Journey (III) (2016)
# Gantz: O (2016)
# Blue Jay (I) (2016)
# The Eyes of My Mother (2016)
# The Birth of a Nation - Il risveglio di un popolo (2016)
# The Monster (2016)
# I corrotti - The Trust (2016)
# Indignazione (2016)
# The Hollars (2016)
# A United Kingdom: L'amore che ha cambiato la storia (2016)
# The Pass (2016)
# Vicolo cieco (2016)
# Una vita da gatto (I) (2016)
# Handsome Devil (2016)
# L'impero delle ombre (2016)
# Quando l'amore si spezza (2016)
# Don't Think Twice (2016)
# Goat (2016)
# Risorto (2016)
# Katie Says Goodbye (2016)
# Certain Women (2016)
# Brotherhood (I) (2016)
# Shut In (I) (2016)
# XOXO (2016)
# Tommy's Honour (2016)
# Knives Out (2016)
# Il tuo ultimo sguardo (2016)
# Queen of Katwe (2016)
# Wakefield - Nascosto nell'ombra (2016)
# Bruce Lee - La grande sfida (2016)
# Die Mitte der Welt (2016)
# In Dubious Battle - Il coraggio degli ultimi (2016)
# The Drowning (2016)
# Christine (2016)
# Nowhereland (2016)
# Other People (I) (2016)
# Lettere da Berlino (2016)
# Aquarius (I) (2016)
# Trapped (XVII) (2016)
# The Thinning (2016)
# Kingsglaive: Final Fantasy XV (2016)
# Tallulah (2016)
# The Bleeder (2016)
# Lady Bloodfight (2016)
# Despite the Falling Snow (2016)
# La ragazza nella scatola (2016)
# Arès (2016)
# Mei ren yu (2016)
# Headshot (II) (2016)
# Barry (II) (2016)
# Agnus Dei (2016)
# Boo! A Madea Halloween (2016)
# I'm Not Ashamed (2016)
# The Disappointments Room (2016)
# Fan (I) (2016)
# A Quiet Passion (2016)
# First Girl I Loved (2016)
# L'uragano Bianca (2016)
# Famiglia all'improvviso - Istruzioni non incluse (2016)
# Antiporno (2016)
# Sangue nella bocca (2016)
# On the Milky Road: Sulla Via Lattea (2016)
# Planetarium (2016)
# Carrie Pilby (2016)
# Mothers and Daughters (2016)
# The Hollow Point (2016)
# La mia vita da zucchina (2016)
# Riphagen (2016)
# The Confirmation (2016)
# Shangri-La Suite (2016)
# The Receptionist (II) (2016)
# Pelé (2016)
# The Model (I) (2016)
# Sanam Teri Kasam (2016)
# Distant Vision (2016)
# In questo angolo di mondo (2016)
# Love (II) (2015)
# Revenant - Redivivo (2015)
# The Witch - Vuoi ascoltare una favola? (2015)
# Inside Out (I) (2015)
# The Hateful Eight (2015)
# Cenerentola (I) (2015)
# Cinquanta sfumature di grigio (2015)
# Knock Knock (I) (2015)
# La grande scommessa (2015)
# Sopravvissuto - The Martian (2015)
# Room (I) (2015)
# Sicario (2015)
# Il caso Spotlight (I) (2015)
# The Lobster (2015)
# Legend (I) (2015)
# Fantastic 4 - I fantastici quattro (2015)
# Carol (2015)
# The Invitation (I) (2015)
# Il segreto dei suoi occhi (2015)
# Krampus: Natale non è sempre Natale (I) (2015)
# Focus - Niente è come sembra (II) (2015)
# Creed - Nato per combattere (II) (2015)
# Bone Tomahawk (2015)
# Il viaggio di Arlo (2015)
# The Danish Girl (2015)
# La risposta è nelle stelle (2015)
# Lo stagista inaspettato (I) (2015)
# San Andreas (2015)
# Il ponte delle spie (2015)
# True Story (I) (2015)
# Black Mass - L'ultimo gangster (2015)
# Un disastro di ragazza (2015)
# Southpaw - L'ultima sfida (2015)
# Humandroid (2015)
# Heart of the Sea - Le origini di Moby Dick (2015)
# Brooklyn (2015)
# Everest (2015)
# Adaline - L'eterna giovinezza (2015)
# McFarland (2015)
# A Bigger Splash (2015)
# Straight Outta Compton (2015)
# Crimson Peak (2015)
# Steve Jobs (2015)
# Bang Gang (une histoire d'amour moderne) (2015)
# Il sapore del successo (I) (2015)
# Regali da uno sconosciuto - The Gift (VI) (2015)
# Effetto Lucifero (2015)
# Premonitions (II) (2015)
# Sotto il cielo delle Hawaii (I) (2015)
# Knight of Cups (2015)
# Gravidanze pericolose (2015)
# Diario di una teenager (2015)
# Joy (I) (2015)
# We Are Your Friends (2015)
# Bus 657 (III) (2015)
# Zona d'ombra (2015)
# Via dalla pazza folla (2015)
# Joker - Wild Card (2015)
# Youth - La giovinezza (I) (2015)
# Irrational Man (2015)
# Child 44 - Il bambino n. 44 (2015)
# Magic Mike XXL (2015)
# Suffragette (2015)
# Quel fantastico peggior anno della mia vita (2015)
# Victor: La storia segreta del dottor Frankenstein (2015)
# Beasts of No Nation (2015)
# Ashby (2015)
# Eddie the Eagle - Il coraggio della follia (2015)
# SWOP: I sesso dipendenti (2015)
# Queen of the Desert (2015)
# L'ultima parola - La vera storia di Dalton Trumbo (2015)
# Macbeth (2015)
# Man Down (I) (2015)
# Città di carta (2015)
# Ip Man 3 (2015)
# The Walk (II) (2015)
# Colonia (2015)
# High-Rise: La rivolta (2015)
# Il diritto di uccidere (2015)
# L'uomo che vide l'infinito (2015)
# The 33 (2015)
# The Final Girls (2015)
# Anomalisa (2015)
# Dark Places - Nei luoghi oscuri (2015)
# The Dressmaker - Il diavolo è tornato (I) (2015)
# Dope: Follia e riscatto (2015)
# Demolition: Amare e vivere (2015)
# Nei miei sogni (2015)
# Circle (II) (2015)
# Mississippi Grind (2015)
# Run All Night - Una notte per sopravvivere (2015)
# Woman in Gold (2015)
# Christmas in the Smokies (2015)
# 6 Years (2015)
# Last Knights (2015)
# Krisha (2015)
# Spooks: Il bene supremo (2015)
# The Devil's Candy (2015)
# By the Sea (2015)
# Tamasha (2015)
# Il piccolo principe (2015)
# Into the Forest (2015)
# Equals (2015)
# Lui è tornato (2015)
# Victoria (II) (2015)
# Palme nella neve (2015)
# Sopravvissuti (2015)
# Jem e le Holograms (2015)
# Shingeki no kyojin (2015)
# Mistress America (2015)
# Bajirao Mastani (2015)
# Man Up (I) (2015)
# Racconto di Natale di una dogsitter (2015)
# Padri e figlie (2015)
# Snoopy & Friends - Il film dei Peanuts (2015)
# Holding the Man (2015)
# Ithaca (2015)
# Mr. Ove (2015)
# Il figlio di Saul (2015)
# Pay the Ghost - Il male cammina tra noi (2015)
# The Wave (2015)
# Slumlord (2015)
# Rosemont (2015)
# Return to Sender - Restituire al mittente (I) (2015)
# Troppo tardi (I) (2015)
# The Bronze: Sono la numero 1 (2015)
# Land of Mine - Sotto la sabbia (2015)
# Jenny's Wedding (2015)
# Bahubali: The Beginning (2015)
# 3 Generations: Una famiglia quasi perfetta (2015)
# Remember (I) (2015)
# The Gunman (2015)
# Benvenuti a ieri (2015)
# Mustang (2015)
# La canzone della vita - Danny Collins (2015)
# Passione senza regole (2015)
# Le armi del cuore (2015)
# Jane Got a Gun (2015)
# Un momento di follia (2015)
# Tra la terra e il cielo (2015)
# Drishyam (2015)
# Tangerine (2015)
# Ritorno al Marigold Hotel (2015)
# A spasso nel bosco (2015)
# Un angelo a Natale (2015)
# Contagious - Epidemia mortale (I) (2015)
# Bound (I) (2015)
# 45 anni (2015)
# Gansin (2015)
# La famiglia Fang (2015)
# Mon roi - Il mio re (2015)
# The Assassin (2015)
# La foresta dei sogni (2015)
# Affare fatto (I) (2015)
# I Saw the Light (2015)
# Tracers (2015)
# The End of the Tour - Un viaggio con David Foster Wallace (2015)
# Il racconto dei racconti (2015)
# Miss You Already (2015)
# L'attacco dei giganti - Il film - Parte 2: Le ali della libertà (2015)
# Abandoned (VI) (2015)
# Max (I) (2015)
# Shut In (2015)
# He Never Died (2015)
# My All-American (2015)
# Mr. Holmes - Il mistero del caso irrisolto (2015)
# Life (I) (2015)
# Suburra (2015)
# Dove eravamo rimasti (2015)
# Perfect Day (I) (2015)
# Il club (2015)
# El cadáver de Anna Fritz (2015)
# Swung (2015)
# La battaglia degli imperi - Dragon Blade (2015)
# Martyrs (2015)
# Steel (I) (2015)
# Mohammad Rasoolollah (2015)
# El abrazo de la serpiente (2015)
# Talvar (2015)
# All'ultimo voto (2015)
# The Lady in the Van (2015)
# Little Sister (2015)
# I (2015)
# Experimenter (2015)
# See You in Valhalla (2015)
# No kiss list: Va a finire che ti amo (2015)
# The Perfect Guy (I) (2015)
# Chi-Raq (2015)
# Un tranquillo weekend di mistero (2015)
# Much Loved (2015)
# 90 minuti in Paradiso (2015)
# The Program (II) (2015)
# I Am Michael (2015)
# Resistance - La battaglia di Sebastopoli (2015)
# Captive (II) (2015)
# Le verità sospese (2015)
# Córki dancingu (2015)
# Mojave (2015)
# Dum Laga Ke Haisha (2015)
# Ritorno alla vita (2015)
# Landmine Goes Click (2015)
# Stonewall (2015)
# Truth: Il prezzo della verità (2015)
# L'infanzia di un capo (2015)
# Il piano di Maggie - A cosa servono gli uomini (2015)
# Mucize (2015)
# Little Boy (2015)
# Manifesto (III) (2015)
# Badlapur (2015)
# Freeheld: Amore, giustizia, uguaglianza (2015)
# Anesthesia (2015)
# Una notte con la regina (2015)
# Bajrangi Bhaijaan (2015)
# Avouterie (2015)
# Rendez-Vous (2015)
# The Daughter (2015)
# The Intruders (I) (2015)
# The Meddler (2015)
# The Survivalist (2015)
# Visaaranai (2015)
# Zipper (2015)
# How to Plan an Orgy in a Small Town (2015)
# Miles Ahead (2015)
# Vendetta (2015)
# Il caso Freddy Heineken (2015)
# La belle saison (2015)
# Walt prima di Topolino (2015)
# Heidi (2015)
# Dil Dhadakne Do (2015)
# Mænd & høns (2015)
# They Look Like People (2015)
# Braqueurs (2015)
# Hello, My Name Is Doris (2015)
# Bare (I) (2015)
# Extinction - Sopravvissuti (2015)
# Fourth Man Out (2015)
# Segreti di famiglia (2015)
# Aap wong (2015)
# Delibal (2015)
# Il labirinto del Grizzly (2015)
# Backtrack (I) (2015)
# Terminus (2015)
# Hope Lost (2015)
# Strangerland (2015)
# One and Two (2015)
# Ma ma - Tutto andrà bene (2015)
# Hyena Road (2015)
# The Girl King (2015)
# Yr Ymadawiad (2015)
# Rams - Storia di due fratelli e otto pecore (2015)
# Interstellar (2014)
# L'amore bugiardo - Gone Girl (2014)
# Whiplash (2014)
# Ex Machina (2014)
# Fury (2014)
# Birdman o (L'imprevedibile virtù dell'ignoranza) (2014)
# American Sniper (2014)
# The Imitation Game (2014)
# Tusk (2014)
# Chef - La ricetta perfetta (2014)
# Predestination (I) (2014)
# Lo sciacallo - Nightcrawler (2014)
# Vizio di forma (2014)
# Babadook (2014)
# The Giver - Il mondo di Jonas (2014)
# La teoria del tutto (2014)
# Into the Woods (2014)
# Pompei (I) (2014)
# Boyhood (I) (2014)
# Colpa delle stelle (2014)
# Unbroken (I) (2014)
# Jack Ryan - L'iniziazione (2014)
# Noah (2014)
# Exodus - Dei e re (2014)
# Dracula Untold (2014)
# Annie - La felicità è contagiosa (2014)
# Sabotage (2014)
# Wild (I) (2014)
# Foxcatcher: Una storia americana (2014)
# Storie pazzesche (2014)
# The Judge (2014)
# Veronica Mars - Il film (2014)
# The Salvation (2014)
# This Is Where I Leave You (2014)
# Vampire Academy (2014)
# Apes Revolution - Il pianeta delle scimmie (2014)
# I Origins (2014)
# La preda perfetta (2014)
# Transcendence (I) (2014)
# Chi è senza colpa (2014)
# PK (2014)
# The Captive: Scomparsa (I) (2014)
# Cake (II) (2014)
# The Best of Me - Il meglio di me (2014)
# Still Alice (2014)
# Outcast - L'ultimo templare (I) (2014)
# Mommy (I) (2014)
# Amore, cucina e curry (2014)
# 1981: Indagine a New York (2014)
# Una folle passione (I) (2014)
# Jersey Boys (2014)
# 3 Days to Kill (2014)
# The Water Diviner (2014)
# Selma - La strada per la libertà (I) (2014)
# Big Eyes (I) (2014)
# Before We Go (I) (2014)
# Resta anche domani (2014)
# The Signal (2014)
# Suite Francese (2014)
# Draft Day (I) (2014)
# Love & Mercy (2014)
# Left Behind - La profezia (I) (2014)
# Giovani si diventa (2014)
# Storia d'inverno (2014)
# In ordine di sparizione (2014)
# Maps to the Stars (2014)
# Monuments Men (2014)
# The Rover (2014)
# Generazione perduta (2014)
# Posh (2014)
# Pride (I) (2014)
# The Homesman (2014)
# Tutto può accadere a Broadway (2014)
# Il regno d'inverno (2014)
# Un amore senza fine (2014)
# La regola del gioco (2014)
# St. Vincent (2014)
# Stonehearst Asylum (2014)
# Leviathan (2014)
# Men, Women & Children (2014)
# La spia - A Most Wanted Man (2014)
# Before I Go to Sleep (2014)
# The Gambler (III) (2014)
# La nostra vacanza in Scozia (2014)
# Backcountry (I) (2014)
# The Falling (2014)
# A Girl Walks Home Alone at Night (2014)
# In-gan-jung-dok (2014)
# '71 (2014)
# Appropriate Behavior (2014)
# Space Station 76 (2014)
# Heaven Knows What (2014)
# Le regole del caos (2014)
# Mr Cobbler e la bottega magica (2014)
# La bella e la bestia (2014)
# The One I Love (2014)
# Lost River (2014)
# Who Am I - Kein System ist sicher (2014)
# La canzone del mare (2014)
# La scomparsa di Eleanor Rigby - Loro (2014)
# Into the Storm (2014)
# Forza maggiore (2014)
# Million Dollar Arm (2014)
# Sils Maria (2014)
# Quando c'era Marnie (2014)
# Manglehorn (2014)
# Clown (2014)
# Addicted - Desiderio irresistibile (I) (2014)
# The Single Moms Club (2014)
# Chiedimi tutto (2014)
# Frank (II) (2014)
# Step Up All In (2014)
# Grace di Monaco (2014)
# Dimmi quando (2014)
# 7 giorni per cambiare (2014)
# La grande partita (2014)
# Twin Peaks: The Missing Pieces (2014)
# The Woman in Black 2 - L'angelo della morte (2014)
# Uniti per sempre (2014)
# X+Y (2014)
# Calvario (2014)
# Just Before I Go (2014)
# American Heist (2014)
# Madame Bovary (2014)
# The Duke of Burgundy (2014)
# Son of a Gun (2014)
# White Bird (2014)
# Beyond the Lights: Trova la tua voce (2014)
# Get on Up: La storia di James Brown (2014)
# God's Not Dead - Dio non è morto (2014)
# Wish I Was Here (2014)
# Black Sea (2014)
# Turner (2014)
# 5 to 7 (2014)
# The Good Lie (2014)
# Free the Nipple (2014)
# Escobar (2014)
# Starry Eyes (2014)
# Il bambino che è in me - Obvious Child (2014)
# Qualcosa di buono (2014)
# A piedi nudi (I) (2014)
# Il paradiso per davvero (2014)
# Camp X-Ray (2014)
# Ruth & Alex - L'amore cerca casa (2014)
# Hoje Eu Quero Voltar Sozinho (2014)
# Dear White People (2014)
# 99 Homes (2014)
# Due giorni, una notte (2014)
# L'ottava nota - Boychoir (2014)
# Diet of Sex (2014)
# Happy Christmas (2014)
# Comet (2014)
# Ossessione omicida (I) (2014)
# 90 minuti a New York (2014)
# Hector e la ricerca della felicità (2014)
# Non lasciarmi sola (2014)
# Welcome to Me (2014)
# Kid Cannabis (2014)
# Trash (I) (2014)
# The Humbling (2014)
# Il segreto del suo volto (II) (2014)
# Lap Dance (2014)
# Effie Gray - Storia di uno scandalo (2014)
# The Little Death (2014)
# Non buttiamoci giù (2014)
# The Tribe (2014)
# The Last Five Years (2014)
# I Vichinghi (2014)
# Cut Bank (2014)
# Durak (II) (2014)
# Northern Soul (2014)
# Haider (2014)
# The Christmas Dragon (2014)
# Miss Julie (2014)
# Natale con l'ex (2014)
# Caccia al mostro (2014)
# Il tempo di vincere (2014)
# Highway (I) (2014)
# Terremoto 10.0 (2014)
# Adult Beginners (2014)
# Queen & Country (2014)
# Il volo del falco (2014)
# Good Kill (2014)
# Ogni cosa è segreta (2014)
# Shelter (I) (2014)
# Road to Paloma (2014)
# Kajaki (2014)
# The Keeping Room (2014)
# Un piccione seduto su un ramo riflette sull'esistenza (2014)
# Il nemico invisibile (2014)
# Billy Elliot the Musical Live (2014)
# The Face of an Angel (2014)
# Motel (I) (2014)
# Bangalore Days (2014)
# Ti lascio la mia canzone (2014)
# Jackie & Ryan (2014)
# Teneramente folle (2014)
# Faults (2014)
# City 44 (2014)
# My Mistress (2014)
# Guida per la felicità (2014)
# Rosewater (2014)
# Mai così vicini (2014)
# Lo straniero della valle oscura - The Dark Valley (2014)
# Un ragionevole dubbio (2014)
# School Dance (2014)
# Not Cool (II) (2014)
# Le meraviglie (2014)
# Madam ppang-deok (2014)
# Date and Switch (2014)
# Animal - Il segreto della foresta (I) (2014)
# Viaggio verso la libertà (2014)
# Vonarstræti (2014)
# Life Partners (2014)
# Hide and Seek (I) (2014)
# The Forger - Il falsario (2014)
# Viharsarok (2014)
# Son of God (2014)
# Sorelle assassine (2014)
# Diamante nero (2014)
# Jack (I) (2014)
# Aspettando Alex (2014)
# Reach Me - La strada per il successo (2014)
# Hungry Hearts (2014)
# Mardaani (2014)
# Por un puñado de besos (2014)
# A Good Marriage (2014)
# Kaththi (2014)
# Anatomia di un amore visto (2014)
# Copenhagen (2014)
# Timbuktu (2014)
# Respire (2014)
# Solamente tu (2014)
# Magical Girl (2014)
# Yo soy la felicidad de este mundo (2014)
# Boulevard (2014)
# Loin des hommes (2014)
# Natt til 17. (2014)
# La famiglia Bélier (2014)
# Mary Kom (2014)
# L'impero e la gloria - Roaring Currents (2014)
# God's Pocket (2014)
# Gemma Bovery (2014)
# Paper Planes - Ai confini del cielo (I) (2014)
# God Help the Girl (2014)
# Reclaim - Prenditi ciò che è tuo (2014)
# Deadly Virtues: Love.Honour.Obey. (2014)
# Walking on Sunshine (2014)
# Blind (II) (2014)
# Black or White (2014)
# The Wolf of Wall Street (2013)
# Lei (2013)
# Snowpiercer (2013)
# Prisoners (2013)
# Il grande Gatsby (2013)
# Don Jon (2013)
# La vita di Adele (2013)
# Nymphomaniac - Vol. I (2013)
# American Hustle - L'apparenza inganna (2013)
# Questione di tempo (I) (2013)
# Rush (I) (2013)
# Under the Skin (I) (2013)
# 12 anni schiavo (2013)
# Prossima fermata Fruitvale Station (2013)
# Saving Mr. Banks (2013)
# Dallas Buyers Club (2013)
# Gravity (2013)
# I sogni segreti di Walter Mitty (2013)
# Effetti collaterali (I) (2013)
# Lone Survivor (2013)
# Locke (2013)
# Elysium (I) (2013)
# Il cacciatore di donne (2013)
# Nymphomaniac - Vol. II (2013)
# A proposito di Davis (2013)
# Sotto assedio - White House Down (2013)
# Gangster Squad (2013)
# Captain Phillips - Attacco in mare aperto (2013)
# Filth (I) (2013)
# Oldboy (2013)
# Solo Dio perdona (2013)
# Pain & Gain - Muscoli e denaro (2013)
# Solo gli amanti sopravvivono (2013)
# Two Mothers (2013)
# I segreti di Osage County (2013)
# Vicino a te non ho paura (I) (2013)
# Lovelace (2013)
# Il fuoco della vendetta - Out of the Furnace (2013)
# Lo sguardo di Satana - Carrie (2013)
# The Spectacular Now (2013)
# Stoker (2013)
# Before Midnight (2013)
# Short Term 12 (2013)
# The Counselor - Il procuratore (2013)
# C'era una volta un'estate (2013)
# Bling Ring (2013)
# Blue Jasmine (2013)
# 47 Ronin (2013)
# After Earth (2013)
# Tutto può cambiare (II) (2013)
# The Call (II) (2013)
# La migliore offerta (2013)
# Giovane e bella (2013)
# Il sosia - The Double (2013)
# Il grande match (2013)
# The Host (2013)
# Horns (2013)
# Redemption - Identità nascoste (I) (2013)
# 42 - La vera storia di una leggenda americana (2013)
# Beautiful Creatures - La sedicesima luna (2013)
# Avant l'hiver (2013)
# La grande bellezza (2013)
# Medicus (2013)
# Empire State (2013)
# All Is Lost - Tutto è perduto (2013)
# Blue Ruin (2013)
# The Lifeguard (2013)
# Un giorno come tanti (2013)
# The Butler - Un maggiordomo alla Casa Bianca (I) (2013)
# The Kings of Summer (2013)
# The Zero Theorem - Tutto è vanità (2013)
# Dead Man Down - Il sapore della vendetta (2013)
# Big Wedding (2013)
# Nebraska (2013)
# Man of Tai Chi (2013)
# Il giardino delle parole (2013)
# In trance (I) (2013)
# Romeo & Juliet (II) (2013)
# Snitch - L'infiltrato (I) (2013)
# Storia di una ladra di libri (2013)
# Giovani ribelli - Kill Your Darlings (2013)
# Last Vegas (2013)
# La ragazza del dipinto (2013)
# Si alza il vento (2013)
# Drinking Buddies - Amici di bevuta (2013)
# C'era una volta a New York (2013)
# Palo Alto (2013)
# Charlie Countryman deve morire (2013)
# Dietro i candelabri (2013)
# Afternoon Delight (2013)
# Angels sing - Un Natale tutto nuovo (2013)
# Venere in pelliccia (2013)
# Jobs (2013)
# Europa Report (2013)
# Ida (2013)
# Anna (VII) (2013)
# Drishyam (2013)
# CBGB (2013)
# Il quinto potere (2013)
# Concussion (2013)
# Killing Season (2013)
# The Canyons (2013)
# The Grandmaster (2013)
# A Teacher (2013)
# Joe (I) (2013)
# Parkland (2013)
# Il ribelle - Starred Up (2013)
# Non dico altro (2013)
# A Madea Christmas (2013)
# Instructions Not Included (2013)
# The Christmas Candle (2013)
# Delivery Man (2013)
# The Haunting in Connecticut 2: Ghosts of Georgia (2013)
# Upstream Color (2013)
# Io sono tu (2013)
# The Best Man Holiday (2013)
# Le due vie del destino (2013)
# Broken City (2013)
# Passione innocente (2013)
# Blood Ties - La legge del sangue (I) (2013)
# Diana - La storia segreta di Lady D (2013)
# La storia della principessa splendente (2013)
# Hours (2013)
# Third Person (2013)
# Philomena (2013)
# 7-beon-bang-ui seon-mul (2013)
# Vi (2013)
# Absolute Deception (2013)
# The Machine (I) (2013)
# Freier Fall (2013)
# Lunchbox (2013)
# Not Another Happy Ending (2013)
# Night Moves (2013)
# Il potere dei soldi (I) (2013)
# Feuchtgebiete (2013)
# We Are What We Are (2013)
# La scomparsa di Eleanor Rigby - Lei (2013)
# Mystery Road (2013)
# Molly Maxwell (2013)
# Devil's Knot - Fino a prova contraria (2013)
# 3096 Tage (2013)
# The Congress (2013)
# La scomparsa di Eleanor Rigby - Lui (2013)
# After the Dark (2013)
# G.B.F. (2013)
# Ugly (2013)
# The East (2013)
# Jimi: All Is by My Side (2013)
# Tom à la ferme (2013)
# Very Good Girls (2013)
# These Final Hours - 12 ore alla fine (2013)
# Are You Here (2013)
# Sunshine on Leith (2013)
# Fateful Findings (2013)
# Tracks - Attraverso il deserto (I) (2013)
# In Secret (2013)
# Salomé (2013)
# Phantom (I) (2013)
# Lo sconosciuto del lago (2013)
# Cate McCall - Il confine della verità (2013)
# Yeh Jawaani Hai Deewani (2013)
# Hawaii (I) (2013)
# Borgman (2013)
# The Truth About Emanuel (2013)
# Il passato (2013)
# The Invisible Woman (2013)
# Admission - Matricole dentro o fuori (2013)
# Dom Hemingway (2013)
# Tarzan (2013)
# Lad: A Yorkshire Story (2013)
# Stalingrad (2013)
# All Is Bright (2013)
# Bad Words (2013)
# Father and Son (2013)
# Adult World (2013)
# Mandela: Long Walk to Freedom (2013)
# Xi you: Xiang mo pian (2013)
# Temptation: Confessions of a Marriage Counselor (2013)
# The Look of Love (2013)
# I disertori - A Field in England (2013)
# Closed Circuit (2013)
# Mood Indigo - La schiuma dei giorni (2013)
# Sinsegye (2013)
# Raze (2013)
# Deseo (2013)
# Il tocco del peccato (2013)
# One Chance - L'opera della mia vita (2013)
# È difficile essere un dio (2013)
# The English Teacher (2013)
# Ashley (I) (2013)
# Tangerines - Mandarini (2013)
# Michael Kohlhaas (2013)
# Senza santi in paradiso (2013)
# La danza della realtà (2013)
# Madras Café (2013)
# Zulu (2013)
# Kamasutra 3D (2013)
# Un'allenatrice speciale (2013)
# Ruby Red (2013)
# La metà di un sole giallo (2013)
# As I Lay Dying (2013)
# Cheap Thrills (I) (2013)
# Goliyon Ki Rasleela Ram-Leela (2013)
# Christmas for a Dollar (2013)
# Fredda è la notte (2013)
# Geography Club (2013)
# Escape from Tomorrow (2013)
# Compulsion (I) (2013)
# Queen (2013)
# Walking with the Enemy (2013)
# Lo straordinario viaggio di T.S. Spivet (2013)
# Breakout - Weekend di paura (I) (2013)
# Lootera (I) (2013)
# I'm in Love with a Church Girl (2013)
# Moebius (2013)
# Kelebegin Rüyasi (2013)
# Rushlights (2013)
# Omar (2013)
# Contracted - Fase I (2013)
# Caníbal (2013)
# The Harvest (I) (2013)
# Gloria (II) (2013)
# The Pretty One (2013)
# Heatstroke (2013)
# The Turning (2013)
# It Felt Like Love (2013)
# Magic Magic (2013)
# Gods Behaving Badly (2013)
# Mister Morgan (2013)
# Bhaag Milkha Bhaag (2013)
# Free Ride (2013)
# Nasha (2013)
# Kai po che! (2013)
# Paradise - Viaggio a Las Vegas (I) (2013)
# Hooligans sotto copertura (2013)
# Ip Man: The Final Fight (2013)
# Police Story - Sotto controllo (2013)
# Grand Masti (2013)
# Crazy Kind of Love (2013)
# No somos animales (2013)
# Pleasure or Pain (2013)
# Battle of the Year - La vittoria è in ballo (2013)
# Málmhaus (2013)
# L'estate all'improvviso (2013)
# Goodbye World (2013)
# C.O.G. (2013)
# Life Inside Out (2013)
# A Single Shot (2013)
# Raanjhanaa (2013)
# Miss Violence (2013)
# End of Watch - Tolleranza zero (2012)
# Django Unchained (2012)
# Looper (2012)
# Les Misérables (2012)
# The Master (2012)
# The Twilight Saga: Breaking Dawn - Parte 2 (2012)
# Spring Breakers - Una vacanza da sballo (2012)
# Cloud Atlas (2012)
# Zero Dark Thirty (2012)
# Il lato positivo - Silver Linings Playbook (2012)
# Noi siamo infinito (2012)
# The Impossible (2012)
# Argo (2012)
# Il sospetto (2012)
# Lincoln (2012)
# Biancaneve e il cacciatore (2012)
# Rock of Ages (2012)
# Moonrise Kingdom - Una fuga d'amore (2012)
# Come un tuono (2012)
# Lawless (2012)
# Anna Karenina (I) (2012)
# Magic Mike (2012)
# Vita di Pi (2012)
# Frances Ha (2012)
# Cosmopolis (2012)
# The Iceman (2012)
# Flight (I) (2012)
# Hates - House at the End of the Street (2012)
# Chronicle (2012)
# Mud (2012)
# Cogan - Killing Them Softly (2012)
# Le belve (2012)
# La memoria del cuore (2012)
# Ho cercato il tuo nome (2012)
# Chroniques sexuelles d'une famille d'aujourd'hui (2012)
# Prigionieri del ghiaccio (I) (2012)
# Un sapore di ruggine e ossa (2012)
# Gangs of Wasseypur (2012)
# Che cosa aspettarsi quando si aspetta (2012)
# Stuck in Love. (2012)
# Tentazioni (ir)resistibili (2012)
# Lorax - Il guardiano della foresta (2012)
# Byzantium (2012)
# The Woman in Black (2012)
# On the Road (2012)
# Safety Not Guaranteed (2012)
# Biancaneve (I) (2012)
# Il fondamentalista riluttante (2012)
# The Sessions - Gli incontri (2012)
# A Perfect Ending (2012)
# Shark 3D (III) (2012)
# Clip (2012)
# Holy Motors (2012)
# Viaggio in paradiso (2012)
# To the Wonder (2012)
# Passion (2012)
# American Mary (2012)
# Amour (2012)
# The Words (2012)
# Royal Affair (2012)
# The First Time (I) (2012)
# Cercasi amore per la fine del mondo (2012)
# Fire with Fire (II) (2012)
# L'era glaciale 4 - Continenti alla deriva (2012)
# Act of Valor (2012)
# Excision (2012)
# Underworld - Il risveglio (2012)
# Di nuovo in gioco (2012)
# LOL - Pazza del mio migliore amico (2012)
# Step Up 4 Revolution 3D (2012)
# The Paperboy (2012)
# Smashed (2012)
# And While We Were Here (2012)
# Hitchcock (2012)
# Red Tails (2012)
# About Cherry (2012)
# Contraband (2012)
# Compliance (2012)
# Grandi speranze (2012)
# L'incredibile vita di Timothy Green (2012)
# Kon-Tiki (2012)
# Upside Down (I) (2012)
# Bez wstydu (2012)
# Broken - Una vita spezzata (IV) (2012)
# Re della terra selvaggia (2012)
# I bambini di Cold Rock (2012)
# Ruby Sparks (2012)
# Disconnect (I) (2012)
# Red Lights (2012)
# Bel Ami - Storia di un seduttore (2012)
# La regola del silenzio - The Company You Keep (2012)
# Chasing Mavericks - Sulla cresta dell'onda (2012)
# Alabama Monroe - Una storia d'amore (2012)
# Promised Land (2012)
# La frode (2012)
# Liberal Arts (2012)
# Wolf Children - Ame e Yuki i bambini lupo (2012)
# Freelancers (2012)
# The Courier (2012)
# Venuto al mondo (2012)
# Chained (I) (2012)
# B.A. Pass (2012)
# Molto rumore per nulla (I) (2012)
# Legami di sangue (2012)
# Qualcosa di straordinario (2012)
# Girls Against Boys (2012)
# Now Is Good (2012)
# Madea protezione testimoni (2012)
# Nella casa (2012)
# Barfi! (2012)
# La concubina (2012)
# Fast Girls (2012)
# Urla silenziose (I) (2012)
# Il matrimonio che vorrei (2012)
# National Theatre Live: All About Eve (2012)
# Laurence Anyways e il desiderio di una donna... (2012)
# Una bugia di troppo (I) (2012)
# Ginger & Rosa (2012)
# Una famiglia all'improvviso (2012)
# A Royal Weekend (2012)
# Separati innamorati (2012)
# Gayby (2012)
# Love Is All You Need (2012)
# Herutâ sukerutâ (2012)
# 28 Hotel Rooms (2012)
# La 'parte' degli angeli (2012)
# Jab Tak Hai Jaan (2012)
# Joyful Noise - Armonie del cuore (2012)
# The Sapphires (2012)
# Starlet (I) (2012)
# Tengo ganas de ti (2012)
# Hemel (2012)
# The Sweeney (2012)
# Shahid (2012)
# Robot & Frank (2012)
# The Battery (2012)
# Out in the Dark (2012)
# Dag (2012)
# Talaash (2012)
# Due vite (2012)
# Dark Tide (2012)
# Struck by Lightning (2012)
# Parto con mamma (2012)
# Not Fade Away (2012)
# Spike Island (2012)
# The Scapegoat (2012)
# Agneepath (2012)
# Marfa Girl (2012)
# It's Such a Beautiful Day (2012)
# The Seasoning House (2012)
# Ill Manors (2012)
# Private Peaceful (2012)
# Cristiada (2012)
# Berberian Sound Studio (2012)
# Generation Um... (2012)
# OMG: Oh My God! (2012)
# Quartet (2012)
# It's a Disaster (2012)
# Wish You Were Here (I) (2012)
# Offender (2012)
# Steekspel (2012)
# No - I giorni dell'arcobaleno (I) (2012)
# Good Deeds (2012)
# Quel che sapeva Maisie (2012)
# Pietà (2012)
# A qualsiasi prezzo (2012)
# Paradies: Liebe (2012)
# Rezeta (2012)
# Sparkle - La luce del successo (I) (2012)
# Berserk: L'epoca d'oro - Capitolo I - L'uovo del re dominatore (2012)
# El sexo de los ángeles (2012)
# La scelta di Barbara (I) (2012)
# Being Flynn (2012)
# Emperor (2012)
# Lore (2012)
# The Giant Mechanical Man (2012)
# Evangelion: 3.0 You Can (Not) Redo (2012)
# Atlas Shrugged II: The Strike (2012)
# Una ragazza a Las Vegas (2012)
# The Magic of Belle Isle (2012)
# Ernest & Célestine (2012)
# Nanban (2012)
# Little Thirteen (2012)
# Kiss of the Damned (2012)
# Girl in Progress (2012)
# Small Apartments (2012)
# Addio mia regina (2012)
# Kapringen (2012)
# Come la prima volta (2012)
# Una fragile armonia (2012)
# Red Hook Summer (2012)
# Sister (2012)
# Walking the Halls (2012)
# Student of the Year (2012)
# La bicicletta verde (2012)
# King Kelly (2012)
# Cocktail (2012)
# Kursk (2012)
# Oh Boy: Un caffè a Berlino (2012)
# Jayne Mansfield's Car - L'ultimo desiderio (2012)
# L'ipnotista (2012)
# Rurouni Kenshin (2012)
# Renoir (2012)
# Io e te (2012)
# The Comedy (2012)
# 6 Bullets (2012)
# Call Girl (2012)
# Chef (2012)
# La fille de nulle part (2012)
# Qualcuno da amare (2012)
# Jack & Diane (2012)
# The Door (I) (2012)
# Love Never Dies (II) (2012)
# The Kitchen (2012)
# Drug War (2012)
# Oltre le colline (2012)
# The Unspeakable Act (2012)
# Fetih 1453 (2012)
# Blancanieves (2012)
# 11 settembre 1683 (2012)
# Ship of Theseus (2012)
# Tensión sexual, Volumen 1: Volátil (2012)
# Post Tenebras Lux (2012)
# Doppio gioco (2012)
# The Rise (2012)
# El Gringo (2012)
# Cena tra amici (2012)
# Il marchio di sangue (2012)
# Bad Parents (2012)
# Ambrosia (I) (2012)
# Cleanskin (2012)
# StreetDance 2 (2012)
# Over Kanten (2012)
# Hannah Arendt (2012)
# Come una donna (2012)
# Nobody Walks (2012)
# Keep the Lights On (2012)
# Christmas Oranges (2012)
# Tabu (I) (2012)
# Foxfire - Ragazze cattive (2012)
# To Write Love on Her Arms (2012)
# Hello Herman (2012)
# An Oversimplification of Her Beauty (2012)
# Quando parla il cuore (2012)
# The Color of Time (II) (2012)
# Rufus (2012)
# Blood (I) (2012)
# Hoi-sa-won (2012)
# After (I) (2012)
# Found (III) (2012)

# %%
for el in original_title:
    print(el)
# Out:
# The Irishman (2019)
# Knives Out (original title)
# Once Upon a Time... in Hollywood (original title)
# Ford v Ferrari (original title)
# Joker (2019)
# Hustlers (original title)
# A Beautiful Day in the Neighborhood (original title)
# Gisaengchung (original title)
# Midway (2019)
# Doctor Sleep (2019)
# Last Christmas (2019)
# Honey Boy (2019)
# 1917 (2019)
# 21 Bridges (2019)
# The Knight Before Christmas (original title)
# It Chapter Two (original title)
# The King (original title)
# Blue Story (2019)
# The Lion King (original title)
# The Lighthouse (I) (2019)
# Queen & Slim (2019)
# Avengers: Endgame (2019)
#
# Gemini Man (2019)
# Lady and the Tramp (original title)
# Jojo Rabbit (2019)
#
# The Peanut Butter Falcon (2019)
# Marriage Story (original title)
# Richard Jewell (2019)
# The Report (I) (2019)
# Midsommar (original title)
# Downton Abbey (2019)
# The Good Liar (original title)
# The Courier (2019)
# Brittany Runs a Marathon (original title)
#
# Dark Waters (2019)
# Earthquake Bird (original title)
# The Goldfinch (original title)
# The Laundromat (original title)
# Motherless Brooklyn (original title)
# Uncut Gems (2019)
# Rocketman (I) (2019)
# After (2019)
# Where'd You Go, Bernadette (original title)
# Harriet (I) (2019)
# Dolemite Is My Name (2019)
# Seberg (2019)
# El Camino: A Breaking Bad Movie (original title)
# Official Secrets (2019)
# Waves (I) (2019)
# I See You (II) (2019)
# Glass (2019)
# Danger Close: The Battle of Long Tan (2019)
# Christmas in the Wild (original title)
# The Art of Racing in the Rain (original title)
# Cold Pursuit (original title)
# Ad Astra (2019)
# Crawl (original title)
# Portrait de la jeune fille en feu (original title)
# The Aeronauts (2019)
# The Kitchen (original title)
# 47 Meters Down: Uncaged (2019)
# The Farewell (original title)
# In the Tall Grass (original title)
#
# A Hidden Life (original title)
# Running with the Devil (2019)
# Dolor y gloria (2019)
# Brightburn (original title)
# Fighting with My Family (original title)
#
# Atlantique (2019)
# Blinded by the Light (original title)
# The Two Popes (original title)
# Extremely Wicked, Shockingly Evil and Vile (original title)
# Just Mercy (original title)
# Triple Frontier (2019)
# American Son (2019)
# Overcomer (2019)
# Five Feet Apart (original title)
# Serenity (original title)
# Killerman (2019)
# Late Night (original title)
# Wounds (2019)
# Tenki no ko (original title)
# Sorry We Missed You (2019)
# Little Joe (2019)
# Polar (I) (2019)
# The Highwaymen (original title)
# The Wolf Hour (2019)
# J'ai perdu mon corps (original title)
# Don't Let Go (2019)
# The Informer (original title)
# The Art of Self-Defense (original title)
# Luce (2019)
# The Professor and the Madman (original title)
# Cep Herkülü: Naim Süleymanoglu (2019)
# The Room (2019)
# Crown Vic (2019)
# Adithya Varma (2019)
# Judy (II) (2019)
# True History of the Kelly Gang (2019)
# Dronningen (2019)
# I Am Mother (2019)
# Zeroville (2019)
# The Dirt (2019)
# The Lodge (2019)
# After the Wedding (original title)
# The Cave (III) (2019)
# Tolkien (2019)
# Rattlesnake (original title)
# J'accuse (original title)
# Lucy in the Sky (2019)
# The Silence (II) (2019)
# Black and Blue (I) (2019)
# Judy & Punch (2019)
# The Aftermath (original title)
# Hellaro (2019)
# Inherit the Viper (2019)
# Section 375 (2019)
# Les misérables (original title)
# Operation Brothers (original title)
# Kaithi (2019)
# Clemency (2019)
# A Vida Invisível (original title)
# Asuran (2019)
# The Shed (2019)
# The Kid (II) (2019)
# Chhichhore (2019)
# The Souvenir (2019)
# Enai Noki Paayum Thota (2019)
# A Dog's Journey (original title)
# Dylda (2019)
# Light of My Life (2019)
# Monos (original title)
# The Bygone (2019)
# Radioflash (2019)
# The Personal History of David Copperfield (2019)
# Miss Bala (2019)
# Semper Fi (2019)
# Prassthanam (2019)
# Captive State (2019)
# Sye Raa Narasimha Reddy (2019)
#
# Fisherman's Friends (2019)
# A Score to Settle (2019)
# The Intruder (I) (2019)
# The Friend (I) (2019)
# Mon frère (2019)
# And Then We Danced (2019)
# Waiting for the Barbarians (2019)
# Polaroid (I) (2019)
# The Last Black Man in San Francisco (2019)
# Curiosa (2019)
# Il traditore (2019)
# Breakthrough (original title)
# Angel of Mine (2019)
# Proxima (2019)
# The Parts You Lose (2019)
# Secret Obsession (2019)
# Plus One (I) (2019)
# Red Devil (2019)
# Super 30 (2019)
# Submission (I) (2019)
# A Dog's Way Home (original title)
# Connect (2019)
# Lying and Stealing (2019)
# Shao nian de ni (2019)
# The Haunting of Sharon Tate (original title)
# Ms. Purple (2019)
# Mr. Jones (2019)
# Liu lang di qiu (original title)
# Pranaam (2019)
# IO (original title)
# Batla House (2019)
# The Mustang (2019)
# Das perfekte Geheimnis (2019)
# Art of Deception (2019)
# Yedinci Kogustaki Mucize (2019)
# The Painted Bird (2019)
# ANYA (2019)
# Kabir Singh (2019)
# Article 15 (2019)
# Nancy Drew and the Hidden Staircase (original title)
# L'uomo senza gravità (2019)
# Der goldene Handschuh (original title)
# Pan deng zhe (2019)
# Red Shoes and the Seven Dwarfs (original title)
# Gully Boy (2019)
# The Boy Who Harnessed the Wind (original title)
# The Jesus Rolls (original title)
# Endings, Beginnings (2019)
# Synonymes (2019)
# Hala (2019)
# Adopt a Highway (2019)
# Bad Education (2019)
#
# Ghost in the Graveyard (2019)
# Badla (2019)
# The Kill Team (2019)
# Changeland (2019)
# Dua Garis Biru (2019)
# Helen (V) (2019)
# Crypto (2019)
# The Warrior Queen of Jhansi (2019)
# Unplanned (I) (2019)
# Mickey and the Bear (2019)
# The Collini Case (2019)
# Super Deluxe (2019)
# The Sky Is Pink (2019)
# The Best of Enemies (original title)
# Kim Ji-young: Born 1982 (2019)
# 2nd Chance for Christmas (2019)
# The Sun Is Also a Star (original title)
# Palm Beach (2019)
# Guava Island (2019)
# Where We Go from Here (I) (2019)
# Berlin, I Love You (2019)
# Ordinary Love (2019)
# Theresa & Allison (2019)
# Bigil (2019)
# The Death of Dick Long (2019)
# La odisea de los giles (2019)
# Dreamland (I) (2019)
# Hors normes (2019)
# La vérité (original title)
#
# Uri: The Surgical Strike (2019)
# Elisa y Marcela (2019)
# Queen Marie of Romania (2019)
# Judgementall Hai Kya (2019)
# Sibyl (2019)
# Jangsa-ri 9.15 (2019)
# Stano (2019)
# Summer Night (2019)
# Never Grow Old (2019)
# Matthias et Maxime (2019)
#
# Low Tide (2019)
# Angelfish (2019)
# Moothon (2019)
# Poms (2019)
# Born a King (2019)
# Systemsprenger (2019)
# Balance, Not Symmetry (2019)
# Paddleton (2019)
# Sword of Trust (2019)
# L'intervention (2019)
# Bohemian Rhapsody (2018)
# Instant Family (2018)
# Freaks (2018)
# The Mule (original title)
# The Chaperone (2018)
# Hereditary (original title)
# Green Book (2018)
# The Nightingale (I) (2018)
# The Favourite (original title)
# The Death and Life of John F. Donovan (original title)
# A Quiet Place (original title)
# A Simple Favor (original title)
# A Star Is Born (2018)
# Crazy Rich Asians (original title)
# Creed II (2018)
# Vice (original title)
# Bad Times at the El Royale (original title)
# BlacKkKlansman (2018)
# Hotel Mumbai (original title)
# Red Sparrow (2018)
# The Ballad of Buster Scruggs (original title)
# Annihilation (original title)
# Destroyer (2018)
# A Million Little Pieces (2018)
# Mary Queen of Scots (original title)
# First Man (original title)
# Arctic (2018)
# Climax (I) (2018)
# Widows (original title)
# The Girl in the Spider's Web (original title)
# Bird Box (2018)
# Den of Thieves (original title)
# High Life (2018)
# Capharnaüm (original title)
# Skin (V) (2018)
# Fifty Shades Freed (original title)
# Friday's Child (2018)
# Peppermint (original title)
# Roma (2018)
# Life Itself (original title)
# Greta (2018)
# Aniara (2018)
# Outlaw King (original title)
# Beautiful Boy (I) (2018)
# Les frères Sisters (original title)
# Bigger (2018)
# The House That Jack Built (original title)
# Second Act (original title)
# Sicario: Day of the Soldado (original title)
# Nomis (2018)
# Dragged Across Concrete (2018)
# The Professor (original title)
# Under the Silver Lake (2018)
# Welcome to Marwen (original title)
# Ophelia (I) (2018)
# Braven (original title)
# Beoning (original title)
# Can You Ever Forgive Me? (original title)
# Replicas (2018)
# A Christmas Prince: The Royal Wedding (original title)
# Searching (III) (2018)
# To All the Boys I've Loved Before (original title)
# The Perfection (2018)
# Christopher Robin (original title)
# Mid90s (2018)
# 12 Strong (original title)
# Wild Rose (original title)
# Death Wish (original title)
# Gräns (original title)
# We Have Always Lived in the Castle (2018)
# On the Basis of Sex (original title)
# Leave No Trace (original title)
# White Boy Rick (original title)
# If Beale Street Could Talk (original title)
# Isle of Dogs (original title)
# Boy Erased (original title)
# The Old Man & the Gun (original title)
# Love, Simon (original title)
# The Hate U Give (original title)
# Eighth Grade (original title)
# The Man Who Killed Don Quixote (original title)
# Prospect (2018)
# Hotel Artemis (2018)
# Spinning Man (original title)
# Level 16 (2018)
# Mowgli (original title)
# Nobody's Fool (original title)
# Midnight Sun (original title)
# Manbiki kazoku (original title)
# Kursk (2018)
# Adrift (original title)
# Dumplin' (original title)
# American Woman (2018)
# Keepers (original title)
# Zimna wojna (original title)
# Terminal (I) (2018)
# Apostle (original title)
# Operation Finale (2018)
# The Guernsey Literary and Potato Peel Pie Society (original title)
# Charlie Says (2018)
# Blindspotting (2018)
# Colette (I) (2018)
# The Holiday Calendar (original title)
# Brian Banks (2018)
# Ying (2018)
# Stan & Ollie (original title)
# Vox Lux (2018)
# The Man Who Killed Hitler and Then The Bigfoot (original title)
# Buttons (I) (2018)
# Durante la tormenta (2018)
# The Clovehitch Killer (2018)
# Red Joan (2018)
# Tully (2018)
# Wij (2018)
# Driven (I) (2018)
# Hold the Dark (2018)
# Wolkenbruchs wunderliche Reise in die Arme einer Schickse (original title)
# Juliet, Naked (original title)
# Alpha (original title)
# Extinction (2018)
# American Kamasutra (2018)
# Anon (I) (2018)
# Don't Worry, He Won't Get Far on Foot (original title)
# Todos lo saben (original title)
# The Cloverfield Paradox (2018)
# The Last Man (2018)
# Kin (I) (2018)
# Yip Man ngoi zyun: Cheung Tin Chi (2018)
# At Eternity's Gate (original title)
# The Front Runner (original title)
# Assassination Nation (2018)
# The 15:17 to Paris (original title)
# The Public (2018)
# Werk ohne Autor (original title)
# Black Mirror: Bandersnatch (2018)
# Book Club (original title)
# Billionaire Boys Club (2018)
# A Private War (2018)
# How It Ends (original title)
# Den skyldige (original title)
# Vita & Virginia (2018)
# Fahrenheit 451 (2018)
# Her Smell (2018)
# Tell It to the Bees (2018)
# Sobibor (original title)
# 22 July (original title)
# Unsane (2018)
# The Little Mermaid (original title)
# Galveston (2018)
# Dogman (2018)
# The Titan (2018)
# The Darkest Minds (original title)
# Gotti (original title)
# Mary Magdalene (original title)
# Stockholm (original title)
# Ben Is Back (2018)
# The Outsider (I) (2018)
# Lords of Chaos (2018)
# Summer of 84 (2018)
# The Pages (original title)
# The Catcher Was a Spy (2018)
# King of Thieves (2018)
# Destination Wedding (original title)
# Gringo (original title)
# Wildlife (2018)
# Ladies in Black (2018)
# Head Full of Honey (original title)
# Winchester (original title)
# The Miseducation of Cameron Post (original title)
# Fast Color (2018)
# Rust Creek (2018)
# City of Lies (original title)
# Wildling (2018)
# American Animals (2018)
# Every Day (original title)
# Girl (II) (2018)
# Spell (I) (2018)
# I Can Only Imagine (original title)
# A Vigilante (2018)
# Ballon (2018)
# Ghostland (original title)
# The Tale (2018)
# The White Crow (original title)
# Forever My Girl (original title)
# Only You (2018)
# Grâce à Dieu (original title)
# Örök tél (2018)
# Every Other Holiday (2018)
# Lez Bomb (2018)
# Farming (2018)
# Da xiang xi di er zuo (2018)
# Final Score (2018)
# Gloria Bell (2018)
# Trautmann (2018)
# The Kindergarten Teacher (original title)
# Skjelvet (original title)
# Cold Brook (2018)
# Ahlat Agaci (original title)
# Down a Dark Hall (original title)
# Alex Strangelove (2018)
# Christmas Harmony (2018)
# All Is True (original title)
# Teen Spirit (original title)
# Diqiu zuihou de yewan (2018)
# Duck Butter (2018)
# Patient Zero (original title)
# The Mountain (II) (2018)
# Between Worlds (2018)
# Eerie (2018)
# Giant Little Ones (2018)
# Ashes in the Snow (2018)
# K.G.F: Chapter 1 (2018)
# Calibre (2018)
# Then Came You (original title)
# Zero (III) (2018)
# Private Life (2018)
# Sierra Burgess Is a Loser (original title)
# What Death Leaves Behind (2018)
# The Little Stranger (original title)
# Lizzie (2018)
# Trial by Fire (I) (2018)
# Possum (2018)
# Geetha Govindam (2018)
# Transit (original title)
# 96 (II) (2018)
# The Angel (original title)
# Le jeu (2018)
# The Party's Just Beginning (2018)
# The Miracle Season (original title)
# Backtrace (2018)
# Black Water (2018)
# Occupation (2018)
# Entebbe (2018)
# Pájaros de verano (original title)
# Support the Girls (2018)
# Kickboxer: Retaliation (2018)
# Holiday (I) (2018)
# Black '47 (2018)
# The Golem (2018)
# Little Women (2018)
# El fotógrafo de Mauthausen (original title)
# Acts of Violence (2018)
# Pilgrim (2018)
# Loro (2018)
# Lazzaro felice (2018)
# Living Space (2018)
# Burden (I) (2018)
# Summer '03 (2018)
# Traffik (2018)
# Damsel (I) (2018)
# Blade Runner 2049 (2017)
# Call Me by Your Name (original title)
#
# Shot Caller (original title)
# Logan (original title)
#
#
#
# Three Billboards Outside Ebbing, Missouri (original title)
# Baby Driver (original title)
# Murder on the Orient Express (original title)
# Mother! (original title)
# Lady Bird (2017)
# The Shape of Water (original title)
# Downsizing (original title)
# The Current War (original title)
# Only the Brave (original title)
# The Snowman (original title)
# Molly's Game (2017)
# Darkest Hour (original title)
# Okja (2017)
# Good Time (2017)
# Gerald's Game (original title)
# I, Tonya (original title)
# Papillon (I) (2017)
# The Disaster Artist (2017)
# Wind River (original title)
# King Arthur: Legend of the Sword (original title)
# Phantom Thread (original title)
# The Killing of a Sacred Deer (original title)
# Fifty Shades Darker (original title)
# Logan Lucky (original title)
# The Post (2017)
# The Upside (original title)
# Hostiles (original title)
# Ghost in the Shell (2017)
# Father Figures (original title)
# God's Own Country (original title)
# War for the Planet of the Apes (original title)
# The Death of Stalin (original title)
# The Man Who Invented Christmas (original title)
# Roman J. Israel, Esq. (original title)
# What Happened to Monday (original title)
# 47 Meters Down (original title)
# All the Money in the World (original title)
# 1922 (2017)
# The Big Sick (original title)
# The Meyerowitz Stories (New and Selected) (2017)
# Gifted (original title)
# Blue My Mind (original title)
# The Florida Project (original title)
# Girls Trip (original title)
# A Dog's Purpose (original title)
# Suburbicon (2017)
# Unlocked (original title)
# The Beguiled (original title)
# War Machine (2017)
# The Circle (I) (2017)
# Newness (2017)
# The Glass Castle (original title)
# Aus dem Nichts (original title)
# Disobedience (2017)
# How to Be a Latin Lover (2017)
# Flatliners (original title)
# Flower (I) (2017)
# Brawl in Cell Block 99 (original title)
# Death Note (original title)
# A Ghost Story (original title)
# T2 Trainspotting (2017)
# First Reformed (original title)
# Three Christs (2017)
# Detroit (2017)
# Jungle (I) (2017)
# Mudbound (2017)
# A Prayer Before Dawn (original title)
# Home Again (original title)
# My Friend Dahmer (2017)
# Thoroughbreds (original title)
# Professor Marston and the Wonder Women (original title)
# Amar (2017)
# Ingrid Goes West (original title)
# Hangman (original title)
# The Square (2017)
# The Space Between Us (original title)
# Shaadi Mein Zaroor Aana (2017)
# Cargo (I) (2017)
# Hot Summer Nights (2017)
# To the Bone (original title)
# Submergence (2017)
# Den 12. mann (original title)
# 6 Below: Miracle on the Mountain (original title)
# Crooked House (original title)
# Before I Fall (original title)
# Wonder Wheel (original title)
# Der Hauptmann (2017)
# The Wife (original title)
# Ghost Stories (I) (2017)
# I Kill Giants (2017)
# Loving Vincent (2017)
# Sand Castle (original title)
# All Eyez on Me (2017)
# Tulip Fever (original title)
# Borg McEnroe (2017)
# I Don't Feel at Home in This World Anymore. (2017)
# Victoria & Abdul (original title)
# Song to Song (I) (2017)
# The Shack (I) (2017)
# Thelma (2017)
# Breathe (original title)
# Teströl és lélekröl (original title)
# Stronger (original title)
# Aftermath (original title)
# Wish Upon (original title)
# The Bookshop (original title)
# The Book of Henry (original title)
# First They Killed My Father (original title)
# Battle of the Sexes (original title)
# Shimmer Lake (2017)
# The Mountain Between Us (original title)
# Mary Shelley (original title)
# Rings (original title)
# Marrowbone (2017)
# Voice from the Stone (original title)
# The Hunter's Prayer (original title)
# My Days of Mercy (2017)
# 6 Days (I) (2017)
# Goodbye Christopher Robin (original title)
# The Only Living Boy in New York (2017)
# Everything, Everything (original title)
# Bullet Head (2017)
# Pin Cushion (2017)
# Beast (III) (2017)
# The Bye Bye Man (2017)
# The Discovery (original title)
# Same Kind of Different as Me (original title)
# Indian Horse (2017)
# Kidnap (2017)
# The Pirates of Somalia (2017)
# Unforgettable (original title)
# You Get Me (2017)
# Berlin Syndrome (original title)
# The Zookeeper's Wife (original title)
# Ayla: The Daughter of War (2017)
# Nelyubov (original title)
# Last Flag Flying (2017)
# All Inclusive (2017)
# Sidney Hall (original title)
# Columbus (2017)
# The Most Hated Woman in America (original title)
# Beach Rats (2017)
# Marshall (original title)
# Table 19 (original title)
# Mark Felt: The Man Who Brought Down the White House (original title)
# The Wall (II) (2017)
# Loving Pablo (original title)
# Hagazussa (2017)
# Lucky (I) (2017)
# On Chesil Beach (original title)
# Sweet Virginia (2017)
# Unicorn Store (2017)
# Arjun Reddy (2017)
# Bushwick (2017)
# Kings (2017)
# The Rider (original title)
# I Am Not a Witch (2017)
# Megan Leavey (original title)
# Super Dark Times (2017)
# Please Stand By (original title)
# D'après une histoire vraie (original title)
# Trafficked (2017)
# Inconceivable (2017)
# Wonderstruck (original title)
# My Cousin Rachel (original title)
# Hampstead (original title)
# Journey's End (I) (2017)
# Euphoria (I) (2017)
# F*&% the Prom (2017)
# L'amant double (original title)
# Chappaquiddick (original title)
# The Ottoman Lieutenant (original title)
# Pieles (2017)
# Churchill (2017)
# Palm Swings (2017)
# Brad's Status (2017)
# American Satan (2017)
# Heartthrob (original title)
# Tuntematon sotilas (2017)
# Forget About Nick (2017)
# Prityazhenie (original title)
# Zama (2017)
# Walking Out (I) (2017)
# Film Stars Don't Die in Liverpool (original title)
# Bad Day for the Cut (2017)
# Dismissed (2017)
# The Breadwinner (original title)
# The Yellow Birds (2017)
# The Party (I) (2017)
# Woman Walks Ahead (2017)
# Mugen no jûnin (original title)
# Renegades (original title)
# Acts of Vengeance (original title)
# Our Souls at Night (original title)
# Shock and Awe (original title)
# Ji zhi zhui ji (original title)
# The Maus (2017)
# Desearás al hombre de tu hermana (2017)
# Thumper (2017)
# Submission (2017)
# Singularity (I) (2017)
# Thank You for Your Service (I) (2017)
# The Lovers (original title)
# My Little Pony: The Movie (original title)
# Princess Cyd (2017)
# The Year of Spectacular Men (2017)
# Novitiate (original title)
# Happy End (2017)
# Taeksi woonjunsa (original title)
# The Hero (I) (2017)
# Picture of Beauty (2017)
# Kodachrome (2017)
# The Children Act (original title)
# Chalard games goeng (2017)
# Aknyeo (original title)
# The Lodgers (original title)
# Billy Boy (I) (2017)
# Rebel in the Rye (2017)
# Small Crimes (2017)
# Vengeance: A Love Story (original title)
# Soleil battant (2017)
# I Love You, Daddy (2017)
# Viceroy's House (original title)
# Freak Show (2017)
# Brigsby Bear (2017)
# The Place (2017)
# Pyewacket (2017)
# M.F.A. (2017)
# Breath (I) (2017)
# Tyler Perry's Boo 2! A Madea Halloween (2017)
# Allure (original title)
# The Jade Pendant (2017)
# Lean on Pete (original title)
# The Dinner (I) (2017)
# Dog Years (I) (2017)
# Pilgrimage (original title)
# Blame (I) (2017)
# Permission (original title)
# Hostile (I) (2017)
# Gemini (II) (2017)
# November (2017)
# Hindi Medium (2017)
# Hacksaw Ridge (original title)
# Silence (I) (2016)
# La La Land (I) (2016)
# Me Before You (original title)
# Moonlight (I) (2016)
# Arrival (II) (2016)
# Nocturnal Animals (original title)
# Kimi no na wa. (original title)
# Miss Peregrine's Home for Peculiar Children (original title)
# The Girl on the Train (original title)
# Ah-ga-ssi (original title)
# Hidden Figures (original title)
# The Legend of Tarzan (2016)
# The Accountant (2016)
# The Escort (IV) (2016)
# Hell or High Water (II) (2016)
# Captain Fantastic (2016)
# Passengers (I) (2016)
# 13 Hours (original title)
# Manchester by the Sea (2016)
# The 5th Wave (original title)
# Below Her Mouth (2016)
# American Honey (2016)
# Lion (original title)
# War Dogs (original title)
# Inferno (I) (2016)
# 10 Cloverfield Lane (2016)
# Ben-Hur (2016)
# The Finest Hours (original title)
# Hail, Caesar! (original title)
# The Jungle Book (original title)
# The Lost City of Z (original title)
# The Edge of Seventeen (original title)
# Collateral Beauty (2016)
# Dangal (2016)
# Sully (2016)
# Snowden (2016)
# Hunt for the Wilderpeople (original title)
# Criminal (2016)
# Miss Sloane (original title)
# The Shallows (original title)
#
#
# The Bad Batch (2016)
# Brimstone (2016)
# Swiss Army Man (original title)
# The Founder (2016)
# Paterson (2016)
# True Crimes (original title)
#
#
# Allied (original title)
#
# Colossal (2016)
#
#
#
#
#
# Lights Out (original title)
# Midnight Special (2016)
# Sing Street (2016)
# The Choice (original title)
# The Exception (original title)
# Jackie (V) (2016)
# Free State of Jones (2016)
# Café Society (2016)
# A Monster Calls (original title)
# The Promise (II) (2016)
# Florence Foster Jenkins (original title)
# I, Daniel Blake (original title)
# A Cure for Wellness (original title)
# Grave (original title)
# Billy Lynn's Long Halftime Walk (original title)
# Fences (original title)
# The Girl with All the Gifts (original title)
# Live by Night (original title)
# Before I Wake (original title)
# Fallen (II) (2016)
# Personal Shopper (2016)
# USS Indianapolis: Men of Courage (original title)
# Gold (original title)
# White Girl (2016)
# The Siege of Jadotville (original title)
# Batman: The Killing Joke (2016)
# Money Monster (original title)
# Perfetti sconosciuti (2016)
# Bridget Jones's Baby (2016)
# Hands of Stone (2016)
# I Am Wrath (original title)
# Imperium (2016)
# Exposed (original title)
# The Light Between Oceans (original title)
# Dag II (original title)
# Miracles from Heaven (original title)
# Elle (I) (2016)
# Almost Friends (original title)
# This Beautiful Fantastic (2016)
# Crouching Tiger, Hidden Dragon: Sword of Destiny (2016)
# The Infiltrator (2016)
# Lady Macbeth (2016)
# 93 Days (2016)
# Ouija: Origin of Evil (original title)
# LBJ (2016)
# Almost Christmas (original title)
# Misconduct (original title)
# Come and Find Me (2016)
# All I See Is You (original title)
# Toni Erdmann (original title)
# Bleed for This (original title)
# The Comedian (2016)
# Frantz (2016)
# Mother's Day (I) (2016)
# The Fundamentals of Caring (original title)
# Genius (2016)
# The Young Offenders (2016)
# Term Life (original title)
# Mr. Church (2016)
# Bastille Day (original title)
# Shin Gojira (original title)
# A Hologram for the King (original title)
# Brain on Fire (2016)
# Cell (I) (2016)
# High Strung (original title)
# Julieta (2016)
# Rules Don't Apply (original title)
# Kickboxer: Vengeance (original title)
# The Good Neighbor (2016)
# Miss Stevens (2016)
# Be Somebody (2016)
# Bad Girl (II) (2016)
# Dear Zindagi (2016)
# A Dark Song (2016)
# Wish for Christmas (2016)
# Loving (original title)
# Lavender (I) (2016)
# Science Fiction Volume One: The Osiris Child (original title)
# I.T. (original title)
# Flaskepost fra P (original title)
# Out of Love (2016)
# American Pastoral (2016)
# Under the Shadow (original title)
# Race (original title)
# Whiskey Tango Foxtrot (2016)
# The Whole Truth (original title)
# Mashina lyubvi (2016)
# Teenage Cocktail (2016)
# A Family Man (original title)
# A Street Cat Named Bob (original title)
# Their Finest (original title)
# La región salvaje (2016)
# Sadie (2016)
# Mine (II) (2016)
# The Duel (original title)
# Maudie (original title)
# King Cobra (2016)
# Our Kind of Traitor (original title)
# Buster's Mal Heart (2016)
# Love & Friendship (original title)
# Good Kids (I) (2016)
# Forushande (original title)
# Joker (2016)
# Juste la fin du monde (original title)
# Birkebeinerne (original title)
# Sugar Mountain (2016)
# Viking (2016)
# Hounds of Love (2016)
# The Secret Scripture (original title)
# Manhattan Nocturne (2016)
# Una (2016)
# Barbershop: The Next Cut (original title)
# Denial (original title)
# The Intervention (I) (2016)
# Pink (III) (2016)
# The Journey (original title)
# Gantz: O (2016)
# Blue Jay (I) (2016)
# The Eyes of My Mother (2016)
# The Birth of a Nation (original title)
# The Monster (2016)
# The Trust (original title)
# Indignation (original title)
# The Hollars (2016)
# A United Kingdom (original title)
# The Pass (2016)
# A Kind of Murder (original title)
# Nine Lives (original title)
# Handsome Devil (2016)
# Mil-jeong (original title)
# When the Bough Breaks (original title)
# Don't Think Twice (2016)
# Goat (2016)
# Risen (original title)
# Katie Says Goodbye (2016)
# Certain Women (2016)
# Brotherhood (I) (2016)
# Shut In (I) (2016)
# XOXO (2016)
# Tommy's Honour (2016)
# Knives Out (2016)
# The Last Face (original title)
# Queen of Katwe (2016)
# Wakefield (original title)
# Birth of the Dragon (original title)
# Die Mitte der Welt (2016)
# In Dubious Battle (original title)
# The Drowning (2016)
# Christine (2016)
# Nowhereland (2016)
# Other People (I) (2016)
# Alone in Berlin (original title)
# Aquarius (I) (2016)
# Trapped (XVII) (2016)
# The Thinning (2016)
# Kingsglaive: Final Fantasy XV (2016)
# Tallulah (2016)
# The Bleeder (2016)
# Lady Bloodfight (2016)
# Despite the Falling Snow (2016)
# Girl in the Box (original title)
# Arès (2016)
# Mei ren yu (2016)
# Headshot (II) (2016)
# Barry (II) (2016)
# Les innocentes (original title)
# Boo! A Madea Halloween (2016)
# I'm Not Ashamed (2016)
# The Disappointments Room (2016)
# Fan (I) (2016)
# A Quiet Passion (2016)
# First Girl I Loved (2016)
# Hurricane Bianca (original title)
# Demain tout commence (original title)
# Anchiporuno (original title)
# Sangre en la boca (original title)
# On the Milky Road (original title)
# Planetarium (2016)
# Carrie Pilby (2016)
# Mothers and Daughters (2016)
# The Hollow Point (2016)
# Ma vie de Courgette (original title)
# Riphagen (2016)
# The Confirmation (2016)
# Shangri-La Suite (2016)
# The Receptionist (II) (2016)
# Pelé: Birth of a Legend (original title)
# The Model (I) (2016)
# Sanam Teri Kasam (2016)
# Distant Vision (2016)
# Kono sekai no katasumi ni (original title)
# Love (II) (2015)
# The Revenant (original title)
# The VVitch: A New-England Folktale (original title)
# Inside Out (I) (2015)
# The Hateful Eight (2015)
# Cinderella (original title)
# Fifty Shades of Grey (original title)
# Knock Knock (I) (2015)
# The Big Short (original title)
# The Martian (original title)
# Room (I) (2015)
# Sicario (2015)
# Spotlight (original title)
# The Lobster (2015)
# Legend (I) (2015)
# Fantastic Four (original title)
# Carol (2015)
# The Invitation (I) (2015)
# Secret in Their Eyes (original title)
# Krampus (original title)
# Focus (original title)
# Creed (original title)
# Bone Tomahawk (2015)
# The Good Dinosaur (original title)
# The Danish Girl (2015)
# The Longest Ride (original title)
# The Intern (original title)
# San Andreas (2015)
# Bridge of Spies (original title)
# True Story (I) (2015)
# Black Mass (original title)
# Trainwreck (original title)
# Southpaw (original title)
# Chappie (original title)
# In the Heart of the Sea (original title)
# Brooklyn (2015)
# Everest (2015)
# The Age of Adaline (original title)
# McFarland, USA (original title)
# A Bigger Splash (2015)
# Straight Outta Compton (2015)
# Crimson Peak (2015)
# Steve Jobs (2015)
# Bang Gang (une histoire d'amour moderne) (2015)
# Burnt (original title)
# The Gift (original title)
# The Stanford Prison Experiment (original title)
# Solace (original title)
# Aloha (original title)
# Knight of Cups (2015)
# Double Daddy (original title)
# The Diary of a Teenage Girl (original title)
# Joy (I) (2015)
# We Are Your Friends (2015)
# Heist (original title)
# Concussion (original title)
# Far from the Madding Crowd (original title)
# Wild Card (original title)
# Youth (original title)
# Irrational Man (2015)
# Child 44 (original title)
# Magic Mike XXL (2015)
# Suffragette (2015)
# Me and Earl and the Dying Girl (original title)
# Victor Frankenstein (original title)
# Beasts of No Nation (2015)
# Ashby (2015)
# Eddie the Eagle (original title)
# Sleeping with Other People (original title)
# Queen of the Desert (2015)
# Trumbo (original title)
# Macbeth (2015)
# Man Down (I) (2015)
# Paper Towns (original title)
# Yip Man 3 (original title)
# The Walk (II) (2015)
# Colonia (2015)
# High-Rise (original title)
# Eye in the Sky (original title)
# The Man Who Knew Infinity (original title)
# The 33 (2015)
# The Final Girls (2015)
# Anomalisa (2015)
# Dark Places (original title)
# The Dressmaker (original title)
# Dope (original title)
# Demolition (original title)
# I'll See You in My Dreams (original title)
# Circle (II) (2015)
# Mississippi Grind (2015)
# Run All Night (original title)
# Woman in Gold (2015)
# Christmas in the Smokies (2015)
# 6 Years (2015)
# Last Knights (2015)
# Krisha (2015)
# Spooks: The Greater Good (original title)
# The Devil's Candy (2015)
# By the Sea (2015)
# Tamasha (2015)
# Le Petit Prince (original title)
# Into the Forest (2015)
# Equals (2015)
# Er ist wieder da (original title)
# Victoria (II) (2015)
# Palmeras en la nieve (original title)
# Z for Zachariah (original title)
# Jem and the Holograms (original title)
# Shingeki no kyojin (2015)
# Mistress America (2015)
# Bajirao Mastani (2015)
# Man Up (I) (2015)
# A Dogwalker's Christmas Tale (original title)
# Fathers & Daughters (original title)
# The Peanuts Movie (original title)
# Holding the Man (2015)
# Ithaca (2015)
# En man som heter Ove (original title)
# Saul fia (original title)
# Pay the Ghost (original title)
# Bølgen (original title)
# Slumlord (2015)
# Rosemont (2015)
# Return to Sender (original title)
# Too Late (original title)
# The Bronze (original title)
# Under sandet (original title)
# Jenny's Wedding (2015)
# Bahubali: The Beginning (2015)
# 3 Generations (original title)
# Remember (I) (2015)
# The Gunman (2015)
# Project Almanac (original title)
# Mustang (2015)
# Danny Collins (original title)
# Careful What You Wish For (original title)
# War Room (original title)
# Jane Got a Gun (2015)
# Un moment d'égarement (original title)
# Masaan (original title)
# Drishyam (2015)
# Tangerine (2015)
# The Second Best Exotic Marigold Hotel (original title)
# A Walk in the Woods (original title)
# Heaven Sent (original title)
# Maggie (original title)
# Bound (I) (2015)
# 45 Years (original title)
# Gansin (2015)
# The Family Fang (original title)
# Mon roi (original title)
# Ci ke Nie Yin Niang (original title)
# The Sea of Trees (original title)
# Unfinished Business (original title)
# I Saw the Light (2015)
# Tracers (2015)
# The End of the Tour (original title)
# Il racconto dei racconti - Tale of Tales (original title)
# Miss You Already (2015)
# Shingeki no kyojin endo obu za wârudo (original title)
# Abandoned (VI) (2015)
# Max (I) (2015)
# Shut In (2015)
# He Never Died (2015)
# My All-American (2015)
# Mr. Holmes (original title)
# Life (I) (2015)
# Suburra (2015)
# Ricki and the Flash (original title)
# A Perfect Day (original title)
# El Club (original title)
# El cadáver de Anna Fritz (2015)
# Swung (2015)
# Tian jiang xiong shi (original title)
# Martyrs (2015)
# Steel (I) (2015)
# Mohammad Rasoolollah (2015)
# El abrazo de la serpiente (2015)
# Talvar (2015)
# Our Brand Is Crisis (original title)
# The Lady in the Van (2015)
# Umimachi Diary (original title)
# I (2015)
# Experimenter (2015)
# See You in Valhalla (2015)
# Naomi and Ely's No Kiss List (original title)
# The Perfect Guy (I) (2015)
# Chi-Raq (2015)
# Digging for Fire (original title)
# Much Loved (2015)
# 90 Minutes in Heaven (original title)
# The Program (II) (2015)
# I Am Michael (2015)
# Bitva za Sevastopol (original title)
# Captive (II) (2015)
# The Adderall Diaries (original title)
# Córki dancingu (2015)
# Mojave (2015)
# Dum Laga Ke Haisha (2015)
# Every Thing Will Be Fine (original title)
# Landmine Goes Click (2015)
# Stonewall (2015)
# Truth (original title)
# The Childhood of a Leader (original title)
# Maggie's Plan (original title)
# Mucize (2015)
# Little Boy (2015)
# Manifesto (III) (2015)
# Badlapur (2015)
# Freeheld (original title)
# Anesthesia (2015)
# A Royal Night Out (original title)
# Bajrangi Bhaijaan (2015)
# Avouterie (2015)
# Rendez-Vous (2015)
# The Daughter (2015)
# The Intruders (I) (2015)
# The Meddler (2015)
# The Survivalist (2015)
# Visaaranai (2015)
# Zipper (2015)
# How to Plan an Orgy in a Small Town (2015)
# Miles Ahead (2015)
# Vendetta (2015)
# Kidnapping Mr. Heineken (original title)
# La belle saison (2015)
# Walt Before Mickey (original title)
# Heidi (2015)
# Dil Dhadakne Do (2015)
# Mænd & høns (2015)
# They Look Like People (2015)
# Braqueurs (2015)
# Hello, My Name Is Doris (2015)
# Bare (I) (2015)
# Extinction (original title)
# Fourth Man Out (2015)
# Louder Than Bombs (original title)
# Aap wong (2015)
# Delibal (2015)
# Into the Grizzly Maze (original title)
# Backtrack (I) (2015)
# Terminus (2015)
# Hope Lost (2015)
# Strangerland (2015)
# One and Two (2015)
# Ma ma (original title)
# Hyena Road (2015)
# The Girl King (2015)
# Yr Ymadawiad (2015)
# Hrútar (original title)
# Interstellar (2014)
# Gone Girl (original title)
# Whiplash (2014)
# Ex Machina (2014)
# Fury (2014)
# Birdman or (The Unexpected Virtue of Ignorance) (original title)
# American Sniper (2014)
# The Imitation Game (2014)
# Tusk (2014)
# Chef (original title)
# Predestination (I) (2014)
# Nightcrawler (original title)
# Inherent Vice (original title)
# The Babadook (original title)
# The Giver (original title)
# The Theory of Everything (original title)
# Into the Woods (2014)
# Pompeii (original title)
# Boyhood (I) (2014)
# The Fault in Our Stars (original title)
# Unbroken (I) (2014)
# Jack Ryan: Shadow Recruit (original title)
# Noah (2014)
# Exodus: Gods and Kings (original title)
# Dracula Untold (2014)
# Annie (original title)
# Sabotage (2014)
# Wild (I) (2014)
# Foxcatcher (original title)
# Relatos salvajes (original title)
# The Judge (2014)
# Veronica Mars (original title)
# The Salvation (2014)
# This Is Where I Leave You (2014)
# Vampire Academy (2014)
# Dawn of the Planet of the Apes (original title)
# I Origins (2014)
# A Walk Among the Tombstones (original title)
# Transcendence (I) (2014)
# The Drop (original title)
# PK (2014)
# The Captive (original title)
# Cake (II) (2014)
# The Best of Me (original title)
# Still Alice (2014)
# Outcast (original title)
# Mommy (I) (2014)
# The Hundred-Foot Journey (original title)
# A Most Violent Year (original title)
# Serena (original title)
# Jersey Boys (2014)
# 3 Days to Kill (2014)
# The Water Diviner (2014)
# Selma (original title)
# Big Eyes (I) (2014)
# Before We Go (I) (2014)
# If I Stay (original title)
# The Signal (2014)
# Suite Française (original title)
# Draft Day (I) (2014)
# Love & Mercy (2014)
# Left Behind (original title)
# While We're Young (original title)
# Winter's Tale (original title)
# Kraftidioten (original title)
# Maps to the Stars (2014)
# The Monuments Men (original title)
# The Rover (2014)
# Testament of Youth (original title)
# The Riot Club (original title)
# Pride (I) (2014)
# The Homesman (2014)
# She's Funny That Way (original title)
# Kis Uykusu (original title)
# Endless Love (original title)
# Kill the Messenger (original title)
# St. Vincent (2014)
# Eliza Graves (original title)
# Leviafan (original title)
# Men, Women & Children (2014)
# A Most Wanted Man (original title)
# Before I Go to Sleep (2014)
# The Gambler (III) (2014)
# What We Did on Our Holiday (original title)
# Backcountry (I) (2014)
# The Falling (2014)
# A Girl Walks Home Alone at Night (2014)
# In-gan-jung-dok (2014)
# '71 (2014)
# Appropriate Behavior (2014)
# Space Station 76 (2014)
# Heaven Knows What (2014)
# A Little Chaos (original title)
# The Cobbler (original title)
# La belle et la bête (original title)
# The One I Love (2014)
# Lost River (2014)
# Who Am I - Kein System ist sicher (2014)
# Song of the Sea (original title)
# The Disappearance of Eleanor Rigby: Them (original title)
# Into the Storm (2014)
# Turist (original title)
# Million Dollar Arm (2014)
# Clouds of Sils Maria (original title)
# Omoide no Mânî (original title)
# Manglehorn (2014)
# Clown (2014)
# Addicted (original title)
# The Single Moms Club (2014)
# Ask Me Anything (original title)
# Frank (II) (2014)
# Step Up All In (2014)
# Grace of Monaco (original title)
# Laggies (original title)
# The Longest Week (original title)
# Pawn Sacrifice (original title)
#
#
#
#
#
#
#
#
#
# Son of a Gun (2014)
#
#
# Get on Up (original title)
# God's Not Dead (original title)
# Wish I Was Here (2014)
# Black Sea (2014)
# Mr. Turner (original title)
# 5 to 7 (2014)
# The Good Lie (2014)
# Free the Nipple (2014)
# Escobar: Paradise Lost (original title)
# Starry Eyes (2014)
# Obvious Child (original title)
# You're Not You (original title)
# Barefoot (original title)
# Heaven Is for Real (original title)
# Camp X-Ray (2014)
# 5 Flights Up (original title)
# Hoje Eu Quero Voltar Sozinho (2014)
# Dear White People (2014)
# 99 Homes (2014)
# Deux jours, une nuit (original title)
# Boychoir (original title)
# Diet of Sex (2014)
# Happy Christmas (2014)
# Comet (2014)
# No Good Deed (original title)
# The Angriest Man in Brooklyn (original title)
# Hector and the Search for Happiness (original title)
# Gimme Shelter (original title)
# Welcome to Me (2014)
# Kid Cannabis (2014)
# Trash (I) (2014)
# The Humbling (2014)
# Phoenix (original title)
# Lap Dance (2014)
# Effie Gray (original title)
# The Little Death (2014)
# A Long Way Down (original title)
# Plemya (original title)
# The Last Five Years (2014)
# Northmen - A Viking Saga (original title)
# Cut Bank (2014)
# Durak (II) (2014)
# Northern Soul (2014)
# Haider (2014)
# The Christmas Dragon (2014)
# Miss Julie (2014)
# Merry Ex-Mas (original title)
# Dark Was the Night (original title)
# When the Game Stands Tall (original title)
# Highway (I) (2014)
# 10.0 Earthquake (original title)
# Adult Beginners (2014)
# Queen & Country (2014)
# Aloft (original title)
# Good Kill (2014)
# Every Secret Thing (original title)
# Shelter (I) (2014)
# Road to Paloma (2014)
# Kajaki (2014)
# The Keeping Room (2014)
# En duva satt på en gren och funderade på tillvaron (original title)
# Dying of the Light (original title)
# Billy Elliot the Musical Live (2014)
# The Face of an Angel (2014)
# The Bag Man (original title)
# Bangalore Days (2014)
# Rudderless (original title)
# Jackie & Ryan (2014)
# Infinitely Polar Bear (original title)
# Faults (2014)
# Miasto 44 (original title)
# My Mistress (2014)
# Learning to Drive (original title)
# Rosewater (2014)
# And So It Goes (original title)
# Das finstere Tal (original title)
# Reasonable Doubt (original title)
# School Dance (2014)
# Not Cool (II) (2014)
# Le meraviglie (2014)
# Madam ppang-deok (2014)
# Date and Switch (2014)
# Animal (original title)
# The Road Within (original title)
# Vonarstræti (2014)
# Life Partners (2014)
# Hide and Seek (I) (2014)
# The Forger (original title)
# Viharsarok (2014)
# Son of God (2014)
# Perfect Sisters (original title)
# Bande de filles (original title)
# Jack (I) (2014)
# Alex of Venice (original title)
# Reach Me (original title)
# Hungry Hearts (2014)
# Mardaani (2014)
# Por un puñado de besos (2014)
# A Good Marriage (2014)
# Kaththi (2014)
# Anatomy of a Love Seen (original title)
# Copenhagen (2014)
# Timbuktu (2014)
# Respire (2014)
# Sadece Sen (original title)
# Magical Girl (2014)
# Yo soy la felicidad de este mundo (2014)
# Boulevard (2014)
# Loin des hommes (2014)
# Natt til 17. (2014)
# La famille Bélier (original title)
# Mary Kom (2014)
# Myeong-ryang (original title)
# God's Pocket (2014)
# Gemma Bovery (2014)
# Paper Planes (original title)
# God Help the Girl (2014)
# Reclaim (original title)
# Deadly Virtues: Love.Honour.Obey. (2014)
# Walking on Sunshine (2014)
# Blind (II) (2014)
# Black or White (2014)
# The Wolf of Wall Street (2013)
# Her (original title)
# Snowpiercer (2013)
# Prisoners (2013)
# The Great Gatsby (original title)
# Don Jon (2013)
# La vie d'Adèle (original title)
# Nymphomaniac: Vol. I (original title)
# American Hustle (original title)
# About Time (original title)
# Rush (I) (2013)
# Under the Skin (I) (2013)
# 12 Years a Slave (original title)
# Fruitvale Station (original title)
# Saving Mr. Banks (2013)
# Dallas Buyers Club (2013)
# Gravity (2013)
# The Secret Life of Walter Mitty (original title)
# Side Effects (original title)
# Lone Survivor (2013)
# Locke (2013)
# Elysium (I) (2013)
# The Frozen Ground (original title)
# Nymphomaniac: Vol. II (original title)
# Inside Llewyn Davis (original title)
# White House Down (original title)
# Gangster Squad (2013)
# Captain Phillips (original title)
# Filth (I) (2013)
# Oldboy (2013)
# Only God Forgives (original title)
# Pain & Gain (original title)
# Only Lovers Left Alive (original title)
# Adoration (original title)
# August: Osage County (original title)
# Safe Haven (original title)
# Lovelace (2013)
# Out of the Furnace (original title)
# Carrie (original title)
# The Spectacular Now (2013)
# Stoker (2013)
# Before Midnight (2013)
# Short Term 12 (2013)
# The Counselor (original title)
# The Way Way Back (original title)
# The Bling Ring (original title)
# Blue Jasmine (2013)
# 47 Ronin (2013)
# After Earth (2013)
# Begin Again (original title)
# The Call (II) (2013)
# La migliore offerta (2013)
# Young and Beautiful (original title)
# The Double (original title)
# Grudge Match (original title)
# The Host (2013)
# Horns (2013)
# Hummingbird (original title)
# 42 (original title)
# Beautiful Creatures (original title)
# Avant l'hiver (2013)
# La grande bellezza (2013)
# The Physician (original title)
# Empire State (2013)
# All Is Lost (original title)
# Blue Ruin (2013)
# The Lifeguard (2013)
# Labor Day (original title)
# The Butler (original title)
# The Kings of Summer (2013)
# The Zero Theorem (original title)
# Dead Man Down (original title)
# The Big Wedding (original title)
# Nebraska (2013)
# Man of Tai Chi (2013)
# Koto no ha no niwa (original title)
# Trance (original title)
# Romeo & Juliet (II) (2013)
# Snitch (original title)
# The Book Thief (original title)
# Kill Your Darlings (original title)
# Last Vegas (2013)
# Belle (original title)
# Kaze tachinu (original title)
# Drinking Buddies (original title)
# The Immigrant (original title)
# Palo Alto (2013)
# The Necessary Death of Charlie Countryman (original title)
# Behind the Candelabra (original title)
# Afternoon Delight (2013)
# Angels Sing (original title)
# La Vénus à la fourrure (original title)
# Jobs (2013)
# Europa Report (2013)
# Ida (2013)
# Anna (VII) (2013)
# Drishyam (2013)
# CBGB (2013)
# The Fifth Estate (original title)
# Concussion (2013)
# Killing Season (2013)
# The Canyons (2013)
# Yi dai zong shi (original title)
# A Teacher (2013)
# Joe (I) (2013)
# Parkland (2013)
# Starred Up (original title)
# Enough Said (original title)
# A Madea Christmas (2013)
# No se aceptan devoluciones (original title)
# The Christmas Candle (2013)
# Delivery Man (2013)
# The Haunting in Connecticut 2: Ghosts of Georgia (2013)
# Upstream Color (2013)
# Identity Thief (original title)
# The Best Man Holiday (2013)
# The Railway Man (original title)
# Broken City (2013)
# Breathe In (original title)
# Blood Ties (original title)
# Diana (original title)
# Kaguyahime no monogatari (original title)
# Hours (2013)
# Third Person (2013)
# Philomena (2013)
# 7-beon-bang-ui seon-mul (2013)
# Vi (2013)
# Absolute Deception (2013)
# The Machine (I) (2013)
# Freier Fall (2013)
# Dabba (original title)
# Not Another Happy Ending (2013)
# Night Moves (2013)
# Paranoia (original title)
# Feuchtgebiete (2013)
# We Are What We Are (2013)
# The Disappearance of Eleanor Rigby: Her (original title)
# Mystery Road (2013)
# Molly Maxwell (2013)
# Devil's Knot (original title)
# 3096 Tage (2013)
# The Congress (2013)
# The Disappearance of Eleanor Rigby: Him (original title)
# After the Dark (2013)
# G.B.F. (2013)
# Ugly (2013)
# The East (2013)
# Jimi: All Is by My Side (2013)
# Tom à la ferme (2013)
# Very Good Girls (2013)
# These Final Hours (original title)
# Are You Here (2013)
# Sunshine on Leith (2013)
# Fateful Findings (2013)
# Tracks (original title)
# In Secret (2013)
# Salomé (2013)
# Phantom (I) (2013)
# L'inconnu du lac (original title)
# The Trials of Cate McCall (original title)
# Yeh Jawaani Hai Deewani (2013)
# Hawaii (I) (2013)
# Borgman (2013)
# The Truth About Emanuel (2013)
# Le passé (original title)
# The Invisible Woman (2013)
# Admission (original title)
# Dom Hemingway (2013)
# Tarzan (2013)
# Lad: A Yorkshire Story (2013)
# Stalingrad (2013)
# All Is Bright (2013)
# Bad Words (2013)
# Soshite chichi ni naru (original title)
# Adult World (2013)
# Mandela: Long Walk to Freedom (2013)
# Xi you: Xiang mo pian (2013)
# Temptation: Confessions of a Marriage Counselor (2013)
# The Look of Love (2013)
# A Field in England (original title)
# Closed Circuit (2013)
# L'écume des jours (original title)
# Sinsegye (2013)
# Raze (2013)
# Deseo (2013)
# Tian zhu ding (original title)
# One Chance (original title)
# Trudno byt bogom (original title)
# The English Teacher (2013)
# Ashley (I) (2013)
# Mandariinid (original title)
# Michael Kohlhaas (2013)
# Ain't Them Bodies Saints (original title)
# La danza de la realidad (original title)
# Madras Cafe (original title)
# Zulu (2013)
# Kamasutra 3D (2013)
# From the Rough (original title)
# Rubinrot (original title)
# Half of a Yellow Sun (original title)
# As I Lay Dying (2013)
# Cheap Thrills (I) (2013)
# Goliyon Ki Rasleela Ram-Leela (2013)
# Christmas for a Dollar (2013)
# Cold Comes the Night (original title)
# Geography Club (2013)
# Escape from Tomorrow (2013)
# Compulsion (I) (2013)
# Queen (2013)
# Walking with the Enemy (2013)
# The Young and Prodigious T.S. Spivet (original title)
# Breakout (original title)
# Lootera (I) (2013)
# I'm in Love with a Church Girl (2013)
# Moebiuseu (original title)
# Kelebegin Rüyasi (2013)
# Rushlights (2013)
# Omar (2013)
# Contracted (original title)
# Caníbal (2013)
# The Harvest (I) (2013)
# Gloria (II) (2013)
# The Pretty One (2013)
# Heatstroke (2013)
# The Turning (2013)
# It Felt Like Love (2013)
# Magic Magic (2013)
# Gods Behaving Badly (2013)
# Mr. Morgan's Last Love (original title)
# Bhaag Milkha Bhaag (2013)
# Free Ride (2013)
# Nasha (2013)
# Kai po che! (2013)
# Paradise (original title)
# Green Street 3: Never Back Down (original title)
# Yip Man: Jung gik yat zin (original title)
# Jing cha gu shi 2013 (original title)
# Grand Masti (2013)
# Crazy Kind of Love (2013)
# No somos animales (2013)
# Pleasure or Pain (2013)
# Battle of the Year (original title)
# Málmhaus (2013)
# Summer in February (original title)
# Goodbye World (2013)
# C.O.G. (2013)
# Life Inside Out (2013)
# A Single Shot (2013)
# Raanjhanaa (2013)
# Miss Violence (2013)
# End of Watch (original title)
# Django Unchained (2012)
# Looper (2012)
# Les Misérables (2012)
# The Master (2012)
# The Twilight Saga: Breaking Dawn - Part 2 (original title)
# Spring Breakers (original title)
# Cloud Atlas (2012)
# Zero Dark Thirty (2012)
# Silver Linings Playbook (original title)
# The Perks of Being a Wallflower (original title)
# Lo imposible (original title)
# Argo (2012)
# Jagten (original title)
# Lincoln (2012)
# Snow White and the Huntsman (original title)
# Rock of Ages (2012)
# Moonrise Kingdom (original title)
# The Place Beyond the Pines (original title)
# Lawless (2012)
# Anna Karenina (I) (2012)
# Magic Mike (2012)
# Life of Pi (original title)
# Frances Ha (2012)
# Cosmopolis (2012)
# The Iceman (2012)
# Flight (I) (2012)
# House at the End of the Street (original title)
# Chronicle (2012)
# Mud (2012)
# Killing Them Softly (original title)
# Savages (original title)
# The Vow (original title)
# The Lucky One (original title)
# Chroniques sexuelles d'une famille d'aujourd'hui (2012)
# Into the White (original title)
# De rouille et d'os (original title)
# Gangs of Wasseypur (2012)
# What to Expect When You're Expecting (original title)
# Stuck in Love. (2012)
# Thanks for Sharing (original title)
# The Lorax (original title)
# Byzantium (2012)
# The Woman in Black (2012)
# On the Road (2012)
# Safety Not Guaranteed (2012)
# Mirror Mirror (original title)
# The Reluctant Fundamentalist (original title)
# The Sessions (original title)
# A Perfect Ending (2012)
# Bait (original title)
# Klip (original title)
# Holy Motors (2012)
# Get the Gringo (original title)
# To the Wonder (2012)
# Passion (2012)
# American Mary (2012)
# Amour (2012)
# The Words (2012)
# En kongelig affære (original title)
# The First Time (I) (2012)
# Seeking a Friend for the End of the World (original title)
# Fire with Fire (II) (2012)
# Ice Age: Continental Drift (original title)
# Act of Valor (2012)
# Excision (2012)
# Underworld Awakening (original title)
# Trouble with the Curve (original title)
# LOL (original title)
# Step Up Revolution (original title)
# The Paperboy (2012)
# Smashed (2012)
# And While We Were Here (2012)
# Hitchcock (2012)
# Red Tails (2012)
# About Cherry (2012)
# Contraband (2012)
# Compliance (2012)
# Great Expectations (original title)
# The Odd Life of Timothy Green (original title)
# Kon-Tiki (2012)
# Upside Down (I) (2012)
# Bez wstydu (2012)
# Broken (original title)
# Beasts of the Southern Wild (original title)
# The Tall Man (original title)
# Ruby Sparks (2012)
# Disconnect (I) (2012)
# Red Lights (2012)
# Bel Ami (original title)
# The Company You Keep (original title)
# Chasing Mavericks (original title)
# The Broken Circle Breakdown (original title)
# Promised Land (2012)
# Arbitrage (original title)
# Liberal Arts (2012)
# Ookami kodomo no Ame to Yuki (original title)
# Freelancers (2012)
# The Courier (2012)
# Venuto al mondo (2012)
# Chained (I) (2012)
# B.A. Pass (2012)
# Much Ado About Nothing (original title)
# Deadfall (original title)
# Big Miracle (original title)
# Girls Against Boys (2012)
# Now Is Good (2012)
# Madea's Witness Protection (original title)
# Dans la maison (original title)
# Barfi! (2012)
# Hoo-goong: Je-wang-eui cheob (original title)
# Fast Girls (2012)
# Eden (original title)
# Hope Springs (original title)
# National Theatre Live: All About Eve (2012)
# Laurence Anyways (original title)
# A Thousand Words (original title)
# Ginger & Rosa (2012)
# People Like Us (original title)
# Hyde Park on Hudson (original title)
# Celeste & Jesse Forever (original title)
# Gayby (2012)
# Den skaldede frisør (original title)
# Herutâ sukerutâ (2012)
# 28 Hotel Rooms (2012)
# The Angels' Share (original title)
# Jab Tak Hai Jaan (2012)
# Joyful Noise (original title)
# The Sapphires (2012)
# Starlet (I) (2012)
# Tengo ganas de ti (2012)
# Hemel (2012)
# The Sweeney (2012)
# Shahid (2012)
# Robot & Frank (2012)
# The Battery (2012)
# Out in the Dark (2012)
# Dag (2012)
# Talaash (2012)
# Zwei Leben (original title)
# Dark Tide (2012)
# Struck by Lightning (2012)
# The Guilt Trip (original title)
# Not Fade Away (2012)
# Spike Island (2012)
# The Scapegoat (2012)
# Agneepath (2012)
# Marfa Girl (2012)
# It's Such a Beautiful Day (2012)
# The Seasoning House (2012)
# Ill Manors (2012)
# Private Peaceful (2012)
# For Greater Glory: The True Story of Cristiada (original title)
# Berberian Sound Studio (2012)
# Generation Um... (2012)
# OMG: Oh My God! (2012)
# Quartet (2012)
# It's a Disaster (2012)
# Wish You Were Here (I) (2012)
# Offender (2012)
# Steekspel (2012)
# No (original title)
# Good Deeds (2012)
# What Maisie Knew (original title)
# Pieta (original title)
# At Any Price (original title)
# Paradies: Liebe (2012)
# Rezeta (2012)
# Sparkle (original title)
# Berserk: Ougon Jidai-hen I - Haou no Tamago (original title)
# El sexo de los ángeles (2012)
# Barbara (original title)
# Being Flynn (2012)
# Emperor (2012)
# Lore (2012)
# The Giant Mechanical Man (2012)
# Evangelion Shin Gekijôban: Kyu (original title)
# Atlas Shrugged II: The Strike (2012)
# Lay the Favorite (original title)
# The Magic of Belle Isle (2012)
# Ernest et Célestine (original title)
# Nanban (2012)
# Little Thirteen (2012)
# Kiss of the Damned (2012)
# Girl in Progress (2012)
# Small Apartments (2012)
# Les adieux à la reine (original title)
# Kapringen (2012)
# Hello I Must Be Going (original title)
# A Late Quartet (original title)
# Red Hook Summer (2012)
# L'enfant d'en haut (original title)
# Walking the Halls (2012)
# Student of the Year (2012)
# Wadjda (original title)
# King Kelly (2012)
# Cocktail (2012)
# Kursk (2012)
# Oh Boy (original title)
# Jayne Mansfield's Car (original title)
# Hypnotisören (original title)
# Rurôni Kenshin: Meiji kenkaku roman tan (original title)
# Renoir (2012)
# Io e te (2012)
# The Comedy (2012)
# 6 Bullets (2012)
# Call Girl (2012)
# Comme un chef (original title)
# La fille de nulle part (2012)
# Like Someone in Love (original title)
# Jack & Diane (2012)
# The Door (I) (2012)
# Love Never Dies (II) (2012)
# The Kitchen (2012)
# Du zhan (original title)
# Dupa dealuri (original title)
# The Unspeakable Act (2012)
# Fetih 1453 (2012)
# Blancanieves (2012)
# 11 settembre 1683 (2012)
# Ship of Theseus (2012)
# Tensión sexual, Volumen 1: Volátil (2012)
# Post Tenebras Lux (2012)
# Shadow Dancer (original title)
# The Rise (2012)
# El Gringo (2012)
# Le prénom (original title)
# Branded (original title)
# Bad Parents (2012)
# Ambrosia (I) (2012)
# Cleanskin (2012)
# StreetDance 2 (2012)
# Over Kanten (2012)
# Hannah Arendt (2012)
# Just Like a Woman (original title)
# Nobody Walks (2012)
# Keep the Lights On (2012)
# Christmas Oranges (2012)
# Tabu (I) (2012)
# Foxfire (original title)
# To Write Love on Her Arms (2012)
# Hello Herman (2012)
# An Oversimplification of Her Beauty (2012)
# English Vinglish (original title)
# The Color of Time (II) (2012)
# Rufus (2012)
# Blood (I) (2012)
# Hoi-sa-won (2012)
# After (I) (2012)
# Found (III) (2012)

# %% [markdown]
# <br></br>
# ## [4.1 Merge Titoli](#4.1)

# %% [markdown]
# <font size=3>
#
# Le liste ottenute con gli altri notebook sono stati salvati in file `picle` e caricate nel seguente blocco di codice. Per facilitare la creazione di una lista unica i file sono inseriti in due liste: una per i titoli geolocalizzati ed una per i titoli originali.

# %%
with open('output_title2', "rb") as input_file:
    title2 = pickle.load(input_file)
with open('output_original_title2', "rb") as input_file2:
    original_title2 = pickle.load(input_file2)
with open('output_title3', "rb") as input_file3:
    title3 = pickle.load(input_file4)
with open('output_original_title3', "rb") as input_file4:
    original_title3 = pickle.load(input_file4)
with open('output_title4', "rb") as input_file5:
    title4 = pickle.load(input_file5)
with open('output_original_title4', "rb") as input_file6:
    original_title4 = pickle.load(input_file6)
    
title_files = [title2, title3, title4]
original_title_files = [original_title2, original_title3, original_title4]

# %% [markdown]
# <font size=3>
#
# Per ogni file all'interno della lista si prende un titolo alla volta e lo si aggiunge alla lista già presente in questo notebook.

# %%
for file in title_files:
    for t in file:
        title.append(t)
        
for file in original_title_files:
    for o in file:
        original_title.append(o)

# %% [markdown]
# <font size=3>
#
# Dalle due liste ottenute si crea un dataframe con `pandas` e il risultato viene salvato in un `.csv`.

# %%
movies_titles = pd.DataFrame({"Translated":title, "Original":original_title})
movies_titles.to_csv("movies titles.csv")

# %% [markdown]
# <br></br>
# <br></br>
# # [5. Scraping Info](#5)

# %% [markdown]
# <font size=3>
#
# Per effettuare una aspect-base sentiment analysis corretta sono necessarie ulteriori informazioni relative al film. Come letto in diversi paper le informazioni di contorno come il nome degli attori sono fondamentali per individuare correttamente gli aspetti ed effettuare un'analisi del sentiment.
#
# Per estrarre queste informazioni si deve far riferimento ad un'altra pagina e quindi è necessario creare una nuova funzione di scraping, denominata `movie_info`; i parametri in ingresso sono:
# * `url`: è lo stesso url utilizzato nelle altre funzioni, in questo caso non verrà iterato.
# * `director_list`: in questa lista verranno salvati i nomi dei direttori.
# * `writer_list`: sono salvati i nomi degli scrittori dei copioni.
# * `actor_list`: sono salvati i nomi degli attori.
# * `fict_actor_list`: sono salvati i nomi dei personaggi interpretati dagli attori.
# * `title_list`: anche questa volta il nome del film sarà usato come chiave per un futuro merge.
#
# Il codice inizia con la creazione di un oggetto browser e l'accesso alla lista dei $250$ film più popolari di un certo anno. I successivi step sono:
# * Il salvataggio del titolo del film, identico a quanto effettuato in precedenza.
# * Si estraggono i collegamenti ipertestuali di ogni film, da essi si modifica l'url in modo tale da accedere alla pagina con le info delle personalità legate al film.
# * Sono inizializzate le liste temporanee in cui saranno salvati gli elementi e alla fine di un'iterazione esse saranno aggiunte alle liste passate in input.
# * Per ogni film si apre una nuova finestra e in questa si cercano le informazioni necessarie sempre tramite l'`xpath`. La lunghezza delle iterazioni dipende dalle informazioni da ricercare, ad esempio per gli attori si cercheranno tanti elementi, per i/il direttori/e meno.
#
# Gli output sono delle liste in cui ogni elemento è una lista contenente le personalità riferite ad una certa categoria.

# %%
def movie_info(url, director_list, writer_list, actor_list, fict_actor_list, title_list):
    movie = webdriver.Firefox(executable_path=r'D:/Scraping2/geckodriver.exe')
    movie.get(url)
    
    for i in range(250):
        title = movie.find_element_by_xpath('/html/body/div[3]/div/div[2]/div[3]/div[1]/div/div[3]/div/div[' + str(i + 1) + ']/div[3]/h3/a')
        title2 = movie.find_element_by_xpath('/html/body/div[3]/div/div[2]/div[3]/div[1]/div/div[3]/div/div[' + str(i + 1) + ']/div[3]/h3/span[2]')
        
        title_list.append(title.text + ' ' + title2.text)
        
        xpath = '//*[@id="main"]/div/div[3]/div/div[' + str(i + 1) + ']/div[3]/h3/a'
        element = movie.find_element_by_xpath(xpath=xpath)
        href = element.get_attribute('href')
    
        temp_url = href.split('?')
        credits_url = temp_url[0] + "fullcredits?ref_=tt_ov_wr#writers/"
        
        temp_director_list = [] 
        temp_writer_list = []
        temp_actor_list = []
        temp_fict_actor_list = []
        
        movie2 = webdriver.Firefox(executable_path=r'D:/Scraping2/geckodriver.exe')
        movie2.get(credits_url)
        
        # direttore
        try:
            director = movie2.find_element_by_xpath("/html/body/div[3]/div/div[2]/div[3]/div[1]/div[1]/div[2]/table[1]/tbody/tr/td[1]/a")
            temp_director_list.append(director.text)
        except (NoSuchElementException, ElementNotInteractableException):
                temp_director_list.append("")
        
        # scrittori
        for i in range(5):
            try:
                writer = movie2.find_element_by_xpath("/html/body/div[3]/div/div[2]/div[3]/div[1]/div[1]/div[2]/table[2]/tbody/tr[" + str(i + 1) + "]/td[1]/a")
                temp_writer_list.append(writer.text)
            except (NoSuchElementException, ElementNotInteractableException):
                pass
            
        if len(writer_list) == 0:
            temp_writer_list.append("")
        
        # attori
        for i in range(10):
            try:
                actor = movie2.find_element_by_xpath("/html/body/div[3]/div/div[2]/div[3]/div[1]/div[1]/div[2]/table[3]/tbody/tr[" + str(i + 1) + "]/td[2]/a")
                fict_actor = movie2.find_element_by_xpath("/html/body/div[3]/div/div[2]/div[3]/div[1]/div[1]/div[2]/table[3]/tbody/tr[" + str(i + 1) + "]/td[4]/a")
                temp_actor_list.append(actor.text)
                temp_fict_actor_list.append(fict_actor.text)
            
            except (NoSuchElementException, ElementNotInteractableException):
                pass
        if len(actor_list) == 0:
            temp_actor_list.append("")
        if len(fict_actor_list) == 0:
            temp_fict_actor_list.append("")
            
        director_list.append(temp_director_list)
        writer_list.append(temp_writer_list)
        actor_list.append(temp_actor_list)
        fict_actor_list.append(temp_fict_actor_list)
        
        movie2.quit()
        
    movie.quit()
    
    return(director_list, writer_list, actor_list, fict_actor_list, title_list)

# %%
director_list = []
writer_list = []
actor_list = []
fict_actor_list = []
title_list = []

# %%
url = 'https://www.imdb.com/search/title/?title_type=feature&release_date=1995-01-01,1995-12-31&genres=drama&count=250'
(director, writer, actor, fict_actor, title) = movie_info(url,
                                                          director_list=director_list,
                                                          writer_list=writer_list,
                                                          actor_list=actor_list,
                                                          fict_actor_list=fict_actor_list,
                                                          title_list=title_list)

# %% [markdown]
# <font size=3>
#
# Sempre tramite `piclke` le liste sono salvate per poi essere caricate successivamente. Nonostante il compito di estrarre queste informazioni non richiedesse un tempo eccessivo, il codice è stato fatto girare su più notebook differenti e quindi per ottenere delle liste complete si dovranno caricare gli altri file e unirli assieme.

# %%
os.chdir('D:/Scraping')
with open('output_director', 'wb') as fp:
    pickle.dump(director_list, fp)
    
with open('output_writer', 'wb') as fp2:
    pickle.dump(writer_list, fp2)
    
with open('output_actor', 'wb') as fp3:
    pickle.dump(actor_list, fp3)
    
with open('output_fict_actor', 'wb') as fp4:
    pickle.dump(fict_actor_list, fp4)
    
with open('output_title', 'wb') as fp5:
    pickle.dump(title_list, fp5)

# %% [markdown]
# <br></br>
# ## [5.1 Merge Info](#5.1)

# %% [markdown]
# <font size=3>
#
# Lo scraping delle info ha funzionato a dovere anche se in alcuni casi se l'attore di un film non possiede una pagina personale sul sito, la formattazione risulta divera e l'algoritmo non è stato in grado di ottenere le informazioni. Si tratta per lo più di attori poco conosciuto e che hanno recitato in film non molto popolari, quindi i dati mancanti sono comunque ristretti. <br></br>
# Per due anni, il $2019$ e il $1995$, il codice ha dato problemi con il risultato di avere delle informazioni duplicate:
# * Per il $2019$ i doppioni riguardavano le prime osservazioni. Si è trovata questa anomalia confrontando la lunghezza di tutte le liste caricate e si sono subito trovati questi duplicati all'inizio della prima lista. Per tutte le informazioni le prime $24$ osservazioni erano ridondanti con l'eccezione dei titoli dove erano $25$.
# * Per il $1995$ la situazione era più complicata in quanto non c'era un pattern preciso che permettesse di individuare facilmente i duplicati, quindi si è proceduto a raccogliere di nuovo tutte le informazioni per quell'anno.
#
# Il caricamento dei file avviene come al solito tramite `pickle`, per vitare un codice lungo e ripetitivo si è provveduto a creare un ciclo in modo tale da poter leggere assieme tutte le liste di una certa categoria:
# * Gli indici sono stati messi in una lista, i file sono stati salvati in modo tale da variare solamente nell'ultimo carattere che rappresenta appunto il numero del file salvato, con l'eccezione del $1995$ come spiegato sopra.
# * Mediante la funzione `globals()` è possibile creare variabili all'interno del ciclo for con un nome comune e che variano per un elemento finale, in questo caso proprio l'indice del for che permette di accedere correttamente ai file.
# * Nel caso della prima lista viene effettuato uno slicing per rimuovere i duplicati.
#
# I risultati sono salvati in delle liste differenziate create in partenza.

# %%
director_files, writer_files, actor_files, fict_actor_files, title_files = ([] for i in range(5))
idx = [1, 2, 3, 4, 1995]
for i in idx:
    if i == 1:
        i = ""
    with open('output_director' + str(i), "rb") as director_file:
        globals()["director%s" % (str(i))] = pickle.load(director_file)
        if i == "":
            director = director[23:1523]
    
    with open('output_writer' + str(i), "rb") as writer_file:
        globals()["writer%s" % (str(i))] = pickle.load(writer_file)
        if i == "":
            writer = writer[23:1523]
        
    with open('output_actor' + str(i), "rb") as actor_file:
        globals()["actor%s" % (str(i))] = pickle.load(actor_file)
        if i == "":
            actor = actor[23:1523]
        
    with open('output_fict_actor' + str(i), "rb") as fict_actor_file:
        globals()["fict_actor%s" % (str(i))] = pickle.load(fict_actor_file)
        if i == "":
            fict_actor = fict_actor[23:1523]
        
    with open('output_title' + str(i), "rb") as title_file:
        globals()["title%s" % (str(i))] = pickle.load(title_file)
        if i == "":
            title = title[24:1524]
        
    director_files.append(globals()["director%s" % (str(i))])
    writer_files.append(globals()["writer%s" % (str(i))])
    actor_files.append(globals()["actor%s" % (str(i))])
    fict_actor_files.append(globals()["fict_actor%s" % (str(i))])
    title_files.append(globals()["title%s" % (str(i))])

# %% [markdown]
# <font size=3>
#
# Un controllo della lunghezza delle liste lette permette di confermare che tutti hanno lo stesso numero di elementi. La somma della prima lista e quella dell'ultima restituisce il valore di lunghezza di quelle intermedie.

# %%
for i in range(5):
    print(len(director_files[i]), len(writer_files[i]), len(actor_files[i]), len(fict_actor_files[i]), len(title_files[i]))
# Out:
# 1500 1500 1500 1500 1500
# 1750 1750 1750 1750 1750
# 1750 1750 1750 1750 1750
# 1750 1750 1750 1750 1750
# 250 250 250 250 250

# %% [markdown]
# Con la funzione `deepflatten` si ottiene una lista sola per categoria che viene trasformata in una colonna del dataframe. L'ultimo passaggio permette di riordinare le colonne in quanto di default sono messe in ordine alfabetico.

# %%
director_flatten = list(deepflatten(director_files, depth=1))
writer_flatten = list(deepflatten(writer_files, depth=1))
actor_flatten = list(deepflatten(actor_files, depth=1))
fict_actor_flatten = list(deepflatten(fict_actor_files, depth=1))
titles_flatten = list(deepflatten(title_files, depth=1))

df_info = pd.DataFrame({'Title':titles_flatten, 'Director':director_flatten, 'Writer':writer_flatten, 
                        'Actor':actor_flatten, 'Fict_actor':fict_actor_flatten})
df_info = df_info[["Title", "Director", "Actor", "Fict_actor", "Writer"]]
df_info.head()
# Out:
#                                    Title             Director  \
# 0                    The Irishman (2019)    [Martin Scorsese]
# 1   Cena con delitto - Knives Out (2019)       [Rian Johnson]
# 2  C'era una volta a... Hollywood (2019)  [Quentin Tarantino]
# 3                           Joker (2019)      [Todd Phillips]
# 4                        Ad Astra (2019)         [James Gray]
#
#                                                Actor  \
# 0  [Robert De Niro, Al Pacino, Joe Pesci, Harvey ...
# 1  [Daniel Craig, Chris Evans, Ana de Armas, Jami...
# 2  [Leonardo DiCaprio, Brad Pitt, Margot Robbie, ...
# 3  [Joaquin Phoenix, Robert De Niro, Zazie Beetz,...
# 4  [Brad Pitt, Tommy Lee Jones, Ruth Negga, Donal...
#
#                                           Fict_actor  \
# 0  [Frank Sheeran, Jimmy Hoffa, Russell Bufalino,...
# 1  [Benoit Blanc, Ransom Drysdale, Marta Cabrera,...
# 2  [Rick Dalton, Cliff Booth, Sharon Tate, Jay Se...
# 3  [Arthur Fleck, Murray Franklin, Sophie Dumond,...
# 4  [Roy McBride, H. Clifford McBride, Helen Lanto...
#
#                                               Writer
# 0                  [Charles Brandt, Steven Zaillian]
# 1                                     [Rian Johnson]
# 2                                [Quentin Tarantino]
# 3  [Todd Phillips, Scott Silver, Bob Kane, Bill F...
# 4                          [James Gray, Ethan Gross]

# %% [markdown]
# <br></br>
# ## [5.2 Salvataggio File](#5.2)

# %%
df_info.to_csv('imdb_info.csv', sep='\t')
#df_info = pd.read_csv("imdb_info.csv", delimiter='\t')
