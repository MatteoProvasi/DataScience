# %%
import os
os.chdir("C:\\path")

# %run -i "libraries.py"
# %run -i "functions.py"

# %% [markdown]
# # 1. File Reading

# %%
try:
    data = pd.read_csv("NYT-merge.csv", sep=";", encoding="UTF-8")
    datar.drop("Unnamed: 0", axis=1, inplace=True)
    print("Loaded comments: %s" %(len(data)))
    
except FileNotFoundError:
    print("Merge file not found, loading every .csv")
    
    articles_path = "C:\\Users\\Hp\\Desktop\\Public Project\\Articles\\*.csv"
    comments_path = "C:\\Users\\Hp\\Desktop\\Public Project\\Comments\\*.csv"
    articles_list = glob.glob(articles_path)
    comments_list = glob.glob(comments_path)

    
    # Loading data
    articles = get_articles(articles_path, articles_list)
    comments = get_comments(comments_path, comments_list)

    # Merge
    data = pd.merge(articles, comments, left_on="artID", right_on="comID", how="left").drop("comID", axis=1)

    
    data = data.dropna() # around 100k rows do not match any article ID
    data = data.reset_index()
    data = data.drop("index", axis=1)
    data = data[data.Keywords != ''] # remove empty keywords
    data = data.drop_duplicates(subset=["Comments"], keep="first")
    print("Loaded comments: %s" %(len(data)))
# Out:
# Loaded comments: 2040273

# %% [markdown]
# ## 1.1 Preparation

# %%
# Create dictionary and corpus for LDA
(key_dictionary, key_corpus, base_keywords) = prepare_lda(data["Keywords"])

# %% [markdown]
# # 2. LDA with grid search

# %%
# %%time
num_topic = [3, 4, 5, 6, 7, 8, 9, 10]
list_perplexity = []
list_top_topics = []
list_coherence = []

for topic in num_topic:
    
    # chunksize and iterations chosen after some tests
    ldamodel = gensim.models.LdaMulticore(key_corpus, id2word=key_dictionary, num_topics=topic, 
                                          workers=3, random_state=0, chunksize=100000, iterations=500)
    
    list_perplexity.append(ldamodel.log_perplexity(key_corpus, total_docs=len(key_corpus)))
    list_top_topics.append(ldamodel.top_topics(corpus=key_corpus, dictionary=key_dictionary, topn=10, coherence='u_mass'))
    
    coherence_model_lda = CoherenceModel(model=ldamodel, corpus=key_corpus, dictionary=key_dictionary, coherence='u_mass')
    coherence_lda = coherence_model_lda.get_coherence()
    list_coherence.append(coherence_lda)
    
    ldamodel.save('model-' + str(topic) + 'topic.gensim') # saving models
    
    # perplexity, coherence and top topics
    print("Model perplexity with", str(topic), " topics: ", 
          list_perplexity[-1], "\tCoherence Score: ", str(list_coherence[-1]))

# save a df from printing the top topics in details
lda_df = pd.DataFrame({"Num_topics":num_topic, "log_perplexity":list_perplexity,
                       "coherence":list_coherence, "Top_topics":list_top_topics})
print(lda_df)
# Out:
# Model perplexity with 3  topics:  -6.27055906475321 	Coherence Score:  -8.904744746944028
# Model perplexity with 4  topics:  -6.273841949631126 	Coherence Score:  -7.839636735084103
# Model perplexity with 5  topics:  -6.290800916586298 	Coherence Score:  -8.57770486394762
# Model perplexity with 6  topics:  -6.31968177006147 	Coherence Score:  -9.204861426995416
# Model perplexity with 7  topics:  -6.39035490703285 	Coherence Score:  -9.284320430552762
# Model perplexity with 8  topics:  -6.468102714817781 	Coherence Score:  -9.779813053130422
# Model perplexity with 9  topics:  -6.57297240150778 	Coherence Score:  -9.686333776043528
# Model perplexity with 10  topics:  -6.714813899974233 	Coherence Score:  -9.832438748547872
#    Num_topics                                         Top_topics  coherence  \
# 0           3  [([(0.12381317, 'Trump, Donald J'), (0.1234036...  -8.904745
# 1           4  [([(0.11763931, 'Trump, Donald J'), (0.1069188...  -7.839637
# 2           5  [([(0.13376634, 'United States Politics and Go...  -8.577705
# 3           6  [([(0.13699321, 'United States Politics and Go...  -9.204861
# 4           7  [([(0.12441089, 'Trump, Donald J'), (0.1116493...  -9.284320
# 5           8  [([(0.12602761, 'Trump, Donald J'), (0.1135816...  -9.779813
# 6           9  [([(0.12822667, 'Trump, Donald J'), (0.1131941...  -9.686334
# 7          10  [([(0.12961261, 'Trump, Donald J'), (0.1159649...  -9.832439
#
#    log_perplexity
# 0       -6.270559
# 1       -6.273842
# 2       -6.290801
# 3       -6.319682
# 4       -6.390355
# 5       -6.468103
# 6       -6.572972
# 7       -6.714814
# Wall time: 3h 7min 33s

# %% [markdown]
# ## 2.1 Plot topics

# %%
for i in range(len(lda_df)):
    for topic in lda_df["Top_topics"].iloc[i]:
        print("topic")
        for key in topic[0]:
            print(key, end="\n")
    print("End lda model \n\n\n")
# Out:
# topic
# (0.12381317, 'Trump, Donald J')
# (0.12340368, 'United States Politics and Government')
# (0.0359334, 'Republican Party')
# (0.027915658, 'Russia')
# (0.023131058, 'House of Representatives')
# (0.0227823, 'Presidential Election of 2016')
# (0.019189112, 'United States International Relations')
# (0.017299274, 'Health Insurance and Managed Care')
# (0.016083615, 'Patient Protection and Affordable Care Act (2010)')
# (0.01552975, 'Federal Bureau of Investigation')
# topic
# (0.04557359, 'Trump, Donald J')
# (0.028926758, 'United States Politics and Government')
# (0.01755291, 'Gun Control')
# (0.01725678, 'Immigration and Emigration')
# (0.015975377, 'School Shootings and Armed Attacks')
# (0.015589056, 'Politics and Government')
# (0.013539489, 'United States International Relations')
# (0.011817302, 'Parkland, Fla, Shooting (2018)')
# (0.011557237, 'Refugees and Displaced Persons')
# (0.011079109, 'Executive Orders and Memorandums')
# topic
# (0.08116547, 'Trump, Donald J')
# (0.066884704, 'United States Politics and Government')
# (0.026789105, 'Comey, James B')
# (0.020617424, 'Federal Bureau of Investigation')
# (0.02008824, 'Global Warming')
# (0.012726094, 'Appointments and Executive Changes')
# (0.012042489, 'United Nations Framework Convention on Climate Change')
# (0.010235395, 'United States International Relations')
# (0.009941624, 'Presidential Election of 2016')
# (0.009294229, 'Greenhouse Gas Emissions')
# End lda model
#
#
#
# topic
# (0.11763931, 'Trump, Donald J')
# (0.10691889, 'United States Politics and Government')
# (0.044483952, 'Russia')
# (0.033534482, 'Presidential Election of 2016')
# (0.026616655, 'Federal Bureau of Investigation')
# (0.025355112, 'United States International Relations')
# (0.018743178, 'Comey, James B')
# (0.01845315, 'Cyberwarfare and Defense')
# (0.017601352, 'Republican Party')
# (0.016933408, 'Russian Interference in 2016 US Elections and Ties to Trump Associates')
# topic
# (0.12146491, 'United States Politics and Government')
# (0.1156555, 'Trump, Donald J')
# (0.04542708, 'Republican Party')
# (0.032121282, 'House of Representatives')
# (0.024904504, 'Health Insurance and Managed Care')
# (0.022740405, 'Patient Protection and Affordable Care Act (2010)')
# (0.021481333, 'Senate')
# (0.015778119, 'Law and Legislation')
# (0.015160486, 'Democratic Party')
# (0.014221165, 'Obama, Barack')
# topic
# (0.04167425, 'Trump, Donald J')
# (0.024142869, 'Immigration and Emigration')
# (0.022893764, 'United States Politics and Government')
# (0.02106846, 'Politics and Government')
# (0.015571103, 'Refugees and Displaced Persons')
# (0.014451928, 'Executive Orders and Memorandums')
# (0.013980864, 'United States International Relations')
# (0.012610459, 'New York City')
# (0.012094398, 'Women and Girls')
# (0.011793651, 'Terrorism')
# topic
# (0.07074912, 'Trump, Donald J')
# (0.05563177, 'United States Politics and Government')
# (0.027041381, 'Global Warming')
# (0.024709957, 'Federal Bureau of Investigation')
# (0.024588311, 'Comey, James B')
# (0.01660806, 'United Nations Framework Convention on Climate Change')
# (0.01303182, 'Greenhouse Gas Emissions')
# (0.012022729, 'United States International Relations')
# (0.011663943, 'Presidential Election of 2016')
# (0.010951708, 'Blacks')
# End lda model
#
#
#
# topic
# (0.13376634, 'United States Politics and Government')
# (0.12525636, 'Trump, Donald J')
# (0.051239863, 'Republican Party')
# (0.03518872, 'House of Representatives')
# (0.029121649, 'Health Insurance and Managed Care')
# (0.0262152, 'Patient Protection and Affordable Care Act (2010)')
# (0.022847036, 'Senate')
# (0.016926672, 'Law and Legislation')
# (0.016904373, 'Democratic Party')
# (0.016601007, 'Ryan, Paul D Jr')
# topic
# (0.122220345, 'Trump, Donald J')
# (0.109897085, 'United States Politics and Government')
# (0.046337258, 'Russia')
# (0.035505697, 'Presidential Election of 2016')
# (0.0294003, 'Federal Bureau of Investigation')
# (0.025286915, 'United States International Relations')
# (0.021058487, 'Comey, James B')
# (0.019194638, 'Cyberwarfare and Defense')
# (0.018054744, 'Russian Interference in 2016 US Elections and Ties to Trump Associates')
# (0.018047784, 'Republican Party')
# topic
# (0.046624, 'Trump, Donald J')
# (0.02553046, 'United States Politics and Government')
# (0.024772553, 'Politics and Government')
# (0.020586928, 'Immigration and Emigration')
# (0.020141507, 'United States International Relations')
# (0.013913852, 'Terrorism')
# (0.013682933, 'Refugees and Displaced Persons')
# (0.0122837825, 'France')
# (0.011587735, 'Elections')
# (0.011143182, 'Executive Orders and Memorandums')
# topic
# (0.08201912, 'Trump, Donald J')
# (0.06800616, 'United States Politics and Government')
# (0.031576704, 'Global Warming')
# (0.024546511, 'Comey, James B')
# (0.0231734, 'Federal Bureau of Investigation')
# (0.019467786, 'United Nations Framework Convention on Climate Change')
# (0.014814474, 'Greenhouse Gas Emissions')
# (0.013142866, 'Blacks')
# (0.012579777, 'United States International Relations')
# (0.011535768, 'Presidential Election of 2016')
# topic
# (0.040932626, 'Gun Control')
# (0.03923732, 'School Shootings and Armed Attacks')
# (0.029974353, 'Parkland, Fla, Shooting (2018)')
# (0.027575029, 'Women and Girls')
# (0.018082984, 'National Rifle Assn')
# (0.016095249, 'Trump, Donald J')
# (0.015240098, 'Sexual Harassment')
# (0.01313311, 'Immigration and Emigration')
# (0.011858266, 'Demonstrations, Protests and Riots')
# (0.01181091, 'Executive Orders and Memorandums')
# End lda model
#
#
#
# topic
# (0.13699321, 'United States Politics and Government')
# (0.127421, 'Trump, Donald J')
# (0.055745244, 'Republican Party')
# (0.038877986, 'House of Representatives')
# (0.03144805, 'Health Insurance and Managed Care')
# (0.028079433, 'Patient Protection and Affordable Care Act (2010)')
# (0.024888102, 'Senate')
# (0.018591633, 'Democratic Party')
# (0.016573193, 'Law and Legislation')
# (0.016443964, 'Ryan, Paul D Jr')
# topic
# (0.12429122, 'Trump, Donald J')
# (0.11075274, 'United States Politics and Government')
# (0.050554644, 'Russia')
# (0.037233133, 'Presidential Election of 2016')
# (0.03164486, 'Federal Bureau of Investigation')
# (0.02693182, 'United States International Relations')
# (0.02273773, 'Comey, James B')
# (0.021108525, 'Cyberwarfare and Defense')
# (0.019495618, 'Russian Interference in 2016 US Elections and Ties to Trump Associates')
# (0.01655018, 'Special Prosecutors (Independent Counsel)')
# topic
# (0.05181034, 'Trump, Donald J')
# (0.029418059, 'United States Politics and Government')
# (0.025018388, 'United States International Relations')
# (0.024286412, 'Politics and Government')
# (0.020825623, 'Immigration and Emigration')
# (0.01409639, 'Refugees and Displaced Persons')
# (0.012971712, 'France')
# (0.01186463, 'Terrorism')
# (0.011745014, 'Macron, Emmanuel (1977- )')
# (0.011424087, 'Executive Orders and Memorandums')
# topic
# (0.05022295, 'Gun Control')
# (0.047405034, 'School Shootings and Armed Attacks')
# (0.03568713, 'Parkland, Fla, Shooting (2018)')
# (0.027492583, 'Women and Girls')
# (0.021936506, 'National Rifle Assn')
# (0.016898038, 'Trump, Donald J')
# (0.014695961, 'Demonstrations, Protests and Riots')
# (0.012023095, 'Immigration and Emigration')
# (0.011032107, 'Executive Orders and Memorandums')
# (0.010891751, 'Refugees and Displaced Persons')
# topic
# (0.05952817, 'Trump, Donald J')
# (0.047225364, 'United States Politics and Government')
# (0.019959407, 'Fox News Channel')
# (0.014842833, 'Sexual Harassment')
# (0.0141039025, 'Immigration and Emigration')
# (0.01211055, 'Illegal Immigration')
# (0.011880982, 'Politics and Government')
# (0.0106040565, 'Television')
# (0.010406952, 'Ethics and Official Misconduct')
# (0.010189183, '#MeToo Movement')
# topic
# (0.08585418, 'Trump, Donald J')
# (0.073069215, 'United States Politics and Government')
# (0.033801936, 'Global Warming')
# (0.028393354, 'Comey, James B')
# (0.027480459, 'Federal Bureau of Investigation')
# (0.021348614, 'United Nations Framework Convention on Climate Change')
# (0.016218714, 'Greenhouse Gas Emissions')
# (0.013979802, 'Presidential Election of 2016')
# (0.012971555, 'Blacks')
# (0.012107102, 'Crossword Puzzles')
# End lda model
#
#
#
# topic
# (0.12441089, 'Trump, Donald J')
# (0.111649394, 'United States Politics and Government')
# (0.058027342, 'Russia')
# (0.0397546, 'Presidential Election of 2016')
# (0.033944193, 'Federal Bureau of Investigation')
# (0.027137319, 'United States International Relations')
# (0.025640959, 'Comey, James B')
# (0.024207069, 'Cyberwarfare and Defense')
# (0.020370893, 'Russian Interference in 2016 US Elections and Ties to Trump Associates')
# (0.017939452, 'Special Prosecutors (Independent Counsel)')
# topic
# (0.11406175, 'Trump, Donald J')
# (0.11290166, 'United States Politics and Government')
# (0.039667655, 'Republican Party')
# (0.035213884, 'House of Representatives')
# (0.029237604, 'Senate')
# (0.028585488, 'Patient Protection and Affordable Care Act (2010)')
# (0.028076818, 'Health Insurance and Managed Care')
# (0.022859383, 'Immigration and Emigration')
# (0.020788683, 'Law and Legislation')
# (0.016459467, 'Democratic Party')
# topic
# (0.13880278, 'United States Politics and Government')
# (0.13304752, 'Trump, Donald J')
# (0.046163436, 'Republican Party')
# (0.024560174, 'House of Representatives')
# (0.02446265, 'Obama, Barack')
# (0.022620002, 'Health Insurance and Managed Care')
# (0.018864721, 'Ryan, Paul D Jr')
# (0.0166159, 'Patient Protection and Affordable Care Act (2010)')
# (0.015585469, 'United States International Relations')
# (0.0155625995, 'Democratic Party')
# topic
# (0.037919026, 'Trump, Donald J')
# (0.030624593, 'Politics and Government')
# (0.02256791, 'United States International Relations')
# (0.01783755, 'United States Politics and Government')
# (0.01566339, 'France')
# (0.013785675, 'Macron, Emmanuel (1977- )')
# (0.013397509, 'European Union')
# (0.013178567, 'Elections')
# (0.012004436, 'Israel')
# (0.0110356165, 'Le Pen, Marine')
# topic
# (0.05707469, 'Gun Control')
# (0.05540144, 'School Shootings and Armed Attacks')
# (0.042112056, 'Parkland, Fla, Shooting (2018)')
# (0.025561186, 'National Rifle Assn')
# (0.023683174, 'Women and Girls')
# (0.017528158, 'Demonstrations, Protests and Riots')
# (0.012701266, 'Education (K-12)')
# (0.012029629, 'Families and Family Life')
# (0.011771952, 'Parenting')
# (0.010333844, 'Mental Health and Disorders')
# topic
# (0.043866307, 'Trump, Donald J')
# (0.032530483, 'United States Politics and Government')
# (0.023156065, 'Fox News Channel')
# (0.019628981, 'Sexual Harassment')
# (0.019610373, 'Deferred Action for Childhood Arrivals')
# (0.016758094, 'Television')
# (0.014956947, '#MeToo Movement')
# (0.013799949, 'Politics and Government')
# (0.013010196, 'Illegal Immigration')
# (0.012795651, 'Ethics and Official Misconduct')
# topic
# (0.083059, 'Trump, Donald J')
# (0.07058482, 'United States Politics and Government')
# (0.0392594, 'Global Warming')
# (0.032334406, 'Comey, James B')
# (0.030552298, 'Federal Bureau of Investigation')
# (0.0252915, 'United Nations Framework Convention on Climate Change')
# (0.01886501, 'Greenhouse Gas Emissions')
# (0.014455555, 'Crossword Puzzles')
# (0.013929507, 'Presidential Election of 2016')
# (0.0137669435, 'United States International Relations')
# End lda model
#
#
#
# topic
# (0.12602761, 'Trump, Donald J')
# (0.11358166, 'United States Politics and Government')
# (0.059460137, 'Russia')
# (0.040847994, 'Presidential Election of 2016')
# (0.035132587, 'Federal Bureau of Investigation')
# (0.029122846, 'United States International Relations')
# (0.026386162, 'Comey, James B')
# (0.024719616, 'Cyberwarfare and Defense')
# (0.021881768, 'Russian Interference in 2016 US Elections and Ties to Trump Associates')
# (0.018157031, 'Special Prosecutors (Independent Counsel)')
# topic
# (0.11852043, 'Trump, Donald J')
# (0.11531201, 'United States Politics and Government')
# (0.04072455, 'Republican Party')
# (0.0363192, 'House of Representatives')
# (0.030519223, 'Senate')
# (0.027385578, 'Patient Protection and Affordable Care Act (2010)')
# (0.025802856, 'Health Insurance and Managed Care')
# (0.02341875, 'Immigration and Emigration')
# (0.019719848, 'Law and Legislation')
# (0.018061161, 'Democratic Party')
# topic
# (0.14385019, 'United States Politics and Government')
# (0.13595562, 'Trump, Donald J')
# (0.046961278, 'Republican Party')
# (0.02522105, 'Health Insurance and Managed Care')
# (0.024852918, 'Obama, Barack')
# (0.024766544, 'House of Representatives')
# (0.017985763, 'Ryan, Paul D Jr')
# (0.01773785, 'Patient Protection and Affordable Care Act (2010)')
# (0.015635833, 'United States International Relations')
# (0.01444828, 'Democratic Party')
# topic
# (0.062464997, 'Gun Control')
# (0.062356707, 'School Shootings and Armed Attacks')
# (0.047139764, 'Parkland, Fla, Shooting (2018)')
# (0.029034918, 'National Rifle Assn')
# (0.022780517, 'Women and Girls')
# (0.019042198, 'Demonstrations, Protests and Riots')
# (0.012688604, 'Trump, Donald J')
# (0.012063067, 'Mental Health and Disorders')
# (0.011935781, 'Education (K-12)')
# (0.011515308, 'Firearms')
# topic
# (0.044002756, 'Trump, Donald J')
# (0.03312386, 'Politics and Government')
# (0.02467349, 'United States International Relations')
# (0.022066861, 'United States Politics and Government')
# (0.016490981, 'France')
# (0.015150167, 'Macron, Emmanuel (1977- )')
# (0.014461379, 'Elections')
# (0.0134407645, 'European Union')
# (0.0128459, 'Israel')
# (0.011618363, 'Le Pen, Marine')
# topic
# (0.026870532, 'Social Media')
# (0.024862614, 'Facebook Inc')
# (0.02247015, 'Supreme Court (US)')
# (0.018074045, 'Television')
# (0.016493674, 'Women and Girls')
# (0.015219006, 'Trump, Donald J')
# (0.014253753, 'Children and Childhood')
# (0.013190017, 'News and News Media')
# (0.012862787, 'Law and Legislation')
# (0.012596252, 'Data-Mining and Database Marketing')
# topic
# (0.051695637, 'Trump, Donald J')
# (0.04089316, 'United States Politics and Government')
# (0.02423581, 'Fox News Channel')
# (0.02248658, 'Deferred Action for Childhood Arrivals')
# (0.021861697, 'Sexual Harassment')
# (0.017970596, '#MeToo Movement')
# (0.015569997, 'Ethics and Official Misconduct')
# (0.015110607, 'Illegal Immigration')
# (0.013570474, 'Politics and Government')
# (0.011131501, 'New York City')
# topic
# (0.09416762, 'Trump, Donald J')
# (0.08005874, 'United States Politics and Government')
# (0.04363683, 'Global Warming')
# (0.035353005, 'Comey, James B')
# (0.031703204, 'Federal Bureau of Investigation')
# (0.028394034, 'United Nations Framework Convention on Climate Change')
# (0.020884471, 'Greenhouse Gas Emissions')
# (0.017336382, 'Crossword Puzzles')
# (0.016056819, 'United States International Relations')
# (0.014063186, 'Colleges and Universities')
# End lda model
#
#
#
# topic
# (0.12822667, 'Trump, Donald J')
# (0.113194145, 'United States Politics and Government')
# (0.062547915, 'Russia')
# (0.042751893, 'Presidential Election of 2016')
# (0.036640234, 'Federal Bureau of Investigation')
# (0.02926457, 'United States International Relations')
# (0.027657451, 'Comey, James B')
# (0.026129922, 'Cyberwarfare and Defense')
# (0.023364477, 'Russian Interference in 2016 US Elections and Ties to Trump Associates')
# (0.019420754, 'Special Prosecutors (Independent Counsel)')
# topic
# (0.1221106, 'Trump, Donald J')
# (0.11804709, 'United States Politics and Government')
# (0.042635623, 'Republican Party')
# (0.03890846, 'House of Representatives')
# (0.032802787, 'Senate')
# (0.028644895, 'Patient Protection and Affordable Care Act (2010)')
# (0.02665922, 'Health Insurance and Managed Care')
# (0.023410827, 'Immigration and Emigration')
# (0.020632196, 'Law and Legislation')
# (0.016263464, 'Democratic Party')
# topic
# (0.14482418, 'United States Politics and Government')
# (0.13994478, 'Trump, Donald J')
# (0.04778492, 'Republican Party')
# (0.029442394, 'Health Insurance and Managed Care')
# (0.027692733, 'Obama, Barack')
# (0.027046654, 'House of Representatives')
# (0.021136034, 'Patient Protection and Affordable Care Act (2010)')
# (0.01942414, 'Ryan, Paul D Jr')
# (0.017915547, 'United States International Relations')
# (0.012659734, 'Appointments and Executive Changes')
# topic
# (0.0700573, 'Gun Control')
# (0.069638334, 'School Shootings and Armed Attacks')
# (0.052712936, 'Parkland, Fla, Shooting (2018)')
# (0.032454286, 'National Rifle Assn')
# (0.018613843, 'Demonstrations, Protests and Riots')
# (0.0177494, 'Women and Girls')
# (0.015310789, 'Trump, Donald J')
# (0.015009885, 'Mental Health and Disorders')
# (0.012997765, 'Firearms')
# (0.010682451, 'Youth')
# topic
# (0.044759348, 'Trump, Donald J')
# (0.038853597, 'Politics and Government')
# (0.029484022, 'United States International Relations')
# (0.018919766, 'France')
# (0.018118657, 'United States Politics and Government')
# (0.017369144, 'Macron, Emmanuel (1977- )')
# (0.016596586, 'Elections')
# (0.015391786, 'European Union')
# (0.014639742, 'Israel')
# (0.013185888, 'Le Pen, Marine')
# topic
# (0.08019142, 'United States Politics and Government')
# (0.061414693, 'Trump, Donald J')
# (0.027119035, 'Democratic Party')
# (0.026418062, 'Elections, House of Representatives')
# (0.022643417, 'Women and Girls')
# (0.02084095, 'Labor and Jobs')
# (0.015264834, 'Midterm Elections (2018)')
# (0.015100112, 'Republican Party')
# (0.014728219, 'Global Warming')
# (0.014115898, 'United States Economy')
# topic
# (0.02905207, 'Social Media')
# (0.026239999, 'Facebook Inc')
# (0.025733178, 'Supreme Court (US)')
# (0.021145951, 'Television')
# (0.016825035, 'Trump, Donald J')
# (0.015160096, 'Children and Childhood')
# (0.014859847, 'News and News Media')
# (0.013916718, 'Law and Legislation')
# (0.013538518, 'Data-Mining and Database Marketing')
# (0.013520975, 'Cambridge Analytica')
# topic
# (0.058711663, 'Trump, Donald J')
# (0.042084612, 'United States Politics and Government')
# (0.024916528, 'Fox News Channel')
# (0.024592623, 'Deferred Action for Childhood Arrivals')
# (0.023266433, 'Sexual Harassment')
# (0.018536689, 'Ethics and Official Misconduct')
# (0.017818786, '#MeToo Movement')
# (0.016871348, 'Illegal Immigration')
# (0.014961865, 'New York City')
# (0.012875198, 'Immigration and Emigration')
# topic
# (0.09906168, 'Trump, Donald J')
# (0.08243528, 'United States Politics and Government')
# (0.04193621, 'Comey, James B')
# (0.039003015, 'Federal Bureau of Investigation')
# (0.03672514, 'Global Warming')
# (0.03203079, 'United Nations Framework Convention on Climate Change')
# (0.019888055, 'Crossword Puzzles')
# (0.017846752, 'United States International Relations')
# (0.017433902, 'Greenhouse Gas Emissions')
# (0.014909385, 'Clinton, Hillary Rodham')
# End lda model
#
#
#
# topic
# (0.12961261, 'Trump, Donald J')
# (0.115964994, 'United States Politics and Government')
# (0.06569561, 'Russia')
# (0.044537965, 'Presidential Election of 2016')
# (0.036905743, 'Federal Bureau of Investigation')
# (0.029953772, 'United States International Relations')
# (0.027859667, 'Comey, James B')
# (0.02753243, 'Cyberwarfare and Defense')
# (0.024001312, 'Russian Interference in 2016 US Elections and Ties to Trump Associates')
# (0.019989481, 'Special Prosecutors (Independent Counsel)')
# topic
# (0.12521254, 'Trump, Donald J')
# (0.122766316, 'United States Politics and Government')
# (0.044533264, 'Republican Party')
# (0.041298594, 'House of Representatives')
# (0.03430404, 'Senate')
# (0.030073509, 'Patient Protection and Affordable Care Act (2010)')
# (0.027389226, 'Health Insurance and Managed Care')
# (0.023582846, 'Immigration and Emigration')
# (0.020356815, 'Law and Legislation')
# (0.016542846, 'Democratic Party')
# topic
# (0.14457636, 'United States Politics and Government')
# (0.13996588, 'Trump, Donald J')
# (0.048310086, 'Republican Party')
# (0.029729443, 'Health Insurance and Managed Care')
# (0.029444417, 'Obama, Barack')
# (0.02672832, 'House of Representatives')
# (0.021470984, 'Patient Protection and Affordable Care Act (2010)')
# (0.02010027, 'Ryan, Paul D Jr')
# (0.019256556, 'United States International Relations')
# (0.012998444, 'Appointments and Executive Changes')
# topic
# (0.07620345, 'School Shootings and Armed Attacks')
# (0.072332114, 'Gun Control')
# (0.057638064, 'Parkland, Fla, Shooting (2018)')
# (0.035470314, 'National Rifle Assn')
# (0.019969573, 'Demonstrations, Protests and Riots')
# (0.01631838, 'Mental Health and Disorders')
# (0.016072974, 'Trump, Donald J')
# (0.0142727485, 'Firearms')
# (0.012736607, 'Youth')
# (0.012521865, 'Women and Girls')
# topic
# (0.048799854, 'Trump, Donald J')
# (0.041661575, 'Politics and Government')
# (0.03222724, 'United States International Relations')
# (0.020686371, 'France')
# (0.01940837, 'United States Politics and Government')
# (0.019009156, 'Macron, Emmanuel (1977- )')
# (0.01790578, 'Elections')
# (0.017698983, 'European Union')
# (0.015434455, 'Israel')
# (0.014391739, 'Le Pen, Marine')
# topic
# (0.08672563, 'United States Politics and Government')
# (0.06755189, 'Trump, Donald J')
# (0.027351037, 'Democratic Party')
# (0.026013833, 'Elections, House of Representatives')
# (0.02413206, 'Women and Girls')
# (0.02124286, 'Labor and Jobs')
# (0.016097538, 'Republican Party')
# (0.016022166, 'Global Warming')
# (0.014971386, 'Midterm Elections (2018)')
# (0.013732772, 'United States Economy')
# topic
# (0.039391115, 'Trump, Donald J')
# (0.037683815, 'News and News Media')
# (0.032537922, 'Television')
# (0.029238012, 'Sexual Harassment')
# (0.022389203, 'Fox News Channel')
# (0.021154268, 'Women and Girls')
# (0.018144192, 'United States Politics and Government')
# (0.013670969, '#MeToo Movement')
# (0.012113286, 'Blacks')
# (0.011615885, 'Marriages')
# topic
# (0.06405931, 'Trump, Donald J')
# (0.047621075, 'United States Politics and Government')
# (0.027909372, 'Deferred Action for Childhood Arrivals')
# (0.020686485, 'Illegal Immigration')
# (0.01917901, 'Ethics and Official Misconduct')
# (0.017014831, 'Immigration and Emigration')
# (0.014925359, 'New York City')
# (0.013634185, 'Fox News Channel')
# (0.012728248, 'Politics and Government')
# (0.011567747, 'United States')
# topic
# (0.031840656, 'Social Media')
# (0.03027123, 'Supreme Court (US)')
# (0.029797712, 'Facebook Inc')
# (0.020316597, 'Trump, Donald J')
# (0.018661154, 'United States Politics and Government')
# (0.016328795, 'Data-Mining and Database Marketing')
# (0.015566904, 'Cambridge Analytica')
# (0.015259616, 'Law and Legislation')
# (0.015225186, 'Gorsuch, Neil M')
# (0.012727864, 'Children and Childhood')
# topic
# (0.105103515, 'Trump, Donald J')
# (0.08706756, 'United States Politics and Government')
# (0.046355583, 'Comey, James B')
# (0.04343319, 'Federal Bureau of Investigation')
# (0.037486326, 'Global Warming')
# (0.03378912, 'United Nations Framework Convention on Climate Change')
# (0.020824568, 'Crossword Puzzles')
# (0.019555956, 'United States International Relations')
# (0.016657464, 'Greenhouse Gas Emissions')
# (0.015827594, 'Clinton, Hillary Rodham')
# End lda model
