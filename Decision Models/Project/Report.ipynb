# %% [markdown]
# # Santa's Uncertain Bags

# %%
# %load_ext autotime
import numpy as np
import operator
import pandas as pd
import os
import time

os.chdir("C:\\path")
# Out:
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 9.42 ms

# %% [markdown]
# ## Generazione casuale dei pesi su RStudio

# %% [markdown]
# library(stringr) <br>
# library(triangle)
#
# gift = read.csv('gifts.csv', sep = ",", header = TRUE) <br>
# gift\$Toy <- factor(str_extract(gift$GiftId, pattern = "[a-z]+"))
#
# sample_ball = function(n) pmax(0, 1 + rnorm(n = n, mean = 1, sd = 0.3)) <br>
# sample_bike = function(n) pmax(0, rnorm(n = n, mean = 20, sd = 10)) <br>
# sample_blocks = function(n) if(n == 0) return(numeric(0)) else return(rtriangle(n = n, a = 5, c = 10, b = 20)) <br>
# sample_book = function(n) rchisq(n = n, df = 2) <br>
# sample_coal = function(n) 47 \* rbeta(n = n, shape1 = 0.5, shape2 = 0.5) <br>
# sample_doll = function(n) rgamma(n = n, shape = 5, rate = 1) <br>
# sample_gloves = function(n) runif(n = n, min = 0, max = 1) + (runif(n = n, min = 0, max = 1) < 0.3) * 3 <br>
# sample_horse = function(n) pmax(0, rnorm(n = n, mean = 5, sd = 2)) <br>
# sample_train = function(n) pmax(0, rnorm(n = n, mean = 10, sd = 5)) <br>
#
# set.seed(1234)
# gift\$Weight = sapply(gift\$Toy, function(x) do.call(paste("sample", x, sep = "_"), as.list(1)))
#
# write.csv(x = gift, file = "Santa's gifts.csv")

# %% [markdown]
# ## Upload del dataset con i pesi casuali

# %%
gift = pd.read_csv("Santa's gifts.csv", sep = ",", index_col = 0)
gift.head()
# Out:
#     GiftId    Toy    Weight
# 1  horse_0  horse  2.585869
# 2  horse_1  horse  5.554858
# 3  horse_2  horse  7.168882
# 4  horse_3  horse  0.308605
# 5  horse_4  horse  5.858249
# time: 31.7 ms

# %%
print('Le osservazioni nel dataset sono: %s' %(len(gift)))
# Out:
# Le osservazioni nel dataset sono: 7166
# time: 1.98 ms

# %% [markdown]
# ## Rimozione dei pesi superiori a 50 lb e nulli

# %%
gift = gift[gift['Weight'] > 0]
print('Dopo aver elminato le osservazioni con peso nullo, le osservazioni rimanenti sono: %s' %(len(gift)))
gift = gift[gift['Weight'] < 50]
print('Dopo aver elminato le osservazioni con peso eccessivo, le osservazioni rimanenti sono: %s' %(len(gift)))
# Out:
# Dopo aver elminato le osservazioni con peso nullo, le osservazioni rimanenti sono: 7125
# Dopo aver elminato le osservazioni con peso eccessivo, le osservazioni rimanenti sono: 7124
# time: 12.4 ms

# %% [markdown]
# ## Frequenze relative dei giocattoli

# %%
gift['Toy'].value_counts(normalize = True)
# Out:
# book      0.168445
# ball      0.154408
# doll      0.140371
# blocks    0.140371
# horse     0.138546
# train     0.137704
# bike      0.068782
# gloves    0.028074
# coal      0.023302
# Name: Toy, dtype: float64

# %% [markdown]
# ## Creazione di dataset distinti per ogni giocattolo

# %%
ball = gift[gift['Toy'] == 'ball'].reset_index(drop = True).set_index('GiftId')
bike = gift[gift['Toy'] == 'bike'].reset_index(drop = True).set_index('GiftId')
blocks = gift[gift['Toy'] == 'blocks'].reset_index(drop = True).set_index('GiftId')
book = gift[gift['Toy'] == 'book'].reset_index(drop = True).set_index('GiftId')
coal = gift[gift['Toy'] == 'coal'].reset_index(drop = True).set_index('GiftId')
doll = gift[gift['Toy'] == 'doll'].reset_index(drop = True).set_index('GiftId')
gloves = gift[gift['Toy'] == 'gloves'].reset_index(drop = True).set_index('GiftId')
horse = gift[gift['Toy'] == 'horse'].reset_index(drop = True).set_index('GiftId')
train = gift[gift['Toy'] == 'train'].reset_index(drop = True).set_index('GiftId')
# Out:
# time: 63 ms

# %% [markdown]
# # Algoritmo di ottimizzazione

# %%
#Liste in cui saranno memorizzati i sacchi. Sono divise per l'ID, il tipo e il peso dell'oggetto
big_bag_ID = []
big_bag_Toy = []
big_bag_weight = []

#Contatori che sono necessari per l'algoritmo
cont_bag = 0
oggetti_inseriti = 0
data_vuoti = 0
sacchi_fermati_dogana = 0

#Dizionario con le frequenze dei giocattoli inseriti, ovviamente inizializzato con frequenze nulle.
diz_freq = {'ball':0, 'bike':0, 'blocks':0, 'book':0, 'coal':0, 'doll':0, 'gloves':0, 'horse':0, 'train':0}
while cont_bag < 1000: #Algoritmo continua fino a 1000 sacche
    copy = {}
    copy.update(diz_freq) #Copia del dizionario
    peso_sacco = 0
    
    #Liste in cui saranno memorizzati i singoli elementi che comporranno il sacco
    bag_ID = []
    bag_Toy = []
    bag_Weight = []
    
    while peso_sacco < 50:
        min_toy = min(copy, key=copy.get) #In caso di più frequenze minime prende il primo in ordine alfabetico
        #Se un sacco ha già 3 elementi cerco di non inserire oggetti che complessivamente sono già stati estratti frequentemente
        if len(bag_ID) > 2 and (copy[min_toy] > (oggetti_inseriti)/(9 - data_vuoti)):
            break
            
        #Se nella tipologia di giocattolo meno frequente non ne esiste uno che possa mantenere il peso < 50lb passo alla tiplogia successiva    
        if min(globals()[min_toy]['Weight']) + peso_sacco > 50:
            success = 0
            while success == 0 and len(copy) > 1: 
                del copy[min_toy]
                min_toy = min(copy, key=copy.get)
                if min(globals()[min_toy]['Weight']) + peso_sacco > 50:
                    success == 0
                else:
                    success == 1
             
        if len(copy) < 2:
            break
                
                
                
        campione = globals()[min_toy].sample(1) #Estraggo un giocattolo da quelli con freq minore o che garatisca un peso < 50lb
        peso_temp = campione['Weight'].iloc[0] #Peso dell'elemento estratto
        
        #Esiste almeno un elemento della tipologia che non fa superare le 50lb, estraggo casualmente fino a quando ne trovo uno
        if peso_sacco + peso_temp > 50:
            while peso_sacco + peso_temp > 50:
                campione = globals()[min_toy].sample(1) 
                peso_temp = campione['Weight'].iloc[0] 
          
        
        
        #Inserisco le informazioni del giocattolo nelle tre liste
        if campione.index.values[0] not in bag_ID:
            bag_ID.append(campione.index.values[0])
            bag_Toy.append(campione['Toy'].iloc[0])
            bag_Weight.append(campione['Weight'].iloc[0])
            
            #Aumento la frequenza del dizionario in base alla tipologia di giocattolo aggiunta
            diz_freq[min_toy] = diz_freq[min_toy] + 1
            copy[min_toy] = copy[min_toy] + 1
            
            #Aggiorno il peso del sacco
            peso_sacco = peso_sacco + peso_temp
            oggetti_inseriti = oggetti_inseriti + 1
            
            globals()[min_toy].drop(campione.index.values[0], axis = 0, inplace = True)
            if len(globals()[min_toy]) == 0:
                data_vuoti = data_vuoti + 1
                del diz_freq[min_toy]
                del copy[min_toy]
     
    
    #Se non è possibile raggiungere almeno 3 giocattoli in qualsiasi modo, il sacco viene eliminato   
    if len(copy) == 0 and len(bag_ID) < 3:
        print('Attenzione: il sacco è stato bloccato dalla polizia del Polo Nord! Alcuni bambini non riceveranno il loro regalo :(')
        sacchi_fermati_dogana = sacchi_fermati_dogana + 1
    
    
    #Nel caso il sacco abbia almeno 3 giocattoli e non sono soddisfatte le condizioni precedenti, le liste iniziali sono aggiornate con il sacco creato 
    if len(bag_ID) > 2:
        big_bag_ID.append(bag_ID)
        big_bag_Toy.append(bag_Toy)
        big_bag_weight.append(bag_Weight)
        cont_bag = cont_bag + 1
    
    
    #Print di controllo
        print('Oggetti inseriti: %s' %(bag_ID))
        print('Sacchi fermati alla dogana: %s' %(sacchi_fermati_dogana))
        print('Sacchi riempiti: %s' %(len(big_bag_ID)))        
        print('Conteggio: %s' %(cont_bag))
        print('%s \n' %(diz_freq))
# Out:
# Oggetti inseriti: ['ball_29', 'bike_243', 'blocks_420', 'book_802', 'coal_15', 'doll_30', 'gloves_96', 'horse_541', 'train_307']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 1
# Conteggio: 1
# {'ball': 1, 'bike': 1, 'blocks': 1, 'book': 1, 'coal': 1, 'doll': 1, 'gloves': 1, 'horse': 1, 'train': 1}
#
# Oggetti inseriti: ['ball_972', 'bike_181', 'blocks_535', 'book_763', 'coal_130', 'doll_412', 'gloves_190', 'horse_801', 'train_468']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 2
# Conteggio: 2
# {'ball': 2, 'bike': 2, 'blocks': 2, 'book': 2, 'coal': 2, 'doll': 2, 'gloves': 2, 'horse': 2, 'train': 2}
#
# Oggetti inseriti: ['ball_260', 'bike_198', 'blocks_278', 'book_1112', 'coal_158', 'doll_356', 'gloves_57']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 3
# Conteggio: 3
# {'ball': 3, 'bike': 3, 'blocks': 3, 'book': 3, 'coal': 3, 'doll': 3, 'gloves': 3, 'horse': 2, 'train': 2}
#
# Oggetti inseriti: ['horse_173', 'train_386', 'ball_510', 'bike_92', 'blocks_336', 'book_606', 'coal_26']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 4
# Conteggio: 4
# {'ball': 4, 'bike': 4, 'blocks': 4, 'book': 4, 'coal': 4, 'doll': 3, 'gloves': 3, 'horse': 3, 'train': 3}
#
# Oggetti inseriti: ['doll_857', 'gloves_144', 'horse_107', 'train_114', 'ball_622', 'bike_439', 'blocks_436', 'book_563', 'coal_128']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 5
# Conteggio: 5
# {'ball': 5, 'bike': 5, 'blocks': 5, 'book': 5, 'coal': 5, 'doll': 4, 'gloves': 4, 'horse': 4, 'train': 4}
#
# Oggetti inseriti: ['doll_35', 'gloves_87', 'horse_291', 'train_342', 'ball_1068', 'bike_28', 'blocks_662', 'book_1136', 'coal_152', 'doll_671', 'gloves_73', 'horse_635', 'train_477']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 6
# Conteggio: 6
# {'ball': 6, 'bike': 6, 'blocks': 6, 'book': 6, 'coal': 6, 'doll': 6, 'gloves': 6, 'horse': 6, 'train': 6}
#
# Oggetti inseriti: ['ball_1072', 'bike_417', 'blocks_271', 'book_68', 'coal_65', 'doll_342', 'gloves_34', 'horse_431', 'train_592']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 7
# Conteggio: 7
# {'ball': 7, 'bike': 7, 'blocks': 7, 'book': 7, 'coal': 7, 'doll': 7, 'gloves': 7, 'horse': 7, 'train': 7}
#
# Oggetti inseriti: ['ball_158', 'bike_458', 'blocks_533', 'book_212', 'coal_123', 'doll_401', 'gloves_114']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 8
# Conteggio: 8
# {'ball': 8, 'bike': 8, 'blocks': 8, 'book': 8, 'coal': 8, 'doll': 8, 'gloves': 8, 'horse': 7, 'train': 7}
#
# Oggetti inseriti: ['horse_523', 'train_12', 'ball_515', 'bike_497', 'blocks_346', 'book_312', 'coal_70', 'doll_470', 'gloves_148', 'horse_235', 'train_686']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 9
# Conteggio: 9
# {'ball': 9, 'bike': 9, 'blocks': 9, 'book': 9, 'coal': 9, 'doll': 9, 'gloves': 9, 'horse': 9, 'train': 9}
#
# Oggetti inseriti: ['ball_809', 'bike_317', 'blocks_835', 'book_505', 'coal_51', 'doll_592', 'gloves_39', 'horse_190', 'train_680', 'ball_805']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 10
# Conteggio: 10
# {'ball': 11, 'bike': 10, 'blocks': 10, 'book': 10, 'coal': 10, 'doll': 10, 'gloves': 10, 'horse': 10, 'train': 10}
#
# Oggetti inseriti: ['bike_274', 'blocks_603', 'book_781', 'coal_9', 'doll_364', 'gloves_49', 'horse_681', 'train_826']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 11
# Conteggio: 11
# {'ball': 11, 'bike': 11, 'blocks': 11, 'book': 11, 'coal': 11, 'doll': 11, 'gloves': 11, 'horse': 11, 'train': 11}
#
# Oggetti inseriti: ['ball_489', 'bike_150', 'blocks_904', 'book_688', 'coal_24']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 12
# Conteggio: 12
# {'ball': 12, 'bike': 12, 'blocks': 12, 'book': 12, 'coal': 12, 'doll': 11, 'gloves': 11, 'horse': 11, 'train': 11}
#
# Oggetti inseriti: ['doll_588', 'gloves_155', 'horse_768', 'train_710', 'ball_21', 'bike_218', 'blocks_494', 'book_321', 'coal_132', 'doll_703', 'gloves_104']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 13
# Conteggio: 13
# {'ball': 13, 'bike': 13, 'blocks': 13, 'book': 13, 'coal': 13, 'doll': 13, 'gloves': 13, 'horse': 12, 'train': 12}
#
# Oggetti inseriti: ['horse_280', 'train_266', 'ball_375', 'bike_158', 'blocks_138', 'book_542', 'coal_162', 'doll_307']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 14
# Conteggio: 14
# {'ball': 14, 'bike': 14, 'blocks': 14, 'book': 14, 'coal': 14, 'doll': 14, 'gloves': 13, 'horse': 13, 'train': 13}
#
# Oggetti inseriti: ['gloves_47', 'horse_575', 'train_102', 'ball_370', 'bike_224', 'blocks_578', 'book_389', 'coal_39', 'doll_661', 'gloves_93', 'horse_3']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 15
# Conteggio: 15
# {'ball': 15, 'bike': 15, 'blocks': 15, 'book': 15, 'coal': 15, 'doll': 15, 'gloves': 15, 'horse': 15, 'train': 14}
#
# Oggetti inseriti: ['train_851', 'ball_849', 'bike_108', 'blocks_478', 'book_498', 'coal_4', 'doll_419', 'gloves_102', 'horse_679', 'train_900']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 16
# Conteggio: 16
# {'ball': 16, 'bike': 16, 'blocks': 16, 'book': 16, 'coal': 16, 'doll': 16, 'gloves': 16, 'horse': 16, 'train': 16}
#
# Oggetti inseriti: ['ball_172', 'bike_250', 'blocks_243', 'book_494', 'coal_78', 'doll_41', 'gloves_66']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 17
# Conteggio: 17
# {'ball': 17, 'bike': 17, 'blocks': 17, 'book': 17, 'coal': 17, 'doll': 17, 'gloves': 17, 'horse': 16, 'train': 16}
#
# Oggetti inseriti: ['horse_346', 'train_600', 'ball_763', 'bike_261', 'blocks_857', 'book_945', 'coal_32', 'doll_269', 'gloves_15']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 18
# Conteggio: 18
# {'ball': 18, 'bike': 18, 'blocks': 18, 'book': 18, 'coal': 18, 'doll': 18, 'gloves': 18, 'horse': 17, 'train': 17}
#
# Oggetti inseriti: ['horse_199', 'train_498', 'ball_802', 'bike_415', 'blocks_222', 'book_140', 'coal_88', 'doll_611', 'gloves_184', 'horse_813', 'train_773']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 19
# Conteggio: 19
# {'ball': 19, 'bike': 19, 'blocks': 19, 'book': 19, 'coal': 19, 'doll': 19, 'gloves': 19, 'horse': 19, 'train': 19}
#
# Oggetti inseriti: ['ball_683', 'bike_67', 'blocks_14', 'book_874', 'coal_37', 'doll_747', 'gloves_81']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 20
# Conteggio: 20
# {'ball': 20, 'bike': 20, 'blocks': 20, 'book': 20, 'coal': 20, 'doll': 20, 'gloves': 20, 'horse': 19, 'train': 19}
#
# Oggetti inseriti: ['horse_81', 'train_956', 'ball_215', 'bike_186', 'blocks_763', 'book_745', 'coal_119', 'doll_940', 'gloves_197']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 21
# Conteggio: 21
# {'ball': 21, 'bike': 21, 'blocks': 21, 'book': 21, 'coal': 21, 'doll': 21, 'gloves': 21, 'horse': 20, 'train': 20}
#
# Oggetti inseriti: ['horse_473', 'train_5', 'ball_980', 'bike_468', 'blocks_713', 'book_69', 'coal_52', 'doll_723', 'gloves_181']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 22
# Conteggio: 22
# {'ball': 22, 'bike': 22, 'blocks': 22, 'book': 22, 'coal': 22, 'doll': 22, 'gloves': 22, 'horse': 21, 'train': 21}
#
# Oggetti inseriti: ['horse_613', 'train_450', 'ball_922', 'bike_120', 'blocks_161', 'book_958', 'coal_25']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 23
# Conteggio: 23
# {'ball': 23, 'bike': 23, 'blocks': 23, 'book': 23, 'coal': 23, 'doll': 22, 'gloves': 22, 'horse': 22, 'train': 22}
#
# Oggetti inseriti: ['doll_958', 'gloves_26', 'horse_395', 'train_951', 'ball_339', 'bike_360', 'blocks_802', 'book_1110', 'coal_53']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 24
# Conteggio: 24
# {'ball': 24, 'bike': 24, 'blocks': 24, 'book': 24, 'coal': 24, 'doll': 23, 'gloves': 23, 'horse': 23, 'train': 23}
#
# Oggetti inseriti: ['doll_54', 'gloves_4', 'horse_406', 'train_274', 'ball_843', 'bike_9']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 25
# Conteggio: 25
# {'ball': 25, 'bike': 25, 'blocks': 24, 'book': 24, 'coal': 24, 'doll': 24, 'gloves': 24, 'horse': 24, 'train': 24}
#
# Oggetti inseriti: ['blocks_334', 'book_1155', 'coal_150', 'doll_976', 'gloves_164', 'horse_435', 'train_907', 'ball_25', 'bike_139', 'blocks_472', 'book_588', 'coal_104', 'doll_650', 'gloves_75']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 26
# Conteggio: 26
# {'ball': 26, 'bike': 26, 'blocks': 26, 'book': 26, 'coal': 26, 'doll': 26, 'gloves': 26, 'horse': 25, 'train': 25}
#
# Oggetti inseriti: ['horse_378', 'train_794', 'ball_520', 'bike_199', 'blocks_248', 'book_677', 'coal_133']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 27
# Conteggio: 27
# {'ball': 27, 'bike': 27, 'blocks': 27, 'book': 27, 'coal': 27, 'doll': 26, 'gloves': 26, 'horse': 26, 'train': 26}
#
# Oggetti inseriti: ['doll_788', 'gloves_119', 'horse_202', 'train_394', 'ball_894', 'bike_77', 'blocks_418', 'book_55', 'coal_20', 'doll_815', 'gloves_156']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 28
# Conteggio: 28
# {'ball': 28, 'bike': 28, 'blocks': 28, 'book': 28, 'coal': 28, 'doll': 28, 'gloves': 28, 'horse': 27, 'train': 27}
#
# Oggetti inseriti: ['horse_392', 'train_364', 'ball_511', 'bike_358']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 29
# Conteggio: 29
# {'ball': 29, 'bike': 29, 'blocks': 28, 'book': 28, 'coal': 28, 'doll': 28, 'gloves': 28, 'horse': 28, 'train': 28}
#
# Oggetti inseriti: ['blocks_753', 'book_769', 'coal_91', 'doll_232', 'gloves_123', 'horse_464', 'train_149', 'ball_1026']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 30
# Conteggio: 30
# {'ball': 30, 'bike': 29, 'blocks': 29, 'book': 29, 'coal': 29, 'doll': 29, 'gloves': 29, 'horse': 29, 'train': 29}
#
# Oggetti inseriti: ['bike_303', 'blocks_151', 'book_1013', 'coal_112', 'doll_615', 'gloves_128', 'horse_350', 'train_525']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 31
# Conteggio: 31
# {'ball': 30, 'bike': 30, 'blocks': 30, 'book': 30, 'coal': 30, 'doll': 30, 'gloves': 30, 'horse': 30, 'train': 30}
#
# Oggetti inseriti: ['ball_488', 'bike_85', 'blocks_326', 'book_774', 'coal_83', 'doll_744']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 32
# Conteggio: 32
# {'ball': 31, 'bike': 31, 'blocks': 31, 'book': 31, 'coal': 31, 'doll': 31, 'gloves': 30, 'horse': 30, 'train': 30}
#
# Oggetti inseriti: ['gloves_36', 'horse_913', 'train_786', 'ball_495', 'bike_5', 'blocks_926', 'book_112', 'coal_17', 'doll_404', 'gloves_107']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 33
# Conteggio: 33
# {'ball': 32, 'bike': 32, 'blocks': 32, 'book': 32, 'coal': 32, 'doll': 32, 'gloves': 32, 'horse': 31, 'train': 31}
#
# Oggetti inseriti: ['horse_108', 'train_75', 'ball_27', 'bike_153', 'blocks_796', 'book_139', 'coal_42']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 34
# Conteggio: 34
# {'ball': 33, 'bike': 33, 'blocks': 33, 'book': 33, 'coal': 33, 'doll': 32, 'gloves': 32, 'horse': 32, 'train': 32}
#
# Oggetti inseriti: ['doll_68', 'gloves_29', 'horse_70', 'train_792', 'ball_774', 'bike_189', 'blocks_946', 'book_906']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 35
# Conteggio: 35
# {'ball': 34, 'bike': 34, 'blocks': 34, 'book': 34, 'coal': 33, 'doll': 33, 'gloves': 33, 'horse': 33, 'train': 33}
#
# Oggetti inseriti: ['coal_41', 'doll_361', 'gloves_65']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 36
# Conteggio: 36
# {'ball': 34, 'bike': 34, 'blocks': 34, 'book': 34, 'coal': 34, 'doll': 34, 'gloves': 34, 'horse': 33, 'train': 33}
#
# Oggetti inseriti: ['horse_569', 'train_361', 'ball_892', 'bike_100', 'blocks_441', 'book_442']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 37
# Conteggio: 37
# {'ball': 35, 'bike': 35, 'blocks': 35, 'book': 35, 'coal': 34, 'doll': 34, 'gloves': 34, 'horse': 34, 'train': 34}
#
# Oggetti inseriti: ['coal_101', 'doll_237', 'gloves_20', 'horse_720', 'train_860', 'ball_780', 'bike_421']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 38
# Conteggio: 38
# {'ball': 36, 'bike': 36, 'blocks': 35, 'book': 35, 'coal': 35, 'doll': 35, 'gloves': 35, 'horse': 35, 'train': 35}
#
# Oggetti inseriti: ['blocks_247', 'book_123', 'coal_118', 'doll_254', 'gloves_22', 'horse_729', 'train_830', 'ball_455', 'bike_357']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 39
# Conteggio: 39
# {'ball': 37, 'bike': 37, 'blocks': 36, 'book': 36, 'coal': 36, 'doll': 36, 'gloves': 36, 'horse': 36, 'train': 36}
#
# Oggetti inseriti: ['blocks_743', 'book_1153', 'coal_141', 'doll_47', 'gloves_40', 'horse_903', 'train_504', 'ball_801', 'bike_122']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 40
# Conteggio: 40
# {'ball': 38, 'bike': 38, 'blocks': 37, 'book': 37, 'coal': 37, 'doll': 37, 'gloves': 37, 'horse': 37, 'train': 37}
#
# Oggetti inseriti: ['blocks_900', 'book_1094', 'coal_58', 'doll_816', 'gloves_179', 'horse_259', 'train_335', 'ball_667', 'bike_275']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 41
# Conteggio: 41
# {'ball': 39, 'bike': 39, 'blocks': 38, 'book': 38, 'coal': 38, 'doll': 38, 'gloves': 38, 'horse': 38, 'train': 38}
#
# Oggetti inseriti: ['blocks_979', 'book_341', 'coal_136', 'doll_603', 'gloves_191', 'horse_546', 'train_746', 'ball_94', 'bike_473']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 42
# Conteggio: 42
# {'ball': 40, 'bike': 40, 'blocks': 39, 'book': 39, 'coal': 39, 'doll': 39, 'gloves': 39, 'horse': 39, 'train': 39}
#
# Oggetti inseriti: ['blocks_972', 'book_42', 'coal_140', 'doll_813', 'gloves_176', 'horse_413']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 43
# Conteggio: 43
# {'ball': 40, 'bike': 40, 'blocks': 40, 'book': 40, 'coal': 40, 'doll': 40, 'gloves': 40, 'horse': 40, 'train': 39}
#
# Oggetti inseriti: ['train_646', 'ball_250', 'bike_441']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 44
# Conteggio: 44
# {'ball': 41, 'bike': 41, 'blocks': 40, 'book': 40, 'coal': 40, 'doll': 40, 'gloves': 40, 'horse': 40, 'train': 40}
#
# Oggetti inseriti: ['blocks_193', 'book_517', 'coal_106', 'doll_745', 'gloves_183', 'horse_676', 'train_922', 'ball_534', 'bike_142']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 45
# Conteggio: 45
# {'ball': 42, 'bike': 42, 'blocks': 41, 'book': 41, 'coal': 41, 'doll': 41, 'gloves': 41, 'horse': 41, 'train': 41}
#
# Oggetti inseriti: ['blocks_969', 'book_27', 'coal_163', 'doll_132']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 46
# Conteggio: 46
# {'ball': 42, 'bike': 42, 'blocks': 42, 'book': 42, 'coal': 42, 'doll': 42, 'gloves': 41, 'horse': 41, 'train': 41}
#
# Oggetti inseriti: ['gloves_126', 'horse_175', 'train_470', 'ball_886', 'bike_324', 'blocks_240', 'book_37', 'coal_146']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 47
# Conteggio: 47
# {'ball': 43, 'bike': 43, 'blocks': 43, 'book': 43, 'coal': 43, 'doll': 42, 'gloves': 42, 'horse': 42, 'train': 42}
#
# Oggetti inseriti: ['doll_309', 'gloves_9', 'horse_533', 'train_785', 'ball_613', 'bike_73', 'blocks_99', 'book_1151', 'coal_61', 'doll_505', 'gloves_45']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 48
# Conteggio: 48
# {'ball': 44, 'bike': 44, 'blocks': 44, 'book': 44, 'coal': 44, 'doll': 44, 'gloves': 44, 'horse': 43, 'train': 43}
#
# Oggetti inseriti: ['horse_717', 'train_573', 'ball_209', 'bike_398', 'blocks_769', 'book_489']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 49
# Conteggio: 49
# {'ball': 45, 'bike': 45, 'blocks': 45, 'book': 45, 'coal': 44, 'doll': 44, 'gloves': 44, 'horse': 44, 'train': 44}
#
# Oggetti inseriti: ['coal_149', 'doll_391', 'gloves_135', 'horse_347']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 50
# Conteggio: 50
# {'ball': 45, 'bike': 45, 'blocks': 45, 'book': 45, 'coal': 45, 'doll': 45, 'gloves': 45, 'horse': 45, 'train': 44}
#
# Oggetti inseriti: ['train_76', 'ball_362', 'bike_176', 'blocks_772', 'book_706', 'coal_139', 'doll_694']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 51
# Conteggio: 51
# {'ball': 46, 'bike': 46, 'blocks': 46, 'book': 46, 'coal': 46, 'doll': 46, 'gloves': 45, 'horse': 45, 'train': 45}
#
# Oggetti inseriti: ['gloves_46', 'horse_494', 'train_382', 'ball_676', 'bike_202']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 52
# Conteggio: 52
# {'ball': 47, 'bike': 47, 'blocks': 46, 'book': 46, 'coal': 46, 'doll': 46, 'gloves': 46, 'horse': 46, 'train': 46}
#
# Oggetti inseriti: ['blocks_361', 'book_807', 'coal_92', 'doll_647', 'gloves_199', 'horse_834', 'train_15', 'ball_114', 'bike_99']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 53
# Conteggio: 53
# {'ball': 48, 'bike': 48, 'blocks': 47, 'book': 47, 'coal': 47, 'doll': 47, 'gloves': 47, 'horse': 47, 'train': 47}
#
# Oggetti inseriti: ['blocks_928', 'book_450', 'coal_73', 'doll_432', 'gloves_115', 'horse_564', 'train_990', 'ball_344', 'bike_24']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 54
# Conteggio: 54
# {'ball': 49, 'bike': 49, 'blocks': 48, 'book': 48, 'coal': 48, 'doll': 48, 'gloves': 48, 'horse': 48, 'train': 48}
#
# Oggetti inseriti: ['blocks_461', 'book_692', 'coal_28', 'doll_952', 'gloves_23', 'horse_874']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 55
# Conteggio: 55
# {'ball': 49, 'bike': 49, 'blocks': 49, 'book': 49, 'coal': 49, 'doll': 49, 'gloves': 49, 'horse': 49, 'train': 48}
#
# Oggetti inseriti: ['train_61', 'ball_390', 'bike_486', 'blocks_519', 'book_907', 'coal_151', 'doll_554', 'gloves_196', 'horse_380', 'train_595']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 56
# Conteggio: 56
# {'ball': 50, 'bike': 50, 'blocks': 50, 'book': 50, 'coal': 50, 'doll': 50, 'gloves': 50, 'horse': 50, 'train': 50}
#
# Oggetti inseriti: ['ball_164', 'bike_338', 'blocks_596', 'book_280', 'coal_29', 'doll_220', 'gloves_7']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 57
# Conteggio: 57
# {'ball': 51, 'bike': 51, 'blocks': 51, 'book': 51, 'coal': 51, 'doll': 51, 'gloves': 51, 'horse': 50, 'train': 50}
#
# Oggetti inseriti: ['horse_404', 'train_656', 'ball_14', 'bike_400', 'blocks_841', 'book_956', 'coal_99', 'doll_750', 'gloves_178', 'horse_820', 'train_681']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 58
# Conteggio: 58
# {'ball': 52, 'bike': 52, 'blocks': 52, 'book': 52, 'coal': 52, 'doll': 52, 'gloves': 52, 'horse': 52, 'train': 52}
#
# Oggetti inseriti: ['ball_581', 'bike_365', 'blocks_270', 'book_971', 'coal_135', 'doll_514', 'gloves_189', 'horse_411']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 59
# Conteggio: 59
# {'ball': 53, 'bike': 53, 'blocks': 53, 'book': 53, 'coal': 53, 'doll': 53, 'gloves': 53, 'horse': 53, 'train': 52}
#
# Oggetti inseriti: ['train_317', 'ball_82', 'bike_148']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 60
# Conteggio: 60
# {'ball': 54, 'bike': 54, 'blocks': 53, 'book': 53, 'coal': 53, 'doll': 53, 'gloves': 53, 'horse': 53, 'train': 53}
#
# Oggetti inseriti: ['blocks_389', 'book_775', 'coal_18', 'doll_178', 'gloves_67', 'horse_311', 'train_154', 'ball_751', 'bike_376', 'blocks_568', 'book_375']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 61
# Conteggio: 61
# {'ball': 55, 'bike': 55, 'blocks': 55, 'book': 55, 'coal': 54, 'doll': 54, 'gloves': 54, 'horse': 54, 'train': 54}
#
# Oggetti inseriti: ['coal_131', 'doll_988', 'gloves_61', 'horse_79', 'train_756']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 62
# Conteggio: 62
# {'ball': 55, 'bike': 55, 'blocks': 55, 'book': 55, 'coal': 55, 'doll': 55, 'gloves': 55, 'horse': 55, 'train': 55}
#
# Oggetti inseriti: ['ball_89', 'bike_443', 'blocks_285', 'book_1069', 'coal_161', 'doll_422', 'gloves_137']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 63
# Conteggio: 63
# {'ball': 56, 'bike': 56, 'blocks': 56, 'book': 56, 'coal': 56, 'doll': 56, 'gloves': 56, 'horse': 55, 'train': 55}
#
# Oggetti inseriti: ['horse_336', 'train_232', 'ball_118', 'bike_271', 'blocks_64', 'book_252']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 64
# Conteggio: 64
# {'ball': 57, 'bike': 57, 'blocks': 57, 'book': 57, 'coal': 56, 'doll': 56, 'gloves': 56, 'horse': 56, 'train': 56}
#
# Oggetti inseriti: ['coal_115', 'doll_984', 'gloves_28', 'horse_724', 'train_906', 'ball_440']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 65
# Conteggio: 65
# {'ball': 58, 'bike': 57, 'blocks': 57, 'book': 57, 'coal': 57, 'doll': 57, 'gloves': 57, 'horse': 57, 'train': 57}
#
# Oggetti inseriti: ['bike_373', 'blocks_16', 'book_594', 'coal_30', 'doll_667', 'gloves_109']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 66
# Conteggio: 66
# {'ball': 58, 'bike': 58, 'blocks': 58, 'book': 58, 'coal': 58, 'doll': 58, 'gloves': 58, 'horse': 57, 'train': 57}
#
# Oggetti inseriti: ['horse_320', 'train_892', 'ball_635', 'bike_79', 'blocks_72', 'book_295', 'coal_129', 'doll_159', 'gloves_19']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 67
# Conteggio: 67
# {'ball': 59, 'bike': 59, 'blocks': 59, 'book': 59, 'coal': 59, 'doll': 59, 'gloves': 59, 'horse': 58, 'train': 58}
#
# Oggetti inseriti: ['horse_636', 'train_911', 'ball_961', 'bike_246', 'blocks_778', 'book_901']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 68
# Conteggio: 68
# {'ball': 60, 'bike': 60, 'blocks': 60, 'book': 60, 'coal': 59, 'doll': 59, 'gloves': 59, 'horse': 59, 'train': 59}
#
# Oggetti inseriti: ['coal_157', 'doll_316', 'gloves_185', 'horse_577']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 69
# Conteggio: 69
# {'ball': 60, 'bike': 60, 'blocks': 60, 'book': 60, 'coal': 60, 'doll': 60, 'gloves': 60, 'horse': 60, 'train': 59}
#
# Oggetti inseriti: ['train_501', 'ball_709', 'bike_253', 'blocks_680', 'book_254']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 70
# Conteggio: 70
# {'ball': 61, 'bike': 61, 'blocks': 61, 'book': 61, 'coal': 60, 'doll': 60, 'gloves': 60, 'horse': 60, 'train': 60}
#
# Oggetti inseriti: ['coal_13', 'doll_142', 'gloves_132']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 71
# Conteggio: 71
# {'ball': 61, 'bike': 61, 'blocks': 61, 'book': 61, 'coal': 61, 'doll': 61, 'gloves': 61, 'horse': 60, 'train': 60}
#
# Oggetti inseriti: ['horse_630', 'train_783', 'ball_109', 'bike_76', 'blocks_995', 'book_1141']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 72
# Conteggio: 72
# {'ball': 62, 'bike': 62, 'blocks': 62, 'book': 62, 'coal': 61, 'doll': 61, 'gloves': 61, 'horse': 61, 'train': 61}
#
# Oggetti inseriti: ['coal_63', 'doll_192', 'gloves_177']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 73
# Conteggio: 73
# {'ball': 62, 'bike': 62, 'blocks': 62, 'book': 62, 'coal': 62, 'doll': 62, 'gloves': 62, 'horse': 61, 'train': 61}
#
# Oggetti inseriti: ['horse_40', 'train_997', 'ball_263', 'bike_34', 'blocks_687', 'book_623', 'coal_11', 'doll_768', 'gloves_122']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 74
# Conteggio: 74
# {'ball': 63, 'bike': 63, 'blocks': 63, 'book': 63, 'coal': 63, 'doll': 63, 'gloves': 63, 'horse': 62, 'train': 62}
#
# Oggetti inseriti: ['horse_620', 'train_804', 'ball_180', 'bike_377', 'blocks_94', 'book_1073']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 75
# Conteggio: 75
# {'ball': 64, 'bike': 64, 'blocks': 64, 'book': 64, 'coal': 63, 'doll': 63, 'gloves': 63, 'horse': 63, 'train': 63}
#
# Oggetti inseriti: ['coal_35', 'doll_704', 'gloves_88', 'horse_946', 'train_664', 'ball_1021', 'bike_457']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 76
# Conteggio: 76
# {'ball': 65, 'bike': 65, 'blocks': 64, 'book': 64, 'coal': 64, 'doll': 64, 'gloves': 64, 'horse': 64, 'train': 64}
#
# Oggetti inseriti: ['blocks_634', 'book_999', 'coal_85', 'doll_548', 'gloves_89', 'horse_127', 'train_275', 'ball_637']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 77
# Conteggio: 77
# {'ball': 66, 'bike': 65, 'blocks': 65, 'book': 65, 'coal': 65, 'doll': 65, 'gloves': 65, 'horse': 65, 'train': 65}
#
# Oggetti inseriti: ['bike_480', 'blocks_20', 'book_109', 'coal_125', 'doll_312', 'gloves_193']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 78
# Conteggio: 78
# {'ball': 66, 'bike': 66, 'blocks': 66, 'book': 66, 'coal': 66, 'doll': 66, 'gloves': 66, 'horse': 65, 'train': 65}
#
# Oggetti inseriti: ['horse_959', 'train_850', 'ball_142', 'bike_165', 'blocks_85', 'book_500']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 79
# Conteggio: 79
# {'ball': 67, 'bike': 67, 'blocks': 67, 'book': 67, 'coal': 66, 'doll': 66, 'gloves': 66, 'horse': 66, 'train': 66}
#
# Oggetti inseriti: ['coal_23', 'doll_985', 'gloves_69', 'horse_579', 'train_229', 'ball_166', 'bike_405']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 80
# Conteggio: 80
# {'ball': 68, 'bike': 68, 'blocks': 67, 'book': 67, 'coal': 67, 'doll': 67, 'gloves': 67, 'horse': 67, 'train': 67}
#
# Oggetti inseriti: ['blocks_52', 'book_43', 'coal_103', 'doll_885', 'gloves_41', 'horse_703']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 81
# Conteggio: 81
# {'ball': 68, 'bike': 68, 'blocks': 68, 'book': 68, 'coal': 68, 'doll': 68, 'gloves': 68, 'horse': 68, 'train': 67}
#
# Oggetti inseriti: ['train_351', 'ball_727', 'bike_454', 'blocks_504', 'book_1105']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 82
# Conteggio: 82
# {'ball': 69, 'bike': 69, 'blocks': 69, 'book': 69, 'coal': 68, 'doll': 68, 'gloves': 68, 'horse': 68, 'train': 68}
#
# Oggetti inseriti: ['coal_46', 'doll_109', 'gloves_0', 'horse_517', 'train_445', 'ball_320', 'bike_494']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 83
# Conteggio: 83
# {'ball': 70, 'bike': 70, 'blocks': 69, 'book': 69, 'coal': 69, 'doll': 69, 'gloves': 69, 'horse': 69, 'train': 69}
#
# Oggetti inseriti: ['blocks_265', 'book_655', 'coal_147', 'doll_28', 'gloves_124', 'horse_176', 'train_129', 'ball_373', 'bike_280']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 84
# Conteggio: 84
# {'ball': 71, 'bike': 71, 'blocks': 70, 'book': 70, 'coal': 70, 'doll': 70, 'gloves': 70, 'horse': 70, 'train': 70}
#
# Oggetti inseriti: ['blocks_624', 'book_56', 'coal_43', 'doll_154', 'gloves_163', 'horse_332', 'train_145', 'ball_974']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 85
# Conteggio: 85
# {'ball': 72, 'bike': 71, 'blocks': 71, 'book': 71, 'coal': 71, 'doll': 71, 'gloves': 71, 'horse': 71, 'train': 71}
#
# Oggetti inseriti: ['bike_371', 'blocks_758', 'book_187', 'coal_40']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 86
# Conteggio: 86
# {'ball': 72, 'bike': 72, 'blocks': 72, 'book': 72, 'coal': 72, 'doll': 71, 'gloves': 71, 'horse': 71, 'train': 71}
#
# Oggetti inseriti: ['doll_896', 'gloves_2', 'horse_607', 'train_326', 'ball_742', 'bike_114', 'blocks_437', 'book_86']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 87
# Conteggio: 87
# {'ball': 73, 'bike': 73, 'blocks': 73, 'book': 73, 'coal': 72, 'doll': 72, 'gloves': 72, 'horse': 72, 'train': 72}
#
# Oggetti inseriti: ['coal_5', 'doll_853', 'gloves_5', 'horse_830', 'train_347', 'ball_316']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 88
# Conteggio: 88
# {'ball': 74, 'bike': 73, 'blocks': 73, 'book': 73, 'coal': 73, 'doll': 73, 'gloves': 73, 'horse': 73, 'train': 73}
#
# Oggetti inseriti: ['bike_378', 'blocks_651', 'book_1125', 'coal_60', 'doll_612']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 89
# Conteggio: 89
# {'ball': 74, 'bike': 74, 'blocks': 74, 'book': 74, 'coal': 74, 'doll': 74, 'gloves': 73, 'horse': 73, 'train': 73}
#
# Oggetti inseriti: ['gloves_140', 'horse_619', 'train_683', 'ball_192', 'bike_208', 'blocks_66', 'book_111']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 90
# Conteggio: 90
# {'ball': 75, 'bike': 75, 'blocks': 75, 'book': 75, 'coal': 74, 'doll': 74, 'gloves': 74, 'horse': 74, 'train': 74}
#
# Oggetti inseriti: ['coal_57', 'doll_998', 'gloves_38', 'horse_181', 'train_778']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 91
# Conteggio: 91
# {'ball': 75, 'bike': 75, 'blocks': 75, 'book': 75, 'coal': 75, 'doll': 75, 'gloves': 75, 'horse': 75, 'train': 75}
#
# Oggetti inseriti: ['ball_583', 'bike_273', 'blocks_551', 'book_309', 'coal_142', 'doll_935', 'gloves_146', 'horse_748', 'train_280']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 92
# Conteggio: 92
# {'ball': 76, 'bike': 76, 'blocks': 76, 'book': 76, 'coal': 76, 'doll': 76, 'gloves': 76, 'horse': 76, 'train': 76}
#
# Oggetti inseriti: ['ball_695', 'bike_36', 'blocks_111', 'book_378', 'coal_89', 'doll_205']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 93
# Conteggio: 93
# {'ball': 77, 'bike': 77, 'blocks': 77, 'book': 77, 'coal': 77, 'doll': 77, 'gloves': 76, 'horse': 76, 'train': 76}
#
# Oggetti inseriti: ['gloves_86', 'horse_88', 'train_825', 'ball_723', 'bike_209', 'blocks_576', 'book_410']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 94
# Conteggio: 94
# {'ball': 78, 'bike': 78, 'blocks': 78, 'book': 78, 'coal': 77, 'doll': 77, 'gloves': 77, 'horse': 77, 'train': 77}
#
# Oggetti inseriti: ['coal_66', 'doll_82', 'gloves_158', 'horse_571']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 95
# Conteggio: 95
# {'ball': 78, 'bike': 78, 'blocks': 78, 'book': 78, 'coal': 78, 'doll': 78, 'gloves': 78, 'horse': 78, 'train': 77}
#
# Oggetti inseriti: ['train_523', 'ball_262', 'bike_44', 'blocks_23', 'book_423', 'coal_164', 'doll_789', 'gloves_60', 'horse_586']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 96
# Conteggio: 96
# {'ball': 79, 'bike': 79, 'blocks': 79, 'book': 79, 'coal': 79, 'doll': 79, 'gloves': 79, 'horse': 79, 'train': 78}
#
# Oggetti inseriti: ['train_192', 'ball_0', 'bike_172', 'blocks_384', 'book_482']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 97
# Conteggio: 97
# {'ball': 80, 'bike': 80, 'blocks': 80, 'book': 80, 'coal': 79, 'doll': 79, 'gloves': 79, 'horse': 79, 'train': 79}
#
# Oggetti inseriti: ['coal_148', 'doll_80', 'gloves_71', 'horse_21']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 98
# Conteggio: 98
# {'ball': 80, 'bike': 80, 'blocks': 80, 'book': 80, 'coal': 80, 'doll': 80, 'gloves': 80, 'horse': 80, 'train': 79}
#
# Oggetti inseriti: ['train_818', 'ball_112', 'bike_469', 'blocks_432', 'book_81']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 99
# Conteggio: 99
# {'ball': 81, 'bike': 81, 'blocks': 81, 'book': 81, 'coal': 80, 'doll': 80, 'gloves': 80, 'horse': 80, 'train': 80}
#
# Oggetti inseriti: ['coal_2', 'doll_90', 'gloves_162', 'horse_231']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 100
# Conteggio: 100
# {'ball': 81, 'bike': 81, 'blocks': 81, 'book': 81, 'coal': 81, 'doll': 81, 'gloves': 81, 'horse': 81, 'train': 80}
#
# Oggetti inseriti: ['train_885', 'ball_956', 'bike_41']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 101
# Conteggio: 101
# {'ball': 82, 'bike': 82, 'blocks': 81, 'book': 81, 'coal': 81, 'doll': 81, 'gloves': 81, 'horse': 81, 'train': 81}
#
# Oggetti inseriti: ['blocks_352', 'book_834', 'coal_22', 'doll_609', 'gloves_147']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 102
# Conteggio: 102
# {'ball': 82, 'bike': 82, 'blocks': 82, 'book': 82, 'coal': 82, 'doll': 82, 'gloves': 82, 'horse': 81, 'train': 81}
#
# Oggetti inseriti: ['horse_45', 'train_85', 'ball_90', 'bike_465', 'blocks_908', 'book_352']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 103
# Conteggio: 103
# {'ball': 83, 'bike': 83, 'blocks': 83, 'book': 83, 'coal': 82, 'doll': 82, 'gloves': 82, 'horse': 82, 'train': 82}
#
# Oggetti inseriti: ['coal_124', 'doll_628', 'gloves_121', 'horse_263']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 104
# Conteggio: 104
# {'ball': 83, 'bike': 83, 'blocks': 83, 'book': 83, 'coal': 83, 'doll': 83, 'gloves': 83, 'horse': 83, 'train': 82}
#
# Oggetti inseriti: ['train_245', 'ball_519', 'bike_475', 'blocks_973', 'book_245']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 105
# Conteggio: 105
# {'ball': 84, 'bike': 84, 'blocks': 84, 'book': 84, 'coal': 83, 'doll': 83, 'gloves': 83, 'horse': 83, 'train': 83}
#
# Oggetti inseriti: ['coal_59', 'doll_93', 'gloves_58', 'horse_496', 'train_790', 'ball_374', 'bike_52']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 106
# Conteggio: 106
# {'ball': 85, 'bike': 85, 'blocks': 84, 'book': 84, 'coal': 84, 'doll': 84, 'gloves': 84, 'horse': 84, 'train': 84}
#
# Oggetti inseriti: ['blocks_163', 'book_784', 'coal_90', 'doll_393', 'gloves_50', 'horse_899', 'train_27']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 107
# Conteggio: 107
# {'ball': 85, 'bike': 85, 'blocks': 85, 'book': 85, 'coal': 85, 'doll': 85, 'gloves': 85, 'horse': 85, 'train': 85}
#
# Oggetti inseriti: ['ball_916', 'bike_169', 'blocks_426', 'book_676', 'coal_8', 'doll_655', 'gloves_55', 'horse_743']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 108
# Conteggio: 108
# {'ball': 86, 'bike': 86, 'blocks': 86, 'book': 86, 'coal': 86, 'doll': 86, 'gloves': 86, 'horse': 86, 'train': 85}
#
# Oggetti inseriti: ['train_546', 'ball_141', 'bike_426', 'blocks_971', 'book_454', 'coal_33', 'doll_138', 'gloves_98', 'horse_292', 'train_58']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 109
# Conteggio: 109
# {'ball': 87, 'bike': 87, 'blocks': 87, 'book': 87, 'coal': 87, 'doll': 87, 'gloves': 87, 'horse': 87, 'train': 87}
#
# Oggetti inseriti: ['ball_446', 'bike_289', 'blocks_29', 'book_1149', 'coal_44', 'doll_707', 'gloves_169']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 110
# Conteggio: 110
# {'ball': 88, 'bike': 88, 'blocks': 88, 'book': 88, 'coal': 88, 'doll': 88, 'gloves': 88, 'horse': 87, 'train': 87}
#
# Oggetti inseriti: ['horse_951', 'train_236', 'ball_988', 'bike_451', 'blocks_68', 'book_602']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 111
# Conteggio: 111
# {'ball': 89, 'bike': 89, 'blocks': 89, 'book': 89, 'coal': 88, 'doll': 88, 'gloves': 88, 'horse': 88, 'train': 88}
#
# Oggetti inseriti: ['coal_16', 'doll_622', 'gloves_118', 'horse_765', 'train_658', 'ball_232']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 112
# Conteggio: 112
# {'ball': 90, 'bike': 89, 'blocks': 89, 'book': 89, 'coal': 89, 'doll': 89, 'gloves': 89, 'horse': 89, 'train': 89}
#
# Oggetti inseriti: ['bike_372', 'blocks_579', 'book_10', 'coal_114', 'doll_121', 'gloves_101']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 113
# Conteggio: 113
# {'ball': 90, 'bike': 90, 'blocks': 90, 'book': 90, 'coal': 90, 'doll': 90, 'gloves': 90, 'horse': 89, 'train': 89}
#
# Oggetti inseriti: ['horse_218', 'train_534', 'ball_218', 'bike_318', 'blocks_520', 'book_430']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 114
# Conteggio: 114
# {'ball': 91, 'bike': 91, 'blocks': 91, 'book': 91, 'coal': 90, 'doll': 90, 'gloves': 90, 'horse': 90, 'train': 90}
#
# Oggetti inseriti: ['coal_84', 'doll_72', 'gloves_24', 'horse_573', 'train_4', 'ball_211', 'bike_55', 'blocks_615', 'book_401']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 115
# Conteggio: 115
# {'ball': 92, 'bike': 92, 'blocks': 92, 'book': 92, 'coal': 91, 'doll': 91, 'gloves': 91, 'horse': 91, 'train': 91}
#
# Oggetti inseriti: ['coal_93', 'doll_874', 'gloves_74', 'horse_694', 'train_383']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 116
# Conteggio: 116
# {'ball': 92, 'bike': 92, 'blocks': 92, 'book': 92, 'coal': 92, 'doll': 92, 'gloves': 92, 'horse': 92, 'train': 92}
#
# Oggetti inseriti: ['ball_652', 'bike_119', 'blocks_175', 'book_179', 'coal_45', 'doll_678', 'gloves_165', 'horse_840']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 117
# Conteggio: 117
# {'ball': 93, 'bike': 93, 'blocks': 93, 'book': 93, 'coal': 93, 'doll': 93, 'gloves': 93, 'horse': 93, 'train': 92}
#
# Oggetti inseriti: ['train_966', 'ball_537', 'bike_413', 'blocks_123', 'book_183', 'coal_116', 'doll_284', 'gloves_103']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 118
# Conteggio: 118
# {'ball': 94, 'bike': 94, 'blocks': 94, 'book': 94, 'coal': 94, 'doll': 94, 'gloves': 94, 'horse': 93, 'train': 93}
#
# Oggetti inseriti: ['horse_389', 'train_278', 'ball_1089', 'bike_408', 'blocks_366', 'book_82']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 119
# Conteggio: 119
# {'ball': 95, 'bike': 95, 'blocks': 95, 'book': 95, 'coal': 94, 'doll': 94, 'gloves': 94, 'horse': 94, 'train': 94}
#
# Oggetti inseriti: ['coal_113', 'doll_286', 'gloves_12', 'horse_450', 'train_185', 'ball_841']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 120
# Conteggio: 120
# {'ball': 96, 'bike': 95, 'blocks': 95, 'book': 95, 'coal': 95, 'doll': 95, 'gloves': 95, 'horse': 95, 'train': 95}
#
# Oggetti inseriti: ['bike_433', 'blocks_489', 'book_1162', 'coal_121', 'doll_443', 'gloves_53', 'horse_847']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 121
# Conteggio: 121
# {'ball': 96, 'bike': 96, 'blocks': 96, 'book': 96, 'coal': 96, 'doll': 96, 'gloves': 96, 'horse': 96, 'train': 95}
#
# Oggetti inseriti: ['train_323', 'ball_318', 'bike_434', 'blocks_553', 'book_984']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 122
# Conteggio: 122
# {'ball': 97, 'bike': 97, 'blocks': 97, 'book': 97, 'coal': 96, 'doll': 96, 'gloves': 96, 'horse': 96, 'train': 96}
#
# Oggetti inseriti: ['coal_19', 'doll_428', 'gloves_76', 'horse_281', 'train_151']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 123
# Conteggio: 123
# {'ball': 97, 'bike': 97, 'blocks': 97, 'book': 97, 'coal': 97, 'doll': 97, 'gloves': 97, 'horse': 97, 'train': 97}
#
# Oggetti inseriti: ['ball_983', 'bike_166', 'blocks_948', 'book_209', 'coal_54']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 124
# Conteggio: 124
# {'ball': 98, 'bike': 98, 'blocks': 98, 'book': 98, 'coal': 98, 'doll': 97, 'gloves': 97, 'horse': 97, 'train': 97}
#
# Oggetti inseriti: ['doll_440', 'gloves_92', 'horse_268', 'train_395', 'ball_1060', 'bike_385']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 125
# Conteggio: 125
# {'ball': 99, 'bike': 99, 'blocks': 98, 'book': 98, 'coal': 98, 'doll': 98, 'gloves': 98, 'horse': 98, 'train': 98}
#
# Oggetti inseriti: ['blocks_629', 'book_1099', 'coal_100', 'doll_711', 'gloves_83', 'horse_50']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 126
# Conteggio: 126
# {'ball': 99, 'bike': 99, 'blocks': 99, 'book': 99, 'coal': 99, 'doll': 99, 'gloves': 99, 'horse': 99, 'train': 98}
#
# Oggetti inseriti: ['train_605', 'ball_227', 'bike_471', 'blocks_590', 'book_733', 'coal_27', 'doll_98', 'gloves_8']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 127
# Conteggio: 127
# {'ball': 100, 'bike': 100, 'blocks': 100, 'book': 100, 'coal': 100, 'doll': 100, 'gloves': 100, 'horse': 99, 'train': 99}
# Oggetti inseriti: ['horse_631', 'train_718', 'ball_908', 'bike_444', 'blocks_787', 'book_507']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 128
# Conteggio: 128
# {'ball': 101, 'bike': 101, 'blocks': 101, 'book': 101, 'coal': 100, 'doll': 100, 'gloves': 100, 'horse': 100, 'train': 100}
#
# Oggetti inseriti: ['coal_68', 'doll_385', 'gloves_136', 'horse_632']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 129
# Conteggio: 129
# {'ball': 101, 'bike': 101, 'blocks': 101, 'book': 101, 'coal': 101, 'doll': 101, 'gloves': 101, 'horse': 101, 'train': 100}
#
# Oggetti inseriti: ['train_729', 'ball_306', 'bike_455', 'blocks_991', 'book_165']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 130
# Conteggio: 130
# {'ball': 102, 'bike': 102, 'blocks': 102, 'book': 102, 'coal': 101, 'doll': 101, 'gloves': 101, 'horse': 101, 'train': 101}
#
# Oggetti inseriti: ['coal_69', 'doll_557', 'gloves_157', 'horse_137']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 131
# Conteggio: 131
# {'ball': 102, 'bike': 102, 'blocks': 102, 'book': 102, 'coal': 102, 'doll': 102, 'gloves': 102, 'horse': 102, 'train': 101}
#
# Oggetti inseriti: ['train_315', 'ball_582', 'bike_419', 'blocks_369', 'book_348']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 132
# Conteggio: 132
# {'ball': 103, 'bike': 103, 'blocks': 103, 'book': 103, 'coal': 102, 'doll': 102, 'gloves': 102, 'horse': 102, 'train': 102}
#
# Oggetti inseriti: ['coal_109', 'doll_702', 'gloves_129', 'horse_961']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 133
# Conteggio: 133
# {'ball': 103, 'bike': 103, 'blocks': 103, 'book': 103, 'coal': 103, 'doll': 103, 'gloves': 103, 'horse': 103, 'train': 102}
#
# Oggetti inseriti: ['train_38', 'ball_1084', 'bike_112', 'blocks_372', 'book_608']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 134
# Conteggio: 134
# {'ball': 104, 'bike': 104, 'blocks': 104, 'book': 104, 'coal': 103, 'doll': 103, 'gloves': 103, 'horse': 103, 'train': 103}
#
# Oggetti inseriti: ['coal_156', 'doll_283', 'gloves_127']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 135
# Conteggio: 135
# {'ball': 104, 'bike': 104, 'blocks': 104, 'book': 104, 'coal': 104, 'doll': 104, 'gloves': 104, 'horse': 103, 'train': 103}
#
# Oggetti inseriti: ['horse_269', 'train_220', 'ball_53', 'bike_418', 'blocks_774', 'book_913']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 136
# Conteggio: 136
# {'ball': 105, 'bike': 105, 'blocks': 105, 'book': 105, 'coal': 104, 'doll': 104, 'gloves': 104, 'horse': 104, 'train': 104}
#
# Oggetti inseriti: ['coal_34', 'doll_20', 'gloves_48', 'horse_780', 'train_478', 'ball_174', 'bike_207']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 137
# Conteggio: 137
# {'ball': 106, 'bike': 106, 'blocks': 105, 'book': 105, 'coal': 105, 'doll': 105, 'gloves': 105, 'horse': 105, 'train': 105}
#
# Oggetti inseriti: ['blocks_983', 'book_878', 'coal_145', 'doll_931', 'gloves_142']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 138
# Conteggio: 138
# {'ball': 106, 'bike': 106, 'blocks': 106, 'book': 106, 'coal': 106, 'doll': 106, 'gloves': 106, 'horse': 105, 'train': 105}
#
# Oggetti inseriti: ['horse_362', 'train_810', 'ball_435', 'bike_104', 'blocks_75', 'book_580', 'coal_49']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 139
# Conteggio: 139
# {'ball': 107, 'bike': 107, 'blocks': 107, 'book': 107, 'coal': 107, 'doll': 106, 'gloves': 106, 'horse': 106, 'train': 106}
#
# Oggetti inseriti: ['doll_547', 'gloves_188', 'horse_861', 'train_239', 'ball_436', 'bike_387', 'blocks_613', 'book_925']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 140
# Conteggio: 140
# {'ball': 108, 'bike': 108, 'blocks': 108, 'book': 108, 'coal': 107, 'doll': 107, 'gloves': 107, 'horse': 107, 'train': 107}
#
# Oggetti inseriti: ['coal_3', 'doll_903', 'gloves_27']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 141
# Conteggio: 141
# {'ball': 108, 'bike': 108, 'blocks': 108, 'book': 108, 'coal': 108, 'doll': 108, 'gloves': 108, 'horse': 107, 'train': 107}
#
# Oggetti inseriti: ['horse_911', 'train_479', 'ball_129', 'bike_428']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 142
# Conteggio: 142
# {'ball': 109, 'bike': 109, 'blocks': 108, 'book': 108, 'coal': 108, 'doll': 108, 'gloves': 108, 'horse': 108, 'train': 108}
#
# Oggetti inseriti: ['blocks_524', 'book_1049', 'coal_62', 'doll_912', 'gloves_56', 'horse_118', 'train_544']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 143
# Conteggio: 143
# {'ball': 109, 'bike': 109, 'blocks': 109, 'book': 109, 'coal': 109, 'doll': 109, 'gloves': 109, 'horse': 109, 'train': 109}
#
# Oggetti inseriti: ['ball_176', 'bike_292', 'blocks_821', 'book_132', 'coal_122', 'doll_777', 'gloves_97', 'horse_36']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 144
# Conteggio: 144
# {'ball': 110, 'bike': 110, 'blocks': 110, 'book': 110, 'coal': 110, 'doll': 110, 'gloves': 110, 'horse': 110, 'train': 109}
#
# Oggetti inseriti: ['train_360', 'ball_490', 'bike_133', 'blocks_170', 'book_138']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 145
# Conteggio: 145
# {'ball': 111, 'bike': 111, 'blocks': 111, 'book': 111, 'coal': 110, 'doll': 110, 'gloves': 110, 'horse': 110, 'train': 110}
#
# Oggetti inseriti: ['coal_82', 'doll_490', 'gloves_63']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 146
# Conteggio: 146
# {'ball': 111, 'bike': 111, 'blocks': 111, 'book': 111, 'coal': 111, 'doll': 111, 'gloves': 111, 'horse': 110, 'train': 110}
#
# Oggetti inseriti: ['horse_247', 'train_767', 'ball_552', 'bike_147', 'blocks_892', 'book_690']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 147
# Conteggio: 147
# {'ball': 112, 'bike': 112, 'blocks': 112, 'book': 112, 'coal': 111, 'doll': 111, 'gloves': 111, 'horse': 111, 'train': 111}
#
# Oggetti inseriti: ['coal_67', 'doll_466', 'gloves_31', 'horse_0']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 148
# Conteggio: 148
# {'ball': 112, 'bike': 112, 'blocks': 112, 'book': 112, 'coal': 112, 'doll': 112, 'gloves': 112, 'horse': 112, 'train': 111}
#
# Oggetti inseriti: ['train_45', 'ball_412', 'bike_241', 'blocks_566', 'book_342']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 149
# Conteggio: 149
# {'ball': 113, 'bike': 113, 'blocks': 113, 'book': 113, 'coal': 112, 'doll': 112, 'gloves': 112, 'horse': 112, 'train': 112}
#
# Oggetti inseriti: ['coal_160', 'doll_45', 'gloves_21']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 150
# Conteggio: 150
# {'ball': 113, 'bike': 113, 'blocks': 113, 'book': 113, 'coal': 113, 'doll': 113, 'gloves': 113, 'horse': 112, 'train': 112}
#
# Oggetti inseriti: ['horse_663', 'train_453', 'ball_49', 'bike_26', 'blocks_149', 'book_300']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 151
# Conteggio: 151
# {'ball': 114, 'bike': 114, 'blocks': 114, 'book': 114, 'coal': 113, 'doll': 113, 'gloves': 113, 'horse': 113, 'train': 113}
#
# Oggetti inseriti: ['gloves_170', 'horse_863', 'train_612', 'ball_328', 'bike_47', 'blocks_199', 'book_622']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 152
# Conteggio: 152
# {'ball': 115, 'bike': 115, 'blocks': 115, 'book': 115, 'coal': 114, 'doll': 114, 'gloves': 114, 'horse': 114, 'train': 114}
#
# Oggetti inseriti: ['coal_72', 'doll_834', 'gloves_78', 'horse_403', 'train_311', 'ball_123']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 153
# Conteggio: 153
# {'ball': 116, 'bike': 115, 'blocks': 115, 'book': 115, 'coal': 115, 'doll': 115, 'gloves': 115, 'horse': 115, 'train': 115}
#
# Oggetti inseriti: ['bike_320', 'blocks_766', 'book_325']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 154
# Conteggio: 154
# {'ball': 116, 'bike': 116, 'blocks': 116, 'book': 116, 'coal': 115, 'doll': 115, 'gloves': 115, 'horse': 115, 'train': 115}
#
# Oggetti inseriti: ['coal_154', 'doll_526', 'gloves_133', 'horse_687']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 155
# Conteggio: 155
# {'ball': 116, 'bike': 116, 'blocks': 116, 'book': 116, 'coal': 116, 'doll': 116, 'gloves': 116, 'horse': 116, 'train': 115}
#
# Oggetti inseriti: ['train_451', 'ball_348', 'bike_15', 'blocks_764', 'book_493']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 156
# Conteggio: 156
# {'ball': 117, 'bike': 117, 'blocks': 117, 'book': 117, 'coal': 116, 'doll': 116, 'gloves': 116, 'horse': 116, 'train': 116}
#
# Oggetti inseriti: ['coal_126', 'doll_565', 'gloves_143']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 157
# Conteggio: 157
# {'ball': 117, 'bike': 117, 'blocks': 117, 'book': 117, 'coal': 117, 'doll': 117, 'gloves': 117, 'horse': 116, 'train': 116}
#
# Oggetti inseriti: ['horse_222', 'train_800', 'ball_1081', 'bike_330', 'blocks_477', 'book_589']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 158
# Conteggio: 158
# {'ball': 118, 'bike': 118, 'blocks': 118, 'book': 118, 'coal': 117, 'doll': 117, 'gloves': 117, 'horse': 117, 'train': 117}
#
# Oggetti inseriti: ['coal_97', 'doll_34', 'gloves_134', 'horse_915', 'train_602', 'ball_1020']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 159
# Conteggio: 159
# {'ball': 119, 'bike': 118, 'blocks': 118, 'book': 118, 'coal': 118, 'doll': 118, 'gloves': 118, 'horse': 118, 'train': 118}
#
# Oggetti inseriti: ['bike_151', 'blocks_608', 'book_8']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 160
# Conteggio: 160
# {'ball': 119, 'bike': 119, 'blocks': 119, 'book': 119, 'coal': 118, 'doll': 118, 'gloves': 118, 'horse': 118, 'train': 118}
#
# Oggetti inseriti: ['coal_108', 'doll_33', 'gloves_59', 'horse_664']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 161
# Conteggio: 161
# {'ball': 119, 'bike': 119, 'blocks': 119, 'book': 119, 'coal': 119, 'doll': 119, 'gloves': 119, 'horse': 119, 'train': 118}
#
# Oggetti inseriti: ['train_632', 'ball_903', 'bike_478', 'blocks_618', 'book_362']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 162
# Conteggio: 162
# {'ball': 120, 'bike': 120, 'blocks': 120, 'book': 120, 'coal': 119, 'doll': 119, 'gloves': 119, 'horse': 119, 'train': 119}
#
# Oggetti inseriti: ['coal_110', 'doll_920', 'gloves_10']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 163
# Conteggio: 163
# {'ball': 120, 'bike': 120, 'blocks': 120, 'book': 120, 'coal': 120, 'doll': 120, 'gloves': 120, 'horse': 119, 'train': 119}
#
# Oggetti inseriti: ['horse_670', 'train_391', 'ball_1056', 'bike_366', 'blocks_97', 'book_320']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 164
# Conteggio: 164
# {'ball': 121, 'bike': 121, 'blocks': 121, 'book': 121, 'coal': 120, 'doll': 120, 'gloves': 120, 'horse': 120, 'train': 120}
#
# Oggetti inseriti: ['coal_102', 'doll_662', 'gloves_3', 'horse_43', 'train_963']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 165
# Conteggio: 165
# {'ball': 121, 'bike': 121, 'blocks': 121, 'book': 121, 'coal': 121, 'doll': 121, 'gloves': 121, 'horse': 121, 'train': 121}
#
# Oggetti inseriti: ['ball_31', 'bike_8', 'blocks_943', 'book_1166']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 166
# Conteggio: 166
# {'ball': 122, 'bike': 122, 'blocks': 122, 'book': 122, 'coal': 121, 'doll': 121, 'gloves': 121, 'horse': 121, 'train': 121}
#
# Oggetti inseriti: ['gloves_94', 'horse_756', 'train_434', 'ball_1059', 'bike_187', 'blocks_416', 'book_294']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 167
# Conteggio: 167
# {'ball': 123, 'bike': 123, 'blocks': 123, 'book': 123, 'coal': 122, 'doll': 122, 'gloves': 122, 'horse': 122, 'train': 122}
#
# Oggetti inseriti: ['coal_137', 'doll_480', 'gloves_14']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 168
# Conteggio: 168
# {'ball': 123, 'bike': 123, 'blocks': 123, 'book': 123, 'coal': 123, 'doll': 123, 'gloves': 123, 'horse': 122, 'train': 122}
#
# Oggetti inseriti: ['horse_602', 'train_182', 'ball_161', 'bike_132', 'blocks_773', 'book_272']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 169
# Conteggio: 169
# ...
# Sacchi riempiti: 939
# Conteggio: 939
# {'ball': 875, 'blocks': 875, 'book': 875, 'doll': 875, 'horse': 875, 'train': 874}
#
# Oggetti inseriti: ['train_362', 'ball_926', 'blocks_286', 'book_916', 'doll_710', 'horse_854', 'train_652', 'ball_999']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 940
# Conteggio: 940
# {'ball': 877, 'blocks': 876, 'book': 876, 'doll': 876, 'horse': 876, 'train': 876}
#
# Oggetti inseriti: ['blocks_571', 'book_1137', 'doll_276', 'horse_609', 'train_60', 'ball_862']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 941
# Conteggio: 941
# {'ball': 878, 'blocks': 877, 'book': 877, 'doll': 877, 'horse': 877, 'train': 877}
#
# Oggetti inseriti: ['blocks_620', 'book_251', 'doll_737', 'horse_965', 'train_925', 'ball_3', 'blocks_128', 'book_1059']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 942
# Conteggio: 942
# {'ball': 879, 'blocks': 879, 'book': 879, 'doll': 878, 'horse': 878, 'train': 878}
#
# Oggetti inseriti: ['doll_22', 'horse_309', 'train_194', 'ball_860', 'blocks_581', 'book_559', 'doll_10']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 943
# Conteggio: 943
# {'ball': 880, 'blocks': 880, 'book': 880, 'doll': 880, 'horse': 879, 'train': 879}
#
# Oggetti inseriti: ['horse_93', 'train_425', 'ball_925', 'blocks_24', 'book_625', 'doll_573', 'horse_399', 'train_410', 'ball_314']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 944
# Conteggio: 944
# {'ball': 882, 'blocks': 881, 'book': 881, 'doll': 881, 'horse': 881, 'train': 881}
#
# Oggetti inseriti: ['blocks_715', 'book_701', 'doll_878', 'horse_416', 'train_644', 'ball_985', 'blocks_33', 'book_818']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 945
# Conteggio: 945
# {'ball': 883, 'blocks': 883, 'book': 883, 'doll': 882, 'horse': 882, 'train': 882}
#
# Oggetti inseriti: ['doll_504', 'horse_83', 'train_563', 'ball_701', 'blocks_236', 'book_115', 'doll_218', 'horse_661']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 946
# Conteggio: 946
# {'ball': 884, 'blocks': 884, 'book': 884, 'doll': 884, 'horse': 884, 'train': 883}
#
# Oggetti inseriti: ['train_265', 'ball_264', 'blocks_177', 'book_512', 'doll_184', 'horse_105', 'train_708', 'ball_761']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 947
# Conteggio: 947
# {'ball': 886, 'blocks': 885, 'book': 885, 'doll': 885, 'horse': 885, 'train': 885}
#
# Oggetti inseriti: ['blocks_368', 'book_897', 'doll_484', 'horse_530', 'train_401', 'ball_443']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 948
# Conteggio: 948
# {'ball': 887, 'blocks': 886, 'book': 886, 'doll': 886, 'horse': 886, 'train': 886}
#
# Oggetti inseriti: ['blocks_749', 'book_243', 'doll_26', 'horse_678', 'train_204', 'ball_992', 'blocks_806', 'book_1114']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 949
# Conteggio: 949
# {'ball': 888, 'blocks': 888, 'book': 888, 'doll': 887, 'horse': 887, 'train': 887}
#
# Oggetti inseriti: ['doll_965', 'horse_973', 'train_620', 'ball_670', 'blocks_55', 'book_780', 'doll_924', 'horse_624', 'train_991', 'ball_791']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 950
# Conteggio: 950
# {'ball': 890, 'blocks': 889, 'book': 889, 'doll': 889, 'horse': 889, 'train': 889}
#
# Oggetti inseriti: ['blocks_165', 'book_964', 'doll_476', 'horse_771', 'train_696', 'ball_185']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 951
# Conteggio: 951
# {'ball': 891, 'blocks': 890, 'book': 890, 'doll': 890, 'horse': 890, 'train': 890}
#
# Oggetti inseriti: ['blocks_281', 'book_197', 'doll_407', 'horse_454', 'train_284', 'ball_574', 'blocks_454', 'book_473']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 952
# Conteggio: 952
# {'ball': 892, 'blocks': 892, 'book': 892, 'doll': 891, 'horse': 891, 'train': 891}
#
# Oggetti inseriti: ['doll_593', 'horse_151', 'train_257', 'ball_639', 'blocks_297', 'book_388', 'doll_910']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 953
# Conteggio: 953
# {'ball': 893, 'blocks': 893, 'book': 893, 'doll': 893, 'horse': 892, 'train': 892}
#
# Oggetti inseriti: ['horse_363', 'train_740', 'ball_734', 'blocks_777', 'book_547', 'doll_246', 'horse_52', 'train_467']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 954
# Conteggio: 954
# {'ball': 894, 'blocks': 894, 'book': 894, 'doll': 894, 'horse': 894, 'train': 894}
#
# Oggetti inseriti: ['ball_52', 'blocks_838', 'book_142', 'doll_271', 'horse_433', 'train_282', 'ball_607']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 955
# Conteggio: 955
# {'ball': 896, 'blocks': 895, 'book': 895, 'doll': 895, 'horse': 895, 'train': 895}
#
# Oggetti inseriti: ['blocks_819', 'book_207', 'doll_668', 'horse_304', 'train_430', 'ball_724']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 956
# Conteggio: 956
# {'ball': 897, 'blocks': 896, 'book': 896, 'doll': 896, 'horse': 896, 'train': 896}
#
# Oggetti inseriti: ['blocks_632', 'book_877', 'doll_287', 'horse_594', 'train_99', 'ball_694', 'blocks_626', 'book_90']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 957
# Conteggio: 957
# {'ball': 898, 'blocks': 898, 'book': 898, 'doll': 897, 'horse': 897, 'train': 897}
#
# Oggetti inseriti: ['doll_170', 'horse_527', 'train_593', 'ball_851', 'blocks_212', 'book_967', 'doll_186']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 958
# Conteggio: 958
# {'ball': 899, 'blocks': 899, 'book': 899, 'doll': 899, 'horse': 898, 'train': 898}
#
# Oggetti inseriti: ['horse_843', 'train_548', 'ball_735', 'blocks_877', 'book_227', 'doll_734', 'horse_954']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 959
# Conteggio: 959
# {'ball': 900, 'blocks': 900, 'book': 900, 'doll': 900, 'horse': 900, 'train': 899}
#
# Oggetti inseriti: ['train_689', 'ball_931', 'blocks_251', 'book_192', 'doll_936', 'horse_290']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 960
# Conteggio: 960
# {'ball': 901, 'blocks': 901, 'book': 901, 'doll': 901, 'horse': 901, 'train': 900}
#
# Oggetti inseriti: ['train_253', 'ball_898', 'blocks_209', 'book_793', 'doll_99', 'horse_18', 'train_610', 'ball_479']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 961
# Conteggio: 961
# {'ball': 903, 'blocks': 902, 'book': 902, 'doll': 902, 'horse': 902, 'train': 902}
#
# Oggetti inseriti: ['blocks_710', 'book_711', 'doll_501', 'horse_360', 'train_875', 'ball_693', 'blocks_226']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 962
# Conteggio: 962
# {'ball': 904, 'blocks': 904, 'book': 903, 'doll': 903, 'horse': 903, 'train': 903}
#
# Oggetti inseriti: ['book_1003', 'doll_766', 'horse_738', 'train_516', 'ball_777', 'blocks_95', 'book_812', 'doll_926']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 963
# Conteggio: 963
# {'ball': 905, 'blocks': 905, 'book': 905, 'doll': 905, 'horse': 904, 'train': 904}
#
# Oggetti inseriti: ['horse_822', 'train_678', 'ball_1030', 'blocks_339', 'book_427', 'doll_262', 'horse_751', 'train_791', 'ball_930']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 964
# Conteggio: 964
# {'ball': 907, 'blocks': 906, 'book': 906, 'doll': 906, 'horse': 906, 'train': 906}
#
# Oggetti inseriti: ['blocks_517', 'book_674', 'doll_977', 'horse_931', 'train_669', 'ball_108', 'blocks_324', 'book_213']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 965
# Conteggio: 965
# {'ball': 908, 'blocks': 908, 'book': 908, 'doll': 907, 'horse': 907, 'train': 907}
#
# Oggetti inseriti: ['doll_292', 'horse_423', 'train_902', 'ball_292', 'blocks_541', 'book_1120', 'doll_57', 'horse_561']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 966
# Conteggio: 966
# {'ball': 909, 'blocks': 909, 'book': 909, 'doll': 909, 'horse': 909, 'train': 908}
#
# Oggetti inseriti: ['train_295', 'ball_378', 'blocks_800', 'book_1196', 'doll_229', 'horse_183', 'train_514', 'ball_400']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 967
# Conteggio: 967
# {'ball': 911, 'blocks': 910, 'book': 910, 'doll': 910, 'horse': 910, 'train': 910}
#
# Oggetti inseriti: ['blocks_600', 'book_757', 'doll_123', 'horse_825', 'train_271', 'ball_275']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 968
# Conteggio: 968
# {'ball': 912, 'blocks': 911, 'book': 911, 'doll': 911, 'horse': 911, 'train': 911}
#
# Oggetti inseriti: ['blocks_359', 'book_339', 'doll_437', 'horse_857', 'train_170', 'ball_686', 'blocks_76']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 969
# Conteggio: 969
# {'ball': 913, 'blocks': 913, 'book': 912, 'doll': 912, 'horse': 912, 'train': 912}
#
# Oggetti inseriti: ['book_871', 'doll_380', 'horse_334', 'train_917', 'ball_830', 'blocks_565', 'book_428', 'doll_60', 'horse_715']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 970
# Conteggio: 970
# {'ball': 914, 'blocks': 914, 'book': 914, 'doll': 914, 'horse': 914, 'train': 913}
#
# Oggetti inseriti: ['train_366', 'ball_748', 'blocks_473', 'book_744', 'doll_350', 'horse_536', 'train_400', 'ball_137']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 971
# Conteggio: 971
# {'ball': 916, 'blocks': 915, 'book': 915, 'doll': 915, 'horse': 915, 'train': 915}
#
# Oggetti inseriti: ['blocks_358', 'book_1116', 'doll_589', 'horse_210', 'train_173', 'ball_277']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 972
# Conteggio: 972
# {'ball': 917, 'blocks': 916, 'book': 916, 'doll': 916, 'horse': 916, 'train': 916}
#
# Oggetti inseriti: ['blocks_531', 'book_957', 'doll_56', 'horse_86', 'train_934', 'ball_540', 'blocks_874', 'book_1066', 'doll_189']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 973
# Conteggio: 973
# {'ball': 918, 'blocks': 918, 'book': 918, 'doll': 918, 'horse': 917, 'train': 917}
#
# Oggetti inseriti: ['horse_447', 'train_250', 'ball_1010', 'blocks_549', 'book_35', 'doll_210', 'horse_812']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 974
# Conteggio: 974
# {'ball': 919, 'blocks': 919, 'book': 919, 'doll': 919, 'horse': 919, 'train': 918}
#
# Oggetti inseriti: ['train_622', 'ball_265', 'blocks_863', 'book_9', 'doll_471', 'horse_261', 'train_625']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 975
# Conteggio: 975
# {'ball': 920, 'blocks': 920, 'book': 920, 'doll': 920, 'horse': 920, 'train': 920}
#
# Oggetti inseriti: ['ball_878', 'blocks_129', 'book_160', 'doll_590', 'horse_735', 'train_372', 'ball_138']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 976
# Conteggio: 976
# {'ball': 922, 'blocks': 921, 'book': 921, 'doll': 921, 'horse': 921, 'train': 921}
#
# Oggetti inseriti: ['blocks_886', 'book_714', 'doll_369', 'horse_714', 'train_720', 'ball_124']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 977
# Conteggio: 977
# {'ball': 923, 'blocks': 922, 'book': 922, 'doll': 922, 'horse': 922, 'train': 922}
#
# Oggetti inseriti: ['blocks_942', 'book_934', 'doll_11', 'horse_256', 'train_94', 'ball_504']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 978
# Conteggio: 978
# {'ball': 924, 'blocks': 923, 'book': 923, 'doll': 923, 'horse': 923, 'train': 923}
#
# Oggetti inseriti: ['blocks_67', 'book_540', 'doll_389', 'horse_387', 'train_904', 'ball_254']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 979
# Conteggio: 979
# {'ball': 925, 'blocks': 924, 'book': 924, 'doll': 924, 'horse': 924, 'train': 924}
#
# Oggetti inseriti: ['blocks_355', 'book_316', 'doll_227', 'horse_368', 'train_118', 'ball_596']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 980
# Conteggio: 980
# {'ball': 926, 'blocks': 925, 'book': 925, 'doll': 925, 'horse': 925, 'train': 925}
#
# Oggetti inseriti: ['blocks_173', 'book_1103', 'doll_701', 'horse_891', 'train_672', 'ball_831']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 981
# Conteggio: 981
# {'ball': 927, 'blocks': 926, 'book': 926, 'doll': 926, 'horse': 926, 'train': 926}
#
# Oggetti inseriti: ['blocks_249', 'book_848', 'doll_670', 'horse_445', 'train_34', 'ball_766']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 982
# Conteggio: 982
# {'ball': 928, 'blocks': 927, 'book': 927, 'doll': 927, 'horse': 927, 'train': 927}
#
# Oggetti inseriti: ['blocks_550', 'book_530', 'doll_298', 'horse_500', 'train_657', 'ball_388']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 983
# Conteggio: 983
# {'ball': 929, 'blocks': 928, 'book': 928, 'doll': 928, 'horse': 928, 'train': 928}
#
# Oggetti inseriti: ['blocks_86', 'book_71', 'doll_288', 'horse_604', 'train_540', 'ball_1077']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 984
# Conteggio: 984
# {'ball': 930, 'blocks': 929, 'book': 929, 'doll': 929, 'horse': 929, 'train': 929}
#
# Oggetti inseriti: ['blocks_505', 'book_1023', 'doll_163', 'horse_22', 'train_196', 'ball_819']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 985
# Conteggio: 985
# {'ball': 931, 'blocks': 930, 'book': 930, 'doll': 930, 'horse': 930, 'train': 930}
#
# Oggetti inseriti: ['blocks_190', 'book_850', 'doll_576', 'horse_24', 'train_977', 'ball_136']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 986
# Conteggio: 986
# {'ball': 932, 'blocks': 931, 'book': 931, 'doll': 931, 'horse': 931, 'train': 931}
#
# Oggetti inseriti: ['blocks_194', 'book_886', 'doll_25', 'horse_278', 'train_781']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 987
# Conteggio: 987
# {'ball': 932, 'blocks': 932, 'book': 932, 'doll': 932, 'horse': 932, 'train': 932}
#
# Oggetti inseriti: ['ball_279', 'blocks_444', 'book_829', 'doll_800', 'horse_446', 'train_675', 'ball_28']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 988
# Conteggio: 988
# {'ball': 934, 'blocks': 933, 'book': 933, 'doll': 933, 'horse': 933, 'train': 933}
#
# Oggetti inseriti: ['blocks_459', 'book_719', 'doll_324', 'horse_424', 'train_771', 'ball_711']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 989
# Conteggio: 989
# {'ball': 935, 'blocks': 934, 'book': 934, 'doll': 934, 'horse': 934, 'train': 934}
#
# Oggetti inseriti: ['blocks_878', 'book_95', 'doll_685', 'horse_937', 'train_687', 'ball_61', 'blocks_503', 'book_893']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 990
# Conteggio: 990
# {'ball': 936, 'blocks': 936, 'book': 936, 'doll': 935, 'horse': 935, 'train': 935}
#
# Oggetti inseriti: ['doll_268', 'horse_14', 'train_88', 'ball_610', 'blocks_282', 'book_847', 'doll_249']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 991
# Conteggio: 991
# {'ball': 937, 'blocks': 937, 'book': 937, 'doll': 937, 'horse': 936, 'train': 936}
#
# Oggetti inseriti: ['horse_421', 'train_308', 'ball_606', 'blocks_412', 'book_599', 'doll_158', 'horse_650']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 992
# Conteggio: 992
# {'ball': 938, 'blocks': 938, 'book': 938, 'doll': 938, 'horse': 938, 'train': 937}
#
# Oggetti inseriti: ['train_965', 'ball_872', 'blocks_798', 'book_720', 'doll_786', 'horse_276', 'train_726', 'ball_212']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 993
# Conteggio: 993
# {'ball': 940, 'blocks': 939, 'book': 939, 'doll': 939, 'horse': 939, 'train': 939}
#
# Oggetti inseriti: ['blocks_25', 'book_242', 'doll_431', 'horse_187', 'train_302', 'ball_594', 'blocks_235', 'book_615']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 994
# Conteggio: 994
# {'ball': 941, 'blocks': 941, 'book': 941, 'doll': 940, 'horse': 940, 'train': 940}
#
# Oggetti inseriti: ['doll_197', 'horse_275', 'train_829', 'ball_426', 'blocks_657', 'book_233', 'doll_539', 'horse_647']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 995
# Conteggio: 995
# {'ball': 942, 'blocks': 942, 'book': 942, 'doll': 942, 'horse': 942, 'train': 941}
#
# Oggetti inseriti: ['train_520', 'ball_379', 'blocks_38', 'book_102', 'doll_774', 'horse_125']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 996
# Conteggio: 996
# {'ball': 943, 'blocks': 943, 'book': 943, 'doll': 943, 'horse': 943, 'train': 942}
#
# Oggetti inseriti: ['train_631', 'ball_567', 'blocks_419', 'book_391', 'doll_376', 'horse_867']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 997
# Conteggio: 997
# {'ball': 944, 'blocks': 944, 'book': 944, 'doll': 944, 'horse': 944, 'train': 943}
#
# Oggetti inseriti: ['train_565', 'ball_303', 'blocks_439', 'book_804', 'doll_362', 'horse_964', 'train_858']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 998
# Conteggio: 998
# {'ball': 945, 'blocks': 945, 'book': 945, 'doll': 945, 'horse': 945, 'train': 945}
#
# Oggetti inseriti: ['ball_526', 'blocks_117', 'book_949', 'doll_930', 'horse_401', 'train_344', 'ball_242']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 999
# Conteggio: 999
# {'ball': 947, 'blocks': 946, 'book': 946, 'doll': 946, 'horse': 946, 'train': 946}
#
# Oggetti inseriti: ['blocks_274', 'book_255', 'doll_810', 'horse_908', 'train_288', 'ball_342', 'blocks_241', 'book_77']
# Sacchi fermati alla dogana: 0
# Sacchi riempiti: 1000
# Conteggio: 1000
# {'ball': 948, 'blocks': 948, 'book': 948, 'doll': 947, 'horse': 947, 'train': 947}
#
# time: 1min 1s

# %% [markdown]
# ## Giocattoli inseriti

# %%
print('Oggetti inseriti: %s' %(sum([len(el) for el in big_bag_ID])))
print('Proporzione oggetti inseriti: %f' %((sum([len(el) for el in big_bag_ID])/len(gift))))
# Out:
# Oggetti inseriti: 7030
# Proporzione oggetti inseriti: 0.986805
# time: 9.42 ms

# %% [markdown]
# ## Peso totale dei sacchi

# %%
print('Il peso totale dei sacchi risulta: %f lbs' %(sum([sum(el) for el in big_bag_weight])))
print('Il peso medio per sacco risulta: %f lbs' %((sum([sum(el) for el in big_bag_weight]))/len(big_bag_weight)))
# Out:
# Il peso totale dei sacchi risulta: 47638.487441 lbs
# Il peso medio per sacco risulta: 47.638487 lbs
# time: 12.9 ms

# %% [markdown]
# ## Controllo dei vincoli sui sacchi

# %%
print('Numero di sacchi oltre 50 lbs: %s' %(len([sum(el) for el in big_bag_weight if sum(el)>50])))
print('Numero di sacchi con meno di 3 giocattoli: %s' %(len([el for el in big_bag_ID if len(el) < 3])))
# Out:
# Numero di sacchi oltre 50 lbs: 0
# Numero di sacchi con meno di 3 giocattoli: 0
# time: 13.9 ms

# %% [markdown]
# ## Aggiunga dei giocattoli mancanti

# %%
#Alcuni giocattoli non sono stati inseriti, ma è possibile che in alcuni sacchi ci sia ancora spazio per loro

for el in diz_freq.keys(): #Per ogni tipologia di oggetto
    while len(globals()[el]) > 0:
        campione = globals()[el].sample(1) #Estrazione casuale
        campione_id = campione.index.values[0]
        campione_toy = campione['Toy'].iloc[0]
        campione_weight = campione['Weight'].iloc[0]
        
        cont = 0
        while cont < len(big_bag_ID): #Per ogni giocattolo controllo se esiste almeno un sacco in cui potrebbe entrare
            if sum(big_bag_weight[cont]) + campione_weight < 50:
                big_bag_weight[cont].append(campione_weight)
                big_bag_ID[cont].append(campione_id)
                big_bag_Toy[cont].append(campione_toy)
                globals()[el].drop(campione.index.values[0], axis = 0, inplace = True)
                diz_freq[el] = diz_freq[el] + 1
                break
            else:
                pass
            
            cont = cont + 1
            
            
        if cont == len(big_bag_ID):
            globals()[el].drop(campione.index.values[0], axis = 0, inplace = True)
# Out:
# time: 2.06 s

# %% [markdown]
# ## Ricontrollo i valori aggiornati

# %%
print('Oggetti inseriti: %s' %(sum([len(el) for el in big_bag_ID])))
print('Proporzione oggetti inseriti: %f' %((sum([len(el) for el in big_bag_ID])/len(gift))))

print('\n')

print('Il peso totale dei sacchi risulta: %f lbs' %(sum([sum(el) for el in big_bag_weight])))
print('Il peso medio per sacco risulta: %f lbs' %((sum([sum(el) for el in big_bag_weight]))/len(big_bag_weight)))

print('\n')

print('Numero di sacchi oltre 50 lbs: %s' %(len([sum(el) for el in big_bag_weight if sum(el)>50])))
print('Numero di sacchi con meno di 3 giocattoli: %s' %(len([el for el in big_bag_ID if len(el) < 3])))
# Out:
# Oggetti inseriti: 7030
# Proporzione oggetti inseriti: 0.986805
#
#
# Il peso totale dei sacchi risulta: 49410.810965 lbs
# Il peso medio per sacco risulta: 49.410811 lbs
#
#
# Numero di sacchi oltre 50 lbs: 0
# Numero di sacchi con meno di 3 giocattoli: 0
# time: 46.6 ms

# %% [markdown]
# ## Generalizzazione

# %% [markdown]
# L'algoritmo implementato ottiene risultati diversi a seconda del campione estratto ad ogni passaggio. Si possono ottenere dei risultati più generalizzati ripetendo l'operazione di ottimizzazione <i>n</i> volte.
# <br>
# Utilizzando un <b>random seed</b> per poter replicare i risultati si replica l'algoritmo di ottimizzazzione <i>100</i> volte.

# %%
repliche = 2

really_big_bag_ID = []
really_big_bag_Toy = []
really_big_bag_weight = []
bag_count_ID = []
bag_sum_weight = []
bag_time = []

for replica in range(repliche):
    start_time = time.time()
    #Inizializzazione dei dataset
    ball = gift[gift['Toy'] == 'ball'].reset_index(drop = True).set_index('GiftId')
    bike = gift[gift['Toy'] == 'bike'].reset_index(drop = True).set_index('GiftId')
    blocks = gift[gift['Toy'] == 'blocks'].reset_index(drop = True).set_index('GiftId')
    book = gift[gift['Toy'] == 'book'].reset_index(drop = True).set_index('GiftId')
    coal = gift[gift['Toy'] == 'coal'].reset_index(drop = True).set_index('GiftId')
    doll = gift[gift['Toy'] == 'doll'].reset_index(drop = True).set_index('GiftId')
    gloves = gift[gift['Toy'] == 'gloves'].reset_index(drop = True).set_index('GiftId')
    horse = gift[gift['Toy'] == 'horse'].reset_index(drop = True).set_index('GiftId')
    train = gift[gift['Toy'] == 'train'].reset_index(drop = True).set_index('GiftId')

    big_bag_ID = []
    big_bag_Toy = []
    big_bag_weight = []
    cont_bag = 0
    oggetti_inseriti = 0
    data_vuoti = 0
    sacchi_fermati_dogana = 0

    diz_freq = {'ball':0, 'bike':0, 'blocks':0, 'book':0, 'coal':0, 'doll':0, 'gloves':0, 'horse':0, 'train':0}
    while cont_bag < 1000: 
        copy = {}
        copy.update(diz_freq) 
        peso_sacco = 0
        bag_ID = []
        bag_Toy = []
        bag_Weight = []

        while peso_sacco < 50:
            min_toy = min(copy, key=copy.get) 
            if len(bag_ID) > 2 and (copy[min_toy] > (oggetti_inseriti)/(9 - data_vuoti)):
                break
   
            if min(globals()[min_toy]['Weight']) + peso_sacco > 50:
                success = 0
                while success == 0 and len(copy) > 1: 
                    del copy[min_toy]
                    min_toy = min(copy, key=copy.get)
                    if min(globals()[min_toy]['Weight']) + peso_sacco > 50:
                        success == 0
                    else:
                        success == 1

            if len(copy) < 2:
                break

            campione = globals()[min_toy].sample(1) 
            peso_temp = campione['Weight'].iloc[0] 
            if peso_sacco + peso_temp > 50:
                while peso_sacco + peso_temp > 50:
                    campione = globals()[min_toy].sample(1) 
                    peso_temp = campione['Weight'].iloc[0] 

            if campione.index.values[0] not in bag_ID:
                bag_ID.append(campione.index.values[0])
                bag_Toy.append(campione['Toy'].iloc[0])
                bag_Weight.append(campione['Weight'].iloc[0])
                
                diz_freq[min_toy] = diz_freq[min_toy] + 1
                copy[min_toy] = copy[min_toy] + 1

                peso_sacco = peso_sacco + peso_temp
                oggetti_inseriti = oggetti_inseriti + 1

                globals()[min_toy].drop(campione.index.values[0], axis = 0, inplace = True)
                if len(globals()[min_toy]) == 0:
                    data_vuoti = data_vuoti + 1
                    del diz_freq[min_toy]
                    del copy[min_toy]
   
        if len(copy) == 0 and len(bag_ID) < 3:
            #print('Attenzione: il sacco è stato bloccato dalla polizia del Polo Nord! Alcuni bambini non riceveranno il loro regalo :(')
            sacchi_fermati_dogana = sacchi_fermati_dogana + 1

        if len(bag_ID) > 2:
            big_bag_ID.append(bag_ID)
            big_bag_Toy.append(bag_Toy)
            big_bag_weight.append(bag_Weight)
            cont_bag = cont_bag + 1

            #print('Oggetti inseriti: %s' %(bag_ID))
            #print('Sacchi fermati alla dogana: %s' %(sacchi_fermati_dogana))
            #print('Sacchi riempiti: %s' %(len(big_bag_ID)))        
            #print('Conteggio: %s' %(cont_bag))
            #print('%s \n' %(diz_freq))
    
    
    really_big_bag_ID.append(big_bag_ID)
    really_big_bag_Toy.append(big_bag_Toy)
    really_big_bag_weight.append(big_bag_weight)
    bag_count_ID.append(sum([len(el) for el in big_bag_ID])) #Oggetti inseriti ad ogni iterazione
    bag_sum_weight.append((sum([len(el) for el in big_bag_ID])/len(gift))) #Peso totale ad ogni iterazione
    for el in diz_freq.keys(): 
        while len(globals()[el]) > 0:
            campione = globals()[el].sample(1) 
            campione_id = campione.index.values[0]
            campione_toy = campione['Toy'].iloc[0]
            campione_weight = campione['Weight'].iloc[0]

            cont = 0
            while cont < len(big_bag_ID):
                if sum(big_bag_weight[cont]) + campione_weight < 50:
                    big_bag_weight[cont].append(campione_weight)
                    big_bag_ID[cont].append(campione_id)
                    big_bag_Toy[cont].append(campione_toy)
                    globals()[el].drop(campione.index.values[0], axis = 0, inplace = True)
                    diz_freq[el] = diz_freq[el] + 1
                    break
                else:
                    pass

                cont = cont + 1

            if cont == len(big_bag_ID):
                globals()[el].drop(campione.index.values[0], axis = 0, inplace = True)
            
            
    #Aggiornamento delle liste dopo l'inclusione dei giocattoli non inseriti in un primo momento
    really_big_bag_ID.append(big_bag_ID)
    really_big_bag_Toy.append(big_bag_Toy)
    really_big_bag_weight.append(big_bag_weight)
    bag_count_ID.append(sum([len(el) for el in big_bag_ID])) 
    bag_sum_weight.append((sum([len(el) for el in big_bag_ID])/len(gift))) 
    
    end_time = time.time()
    bag_time.append(end_time - start_time)  
    
    print(replica)
# Out:
# 0
# 1
# time: 1min 50s

# %%
bag_sum_weight
# Out:
# [0.9195676586187536,
#  0.9869455362156092,
#  0.9192869174620999,
#  0.9863840539023021]
# time: 36.2 ms
