# %%
import os
os.chdir("C:/Users/prowm/OneDrive/Desktop/Data Science/Digital Signal/demo/")
# %run -i "libraries.py"
# %run -i "functions.py"
# Out:
# Using TensorFlow backend.

# %%
tree = joblib.load('tree.joblib')

# %%
tree_vgg = joblib.load('tree_vgg.joblib')

# %%
classify = input("Inserire tipologia di classificazione: ")
person = input("Inserire codice identificativo della persona: ")
day = input("Inserire giorno: ")
month = input("Inserire mese: ")

audio = read(feature_extractor=lambda x: mfcc(x, rate=44100, min_len=300, sample=5),
             classify=classify,
             person=person,
             day=day,
             month=month)

ipd.Audio(audio, rate=44100)
# Out:
# Inserire tipologia di classificazione: 4
# Inserire codice identificativo della persona: 0
# Inserire giorno: 1
# Inserire mese: 11
# Data 1 Novembre pronunciata da Luca
#
# 0_1_Novembre_0.wav
# Il modello ha classificato l'audio come:
# 	Luca 1 Novembre
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %matplotlib inline
pic(feature_extractor=nn_inception, person=-1, file=-1, prep=True, base_path="./rullino/")

# %%
# %matplotlib inline
pic(feature_extractor=nn_inception, person=-1, file=-1, prep=True, base_path="./downloads/")
# Out:
# La foto caricata è di Angela Merkel
# Classe predetta: 0
# La foto ritrae Angela Merkel
# functions.py:287: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# %matplotlib inline
index = np.random.randint(0, 80, 1)
retrieval(base_path='./rullino/', method='vgg', index=index, b=False, prep=True, brightness=[140, 200, 40], face=True)

# %%
# %matplotlib inline
index = np.random.randint(0, 80, 1)
retrieval(base_path='./downloads/', method='vgg', index=index, b=False, prep=True, brightness=[130, 200, 30], face=True)
# Out:
# [[73.08581277 74.12341196 77.33162477 77.96783913 78.14185438 78.92643
#   79.73135793 80.43806492 80.70729073 80.793983  ]]
# [[119.62017352 120.1106184  120.36937557 121.97704381 122.01375893
#   122.42668288 122.57143044 123.03557799 123.07525895 123.28213614]]
# [[74.61452539 75.61446152 76.19348479 76.56196276 77.13792535 77.19339856
#   77.34960515 77.38294507 77.66621162 77.90936983]]
